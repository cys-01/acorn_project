# %% [markdown]
# # PDF 크롤링 테스트

# %%
import pandas as pd

# %%
# !pip install PyMuPDF
# import fitz

# %%
def extract_text_from_pdf(pdf_path: str) -> str :

    doc = fitz.open(pdf_path)    # PDF 열기
    full_text = []

    for page_num, page in enumerate(doc, start=1):
        text = page.get_text()   # 페이지의 텍스트 추출
        full_text.append(f"{text}\n")

    doc.close()
    return "".join(full_text)


if __name__ == "__main__":
    pdf_file = "/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/국방과학기술플러스 262호.pdf"  # 텍스트를 추출할 PDF 파일 경로
    extracted_text = extract_text_from_pdf(pdf_file)
    # print(extracted_text)

# %%
import re
def split_sentences(text):
    # 마침표·물음표·느낌표 뒤에 공백이 올 때만 분리
    sentences = re.split(r'(?<=[\.!?])\s+', text)
    # 짧은 조각(10자 미만)은 제거
    sentences = [s for s in sentences if len(s) > 10]
    return sentences

# %%
example = split_sentences(extracted_text)
for i in range(len(example)):
    example[i] = example[i].replace('\n','')

# %%
print(len(example))
example[53]
# Out:
# 952
# '그림 3과 같이 모델 전체를 CNN이나 Transformer로 구성할 수 있으며, Transformer를 백본 네트워크로 사용하고 CNN 구조의 탐지기를 활용하거나 CNN 백본 네트 워크를 사용하고 Transformer decoder를 활용하는 등 두 (a) 2-Stage 탐지 모델(b) 1-Stage 탐지 모델감시정찰용 표적 탐지/인식을 위한 인공지능 기술 | 7모델을 융합할 수도 있다.'

# %%
def extract_text_from_pdf(pdf_path: str) -> str:
    """
    PDF의 모든 페이지에서 텍스트를 뽑아 하나의 문자열로 반환
    """
    doc = fitz.open(pdf_path)
    full_text = []
    for page in doc:
        full_text.append(page.get_text() + "\n")
    doc.close()
    return "".join(full_text)

def normalize_linebreaks(text: str) -> str:
    """
    • 단일 \n은 문장 연결용으로 간주하고 공백으로 대체
    • 연속된 \n\n 이상은 그대로 두어 단락 구분 유지
    """
    return re.sub(r'(?<!\n)\n(?!\n)', '', text)

def split_sentences(text: str, min_len: int = 10) -> list[str]:
    """
    • normalize_linebreaks로 먼저 연결
    • 영문 구두점(.!?)+공백 or 개행,
      한글 종결어미(다/요/습니다 등)+개행에 따라 분리
    • 너무 짧은 조각은 제거
    """
    # 1) 중간 줄바꿈 정리
    text = normalize_linebreaks(text)

    # 2) 분리 패턴
    pattern = (
        r'(?<=[\.!?])(?:\s+|\n)'   # .?! 뒤의 스페이스나 개행
        r'|(?<=[다요습니다요다])\n' # 한글 종결어미 뒤의 개행
    )
    parts = re.split(pattern, text)

    # 3) 10자 미만 제거 + 양쪽 공백 strip
    return [p.strip() for p in parts if len(p.strip()) >= min_len]

if __name__ == "__main__":
    pdf_file = "/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/국방과학기술플러스 262호.pdf"
    raw = extract_text_from_pdf(pdf_file)
    sentences = split_sentences(raw)

# %% [markdown]
# # 용어와 용례 매칭 테스트

# %% [markdown]
# - 매핑시킬 단어 사전

# %%
weapon = pd.read_csv('/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/무기의세계/무기의세계_불필요한것 제외.csv')
weapon.head()
# Out:
#            용어                                                 설명
# 0         F-2  F-2는 일본 항공자위대가 운용중인 전투기로 F-16 전투기를 바탕으로 미국과 일본...
# 1  알레이버크급 구축함  알레이버크급 구축함은 미 해군의 주력 수상전투함으로 이지스함의 대명사로 알려져 있다...
# 2   Ju 52 수송기  Ju 52는 제2차 대전 관련 에피소드에서 약방의 감초처럼 등장하는 숨은 주인공이었...
# 3       X-37B  X-37B는 미 공군이 운용중인 무인우주선으로 궤도시험기라는 정식명칭을 가지고 있다...
# 4        미니트맨  미니트맨은 미 공군이 운용중인 대륙간탄도미사일로 미국의 핵 억제력에 중추적인 위치를...

# %%
weapon_term = list(weapon['용어'])
len(weapon_term)
# Out:
# 366

# %%
map_dict = {}
not_map_dict = {}

# 2) term 별로 예시 수집
for term in weapon_term:
    matched = [ex for ex in sentences if term in ex]
    if matched:
        map_dict[term] = matched
    else:
        not_map_dict[term] = []  # 나중에 필요하시면 비어 있는 대신 count, None 등으로 바꿔도 OK

# 3) 결과 확인
print(f"매칭된 용어 수: {len(map_dict)}")
print(f"매칭되지 않은 용어 수: {len(not_map_dict)}")
# Out:
# 매칭된 용어 수: 3
# 매칭되지 않은 용어 수: 363

# %%
map_dict
# Out:
# {'SM-3': ['국방과학연구소 국방첨단과학기술연구원 소재에너지센터 선임연구원 이정민 온도, 압력, 유량↑ \uf0e8삭마↑ X43-A 온도, 압력, 유량↑ \uf0e8강도↓, 기밀↓ 능동냉각유로 리딩엣지 스크램젯 온도, 압력, 유량↑ \uf0e8삭마↑ SM-3 노즐목 위치•자세제어 Pue, A.',
#   '탄소섬유 기반 초고온 내열/내산화 복합소재 기술   \t 1\t 개요 초고온 내열 복합소재는 위에 대표 그림에서 나타나  있는 것과 같이 사드(THADD)와 유사한 유도탄 방어 무기체계(SM-3)에 필수 핵심부품 소재이다.'],
#  '사드': ['탄소섬유 기반 초고온 내열/내산화 복합소재 기술   \t 1\t 개요 초고온 내열 복합소재는 위에 대표 그림에서 나타나  있는 것과 같이 사드(THADD)와 유사한 유도탄 방어 무기체계(SM-3)에 필수 핵심부품 소재이다.'],
#  '어뢰': ['러시 아의 초공동 어뢰인 쉬크발(Shkval)의 경우 초공동 현 상 발생장치와 해수흡입 추진기관을 조합하여 약 200 노트의 속도를 내는 것으로 알려져 있다.',
#   '전기모터 혹 은 내연기관 방식의 어뢰가 50노트 수준임을 고려하면  표적이 회피하거나 반응할 시간을 제한하는 개념의 무 수중 유도무기 패러다임의 변화 해수흡입 추진기관!',
#   '해수흡입 추진기관 기술 동향 [그림 1] 초공동-해수흡입 추진기관 적용 어뢰 (A) 운용개념 (B) 이란 후트(Hoot) 발사 장면\n\n32 | 국방과학기술플러스 + 기체계이다.',
#   '하지만 이러한 초공동 어뢰의 경우 소음이 크고, 상 대적으로 사거리가 짧으며 유도기능이 제한적이라는  단점이 존재한다.',
#   '이러한 문제를 보완하기 위하여 그림  1과 같이 중요한 시설 보호를 위하여 고정식 발사 플 랫폼을 활용하거나 수상함에서 발사하는 개념이 제안 되고 있으며, 이란의 초공동 어뢰인 후트(Hoot)의 경 우 수상함에서 시험 발사하는 장면을 확인할 수 있다.',
#   '초공동 어뢰는  발사관에서 발사된 후, 사출모타를 통해 초기 가속되 며 순항 심도까지 이동한다.',
#   '사출모타는 작동 후 어뢰 로부터 분리된다.',
#   '러시아 서두에 언급한 바와 같이 해수흡입 추진기관을 초공 동 어뢰에 적용한 사례는 러시아의 쉬크발이다.',
#   '러시아 (구 소련)는 미국의 고속 원자력 잠수함과의 교전과 항 공모함을 공격하는 목적으로 초공동 어뢰 개발에 착수 하였다.',
#   '1960년대에 쉬크발(Shkval)이라는 명칭으로  개발을 시작하였으며, 약 200노트(370km/h)의 속력 으로 바닷속에서 항주가 가능하여 기존 어뢰 대비 4~5 배의 빠른 속력으로 알려져있다.',
#   '독일   1988년 독일은 초공동화연구를 시작하여 최근까지  최대속력 400km/h 이상을 만족하는 바라쿠다(Barracuda)  어뢰를 개발중에 있다.',
#   '개발기관인 DIEHL BGT  Defence에 의하면 바라쿠다는 수중 및 수상의 타켓뿐 만이 아니라 러시아에서 운용하고 있는 쉬크발 어뢰를  직접적으로 요격이 가능하다고 공개하였다.',
#   '더불어 2004년도 에는 새로운 초공동 어뢰개발을 착수하였으나 뚜렷한  프로젝트의 성과는 보여주지 못하고 있다.',
#   '이란   이란은 2006년 4월 2일과 3일 양일에 걸쳐 자체개 발 초공동 어뢰인 후트의 발사시험을 진행하였고 성공 적으로 목표물에 타격했다는 영상을 공개하였다.',
#   '중국  National university of defense technology,  China에서는 수반응 추진제 및 연소특성에 대한 다양 [그림 6] 독일의 바라쿠다 어뢰 개념도 [7] [그림 7] 이란이 공개한 후트 어뢰\n\n해수흡입 추진기관 기술 동향 | 35 한 연구를 수행한 바 있다[7-9].',
#   '순항 심도에 도달 한 초공동 어뢰는 시동부스터를 점화하여 순항 속도인  100m/s까지 가속한다.',
#   '해당 순항 속도에서는 초공동  어뢰의 운동으로 인해 초공동 어뢰 입구에서 약 50bar 에 이르는 고압으로 해수를 흡입하게 되며, 흡입된 해 수는 해수흡입 연소기의 인젝터와 수반응 추진제 이송 을 위한 피스톤으로 공급된다.',
#   '시 동부스터는 어뢰를 순항 속도까지 가속시키는 역할과  함께 수반응 추진제를 점화시키는 역할도 동시에 수행 하며, 시동부스터의 작동 중단에 따라 연소실로 유입 된 해수는 수반응 추진제 연소가스와 반응하여 추력을  발생시키게 된다.',
#   '어뢰 체계 의 형상 제한 조건에 따라 수반응 추진제 끝단의 면적 은 정해지므로 수반응 추진제의 연소속도가 해수흡입  추진기관의 추력을 결정한다.',
#   '따라서 어뢰 체계 요구 조건에 따른 수반응 추진제의 연소속도가 해수흡입 추 진기관의 핵심기술이라 할 수 있다.',
#   '수반응 금속연료 추진제 개발   수반응 금속연료 추진제는 초공동 어뢰의 핵심 구성 품으로서, 금속 기반의 연료과농 고체 추진제가 물과  화학반응을 할 때 생성되는 열과 추력을 이용한다.',
#   'Mg/NaNO3 추진제는 전통적인 조명제 의 조성으로 러시아와 이란을 제외하고 초공동 어뢰에  적용한 사례가 없으며, 금속연료 추진제를 대형으로 제 작하는 관련 기술도 공개되어 있지 않다.',
#   '금 속연료 Mg을 70%까지 사용하면서도 348psia에서  22.4mm/s의 고연소속도를 갖기 때문에 초고속 어뢰 용 금속연료 추진제로 적용 가능할 것으로 판단된다.',
#   '추진제 이송시스템 개발   해수흡입 추진기관의 경우 어뢰의 속도로 인한 유입 되는 유체의 동압을 통하여 유체가 연소기 내부로 분 무되고 이를 바탕으로 추진력을 얻는 것으로 알려져  있다.',
#   '이러한 과정을 통하여 도출된 해수흡입 추진기관  기술이 초공동 형성 및 제어 기술과 통합된다면 향후  요격어뢰 혹은 중어뢰 기술 등으로 발전 가능할 것으로  판단되며 추진기관 기술에 대한 개발 뿐 아니라 운용 개념 및 적용 체계에 대한 연구 개발이 종합적으로 이 루어져야 요소기술이 활용될 수 있는 것으로 판단된다.']}

# %% [markdown]
# # 용어와 매칭 함수

# %%
# !pip install PyMuPDF

# %%
import os
import re
import fitz          # PyMuPDF
import pandas as pd

def extract_text_from_pdf(pdf_path: str) -> str:
    doc = fitz.open(pdf_path)
    full_text = "".join(page.get_text() + "\n" for page in doc)
    doc.close()
    return full_text

def normalize_linebreaks(text: str) -> str:
    text = re.sub(r'(?<!\n)\n(?!\n)', '', text)
    text = re.sub(r'(?<=[\.!?])(?=[^\s])', ' ', text) # ? . ! 뒤에 공백이 없는 경우 의도적으로 붙여주기
    return text

def split_sentences(text: str, min_len: int = 10) -> list[str]:
    text = normalize_linebreaks(text)
    pattern = r'(?<=[\.!?])(?:\s+|\n)|(?<=[다요었습니다요다])\n'
    parts = re.split(pattern, text)
    return [p.strip() for p in parts if len(p.strip()) >= min_len]

def map_terms_to_sentences(terms: list[str], sentences: list[str]) -> dict[str, list[str]]:
    mapped = {}
    for term in terms:
        hits = [s for s in sentences if term in s]
        if hits:
            mapped[term] = list(dict.fromkeys(hits))
    return mapped

def combine_pdfs_to_one_csv(pdf_dir: str,
                            terms: list[str],
                            output_csv: str,
                            min_len: int = 10):
    # 1) pdf 폴더에서 .pdf 파일들 자동 수집
    pdf_files = [
        os.path.join(pdf_dir, fn)
        for fn in os.listdir(pdf_dir)
        if fn.lower().endswith(".pdf")
    ]

    combined_rows = []
    # 2) PDF별 처리
    for pdf_path in pdf_files:
        base = os.path.splitext(os.path.basename(pdf_path))[0]
        raw = extract_text_from_pdf(pdf_path)
        sentences = split_sentences(raw, min_len=min_len)
        mapped = map_terms_to_sentences(terms, sentences)

        for term, examples in mapped.items():
            for ex in examples:
                combined_rows.append({
                    'pdf': base,
                    'term': term,
                    'example': ex
                })
        print(f" • {base}.pdf → {len(mapped)}개 용어 매핑")


    df_all = pd.DataFrame(combined_rows)

    # 3-1) “term + example” 쌍 단위로 중복 제거
    df_all = df_all.drop_duplicates(subset=['term', 'example'])

    df_all = df_all.sort_values(by='term')

    # 4) 용례 개수 확인
    total_examples = len(df_all)
    print(f"\n▶ 총 용례 개수: {total_examples}건\n")

    print("▶ 용어별 용례 개수:")
    print(df_all['term'].value_counts(), "\n")

    print("▶ PDF별 용례 개수:")
    print(df_all['pdf'].value_counts(), "\n")

    # 5) CSV로 저장
    df_all.to_csv(output_csv, index=False, encoding="utf-8-sig")
    print(f"✔ 최종 결과가 '{output_csv}' 에 저장되었습니다.")

# %%
if __name__ == "__main__":
    weapon_df = pd.read_csv(
          '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/무기의세계/무기의세계_불필요한것 제외.csv',
        encoding="utf-8-sig"
    )
    weapon_terms = weapon_df['용어'].tolist()

    pdf_folder =  "/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/"
    output_file ="/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/test.csv"

    combine_pdfs_to_one_csv(pdf_folder, weapon_terms, output_file)
# Out:
#  • 국방과학기술플러스 262호.pdf → 3개 용어 매핑
#  • 261 국방과학기술플러스_최종안.pdf → 5개 용어 매핑
#  • 국방과학기술플러스 vol.260.pdf → 3개 용어 매핑
#  • 259호_국방과학기술플러스.pdf → 9개 용어 매핑
#  • 국방과학기술플러스 Vol.257.pdf → 2개 용어 매핑
#  • 국방과학기술플러스 Vol.256.pdf → 14개 용어 매핑
#  • 국방과학기술플러스 Vol.258.pdf → 8개 용어 매핑
#  • 국방과학기술플러스 Vol.255.pdf → 9개 용어 매핑
#  • 국방기술플러스 251호.pdf → 3개 용어 매핑
#  • 2021_국방과학기술플러스_253호.pdf → 9개 용어 매핑
#  • 2021국방과학기술플러스(254호).pdf → 2개 용어 매핑
#  • 2021국방과학기술플러스252호.pdf → 2개 용어 매핑
#
# ▶ 총 용례 개수: 249건
#
# ▶ 용어별 용례 개수:
# term
# 어뢰            69
# 지뢰            25
# 정찰기           24
# 정찰위성          20
# F-2           13
# 전자전기          12
# 미사일 방어체계      11
# 기뢰             8
# 견인포            7
# 장갑차            7
# 함포             7
# 기총             6
# SM-3           5
# 프레데터           4
# 대륙간탄도미사일       3
# 장사정포           3
# 사드             3
# 상륙돌격장갑차        2
# T-50           2
# C-130 허큘리스     1
# 5세대 전투기        1
# J-20           1
# F-22 랩터        1
# 비살상무기          1
# 독도함            1
# 대포병 레이더        1
# P-3C           1
# 공격기            1
# 공대공 미사일        1
# X-37B          1
# 무인전투기          1
# 랴오닝호           1
# 알레이버크급 구축함     1
# 전익기            1
# 전략 폭격기         1
# 천궁             1
# 화차             1
# Name: count, dtype: int64
#
# ▶ PDF별 용례 개수:
# pdf
# 259호_국방과학기술플러스           57
# 국방과학기술플러스 Vol.256         56
# 국방과학기술플러스 262호           28
# 국방기술플러스 251호                25
# 국방과학기술플러스 Vol.255         21
# 2021_국방과학기술플러스_253호      19
# 국방과학기술플러스 Vol.258         16
# 국방과학기술플러스 vol.260         12
# 261 국방과학기술플러스_최종안     5
# 2021국방과학기술플러스252호         4
# 국방과학기술플러스 Vol.257          4
# 2021국방과학기술플러스(254호)       2
# Name: count, dtype: int64
#
# ✔ 최종 결과가 '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/test.csv' 에 저장되었습니다.

# %% [markdown]
# # 전처리1 : 정확한 용례만 남기기

# %%
import pandas as pd
weapon_ex = pd.read_csv('/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/test.csv')
weapon_ex.head()
# Out:
#                                pdf        term  \
# 0  국방과학기술플러스 Vol.255     5세대 전투기
# 1  국방과학기술플러스 Vol.256  C-130 허큘리스
# 2  국방과학기술플러스 Vol.255         F-2
# 3  국방과학기술플러스 Vol.255         F-2
# 4  국방과학기술플러스 Vol.255         F-2
#
#                                              example
# 0  ■ PL-10 (중국)중국에서 2004년부터 5세대 전투기용으로 개발한  5세대 단...
# 1                       전술수송기의 결정판 C-130 허큘리스, 2017.
# 2  장착기종 으로 F-2, F-15J, F-4EJ에서 운용 중이며, 정밀도 높은 RLG...
# 3  이후 KF-21 체계개발이 확정되고, 국내 항공무장통합 환경이 점차 갖춰짐에 따라 ...
# 4  미국산 최신 전투기에 장착이 가능하며, 한국형전투기 (KF-21) 장착 무장으로 고...

# %%
import re

def filter_examples(terms, examples):
    """
    terms: 용어 리스트 (iterable of str)
    examples: 모든 용례가 담긴 리스트
    반환: { term: [매칭된 용례들], … }
    """
    matched_dict = {}
    for term in terms:
        # term 바로 뒤에 숫자가 오면 매칭에서 제외
        pattern = re.compile(r'(?<!\d)' + re.escape(term) + r'(?!\d)') # 앞 뒤에 숫자가 못오게 막기
        matched_dict[term] = [ex for ex in examples if pattern.search(ex)]
    return matched_dict

# %%
# 1) all_examples 구성
all_examples = []
for row in weapon_ex['example']:
    try:
        all_examples.append(row)
    except:
        continue

# 2) terms 불러오기
terms = weapon_ex['term'].unique().tolist()

# 3) 필터링 수행
filtered_dict = filter_examples(terms, all_examples)

# 4) 중복값 제거
for term, exs in filtered_dict.items():
    # dict.fromkeys 이용해 순서는 유지하되 중복 값은 하나만 남김
    filtered_dict[term] = list(dict.fromkeys(exs))

# %%
# 1) 용례가 있는 용어만 필터링
terms_with_examples = {
    term: exs
    for term, exs in filtered_dict.items()
    if exs  # 리스트가 비어있지 않은 경우만
}
len(terms_with_examples.keys()) # 37개
# Out:
# 37

# %%
# 2) 확인하기
print("용례가 있는 용어와 개수:")
for term, exs in terms_with_examples.items():
    print(f"{term}: {len(exs)}건 -> {exs}")
# Out:
# 용례가 있는 용어와 개수:
# 5세대 전투기: 1건 -> ['■ PL-10 (중국)중국에서 2004년부터 5세대 전투기용으로 개발한  5세대 단거리공대공유도탄이다.']
# C-130 허큘리스: 1건 -> ['전술수송기의 결정판 C-130 허큘리스, 2017.']
# F-2: 1건 -> ['장착기종 으로 F-2, F-15J, F-4EJ에서 운용 중이며, 정밀도 높은 RLG(Ring Laser Gyro) IMU를 탑재하여 LOAL 모드 운용이 가능하다.']
# F-22 랩터: 1건 -> ['최근에는 국방예산에 있어 전세계 지출규모의 약 40%를 차지하는 미국에서 조차도 서울에서 개최한 ‘ADEX 2015’에서 전시 및 시험비행에 참여한 적이 있는 세계 최강의 스텔스 전투기로 평가받는 ‘F-22 랩터(Raptor)’의 과도한 획득 및 운영유지 비용으로 인하여 조기퇴역하고 대체할 차세대전투기를 고려하고 있다고 미공군 참모총장이 최근 개최된 맥앨리스 컨퍼런스에서 언급하였다.']
# J-20: 1건 -> ['중국의 최신전투기인 J-10, J-11, J-20, FC-31 전투기에 장착 예정이며  수출용 버전인 PL-10E도 개발하였다.']
�의 사거리 연장기법초장사정탄 기술동향55초장사정탄 기술동향2차 대전 이후 화포와 탄약이 이루는 무기체계의 사거리 경쟁은 이미 1950년대부터 시작되었는데, 구소련은 1960년대 후반에 130mm 52구경장 M-46 M1954 견인포에서 130mm 고폭탄을 사격하여 27.', '이 결과는 미국이 2차 대전 때 사용하던 M114포와 M107 포탄 조합의 최대사거리가 14km인 점을 고려하면 2배에 달하여, 크게 자극을 받은 미국은 155mm M198 39구경장 견인포와 아울러 M549 (고폭약Comp B), M549A1(고폭약 TNT) 로켓 보조추진탄(RocketAssistance Projectile)을 1970년대 후반까지 개발하였는데, 최대사거리는 30km에 달하였다.', '[그림 10] 레이저 점화장치의 원리[그림 11] 레이저 점화장치(견인포)16) DPLIS : Diode Pumped Laser Ignition System\n\n44 ▒ 국방과학기술플러스 +[그림 12] Laser Ignition System of LW155레이저 점화장치는 부품의 수량도 적고 기구적으로 단순하여 교체와 정비가 용이하고, 뇌관불발과 같은 결함을 완전히 해소할 수 있다.', '1992년 개념에 대한 최초 입증 후, 2005년에는 화포용 레이저 점화장치(DPLIS16))를 개발하였으며, 개발기간동안 기존 자주포와 견인포에 적용하여 약 25,000발의 실 사격을 수행한 바 있다.', '미래 포병이 지향하는 방향에 맞추어 국외의 최근 개발동향을 살펴보면, 각국의 전술환경변화를 고려한 소요에 따라 견인포의 차량탑재형을 개발하는 등의 개량형의 개발이나, 기존의 자주포 기술을 활용한 다양한 목적의 체계를 창출하여 제안하고, 소요를 확대할 수 있는 원격무인 포탑, C-RAM1)용 포탑 등을 연구하고 있다.']
# 공격기: 1건 -> ['Yi Long은 전형적인 무인 공격기로 공대공 미사일, 레이저 유도탄, 대인폭탄, 50kg 소형 유도탄 등을 장착할 수 있다.']
# 공대공 미사일: 1건 -> ['Yi Long은 전형적인 무인 공격기로 공대공 미사일, 레이저 유도탄, 대인폭탄, 50kg 소형 유도탄 등을 장착할 수 있다.']
# 기뢰: 8건 -> ['2008년부터 2년 동안 개념연구 형태로, 노르웨이 FFI와 함께 착저 잠수함 또는 기뢰 탐지를 위한 기술개발 과제를 수행하였다.', '0 kW에너지량-6,000 kWh15,000 kWh6,000 kWh수행임무및임무장비MCM--------ISR○EO/IR------ASW--------정보수집○SAS------장비수송○Mine Laying○-○-○-항해장비FLS○---DVL○---BAS----USBL/ATM○---수상/수중통신거리----탐지소나 성능----탐지소나 제원----특징• 수상감시정찰,기뢰부설• 해저지형 mapping• 모듈형 무인잠수정 • 해저통제 모듈탑재• 모듈형 무인잠수정• 해저지형 탐색 ROV 탑재• 모듈형 무인잠수정• 시추장비 탑재"재구성 가능한 모듈형 수중모함 MUM AUV"무인잠수정의 기본 기능을 보유한 기본 모듈(base module)인 연료/산화제 저장탱크, 항법, 통신 정보처리기를 바탕으로 임무 및 운용목적에 따라 임무 모듈(mission module)을 추가하여 각 임무에 따라 플랫폼 재구성이 가능한 무인잠수정을 그림 8.', 'Orca XLUUV의 주요특징은 전투 임무를 수행할 수 있는 기뢰모듈을 탑재하고 있으며, 수상감시정찰을 위해 마스트에 광학 장비를 탑재한 것을 알 수 있다.', '군사목적으로 전력화 되어 있는 무인잠수정은 측면주사소나(Side Scan Sonar, SSS)를 탑재하여 해저기뢰탐색을 위해 활용되거나, 잠수함의 대잠전 훈련을 위해 소음을 방사/모의 할 수 있는 센서를 탑재하여 활용되고 있다.', '3ASW(Anti-Submarine Warfare)Hold-atRisk4Inspection / IdentifyHLD,ATFP5OceanographySpecialPurposeLittoralAccessLongRange6CN3(Communication / Navigation, and Network Node)\xa0VSW/SOFMobileCN37Payload DeliverySOF, ASW,MCM, TCS8IO(Information Operation)NetworkAttackSubmarineDecoy9TCS(Time Critical Strike)10IPOE(Intelligence Preparation of the Operational Environment)11MIW(MIne Warfare)12EW(Electric Warfare)13ASUW14Payload IntegrationEnvironment, IPOE), 기뢰전(Mine Warfare, MIW), 전자전(Electric Warfare, EW), 대수상함전(Anti-Surface Warfare, ASUW), 적재물 통합운반(Payload integration) 4가지 임무를 추가 하였다.', '무인잠수정 임무2004년 미 해군에서 발표한 UUV Master Plan에서는 무인잠수정의 주요 임무를 정보/감시/정찰, 대기뢰전, 대잠전, 조사/식별, 해양조사, 통신/항해 네트워크, 적재물 운송, 정보작전 그리고 적기신속타격으로 총 9가지로 분류하였다.', '함정의 임무영역을 표현하는 운용성능은 그림 2와 같이 대공전, 대잠전, 대수상전, 기뢰전과 같은 주 임무수행  영역과 이를 가능케 하는 공격능력, 방어능력, 기동, 지속능력 등의 능력요소로 이루어진다.', '이후 미 해군에서는 보잉사의 Echo voyager를 기반 으로한 기뢰부설목적 Orca XLUUV를 개발하여 2022년 4월에 최초로 공개하였고, 이는 그림 7.']
# 기총: 6건 -> ['070 gIIR/TVC/HMCS 연동[그림 7] Python 제원[6]항목크기총(탄도)사거리속도기동기타제원2.', '5세대 단거리공대공유도탄 개발 사례항목크기총(탄도)사거리속도기동기타제원2.', '070 gIIR/TVC/HMCS 연동[그림 5] ASRAAM 제원[4]75세대 단거리공대공유도탄 개발 동향\n\n항목크기총(탄도)사거리속도기동기타제원2.', '항목크기총(탄도)사거리속도기동기타제원3.', '해상시험 임무의 근거 및 사격장 관리국방과학연구소 국방시험연구원 안흥종합시험센터 안전통제실 기술원 이아윤유도무기 해상안전통제 현황과 발전방향                                  해상사격장 안전통제의 중심 안흥센터 안전통제소해  상 (국과연)해상탐지레이더드론열상카메라해상통제시험선 해  상 (해군/관공선/용선)지  상 (국과연)시험통제소해군음성통신망(시험책임자)어업지도선CCTV경비정(해경)용선유도무기총포탄약공  역 (공군)제1 MCRCMCRC(Master Control & Reporting Center), 중앙방공통제소제2 MCRC  유도무기 해상안전통제 현황과 발전방향  \n\n  유도무기 해상안전통제 현황과 발전방향 | 57국가기관에서 수행되는 해상시험은 2년마다 발간되는 합참의 해상사격장 안전운용 지침을 준수하며 수행되어야 한다.', '항목크기총(탄도)사거리속도기동기타제원2.']
구”, Journal of Aerospace System Engineering, pp.', '항공기반 상승단계 탄도미사일 방어체계가 개발되어 기존 중간단계/종말단계 방어에 추가되면 다층방어의 효과를 증대시킬 수 있을 것으로 기대된다.', '반면 탐지센서와 요격미사일을 무인항공기에 통합하여 Sensor-to-Shooter 방식으로 항공기반 탄도미사일 방어체계가 구현되면 탐지부터 요격까지 소요되는 시간을 줄여 대응 능력을 개선할 수 있다.', '[그림 20] 항공기반 상승단계 탄도미사일 방어체계다.', '항공기반 탄도미사일 방어체계 구성에 필요한 무인항공기는 적외선센서와 요격미사일을 장착 가능해야 하며 그림20은 이에 따른 개념도이다.', '항공기반 상승단계 탄도미사일 방어체계 구성항공기반 상승단계 탄도미사일 방어체계는 교전시간 확보를 위해 탐지센서와 요격미사일을 장착한 Sen\xadsor-to-Shooter 방식이 되어야 한다.']
# 비살상무기: 1건 -> ['그리고 드론, 전투 차량, 통신 기지국 등 체계를  직접적으로 파괴하지 않으면서 무력화시킬 수 있는 기술이므로 비살상무기로 분류된다.']
# 사드: 3건 -> ['SM-3, GBI(Ground Based Intercepter)는 중간단계, 천궁-II, 사드(THAAD), 패트리어트(Patriot)는 종말단계 미사일 방어에 해당한다.', '탄소섬유 기반 초고온 내열/내산화 복합소재 기술  \t 1\t개요초고온 내열 복합소재는 위에 대표 그림에서 나타나 있는 것과 같이 사드(THADD)와 유사한 유도탄 방어무기체계(SM-3)에 필수 핵심부품 소재이다.', '무선기기가 폭증함에 따라 전자파에 대한 관심이 높아지고 이에 대한 우려로 인해서 사회적으로 과도한 비용이 발생하고 있으며, 기상청 레이다 논란, 해상관제용 레이다 논란, 사드 논란 등 전자파 영향 여부를 둘러싼 진실 공방으로 사회적 갈등이 확산되고 있다.']
# 상륙돌격장갑차: 2건 -> ['(그림 3 참고)가상모의 시뮬레이터의 경우, 공수강하시뮬레이터, 상륙돌격장갑차 KAAV 시뮬레이터, 합동화력 시뮬레이터, KUH-1 시뮬레이터 등과 같은 다양한 시뮬레이터를 보유하고 있으며 이는 실제 장비와 유사한 환경에서 해당 체계를 운용하는 훈련여건을 제공하며 경제적인 훈련이 가능한 시스템이다(그림 4&5 참고).', '해병대의 경우도 그와 유사하게 공수강하시뮬레이터, 상륙돌격장갑차 KAAV 시뮬레이터, 합동화력 시뮬레이터, KUH-1 시뮬레이터 등과 같은 다양한 시뮬레이터를 보유하고 있으나 이것들은 개별 체계의 숙달 훈련 위주로 활용되고 있다.']
# 알레이버크급 구축함: 1건 -> ['55m, 무게는 50kg, GPS/INS 유도항법 기능을 갖고  있어, CEP 20m의 정확도 사격이 가능한 것으로 알려졌고, 알레이버크급 구축함에서 발사하여 최대 110km 떨어진 지상표적 타격이 가능한 것으로 알려졌다.']
�다 어뢰 개념도 [7][그림 7] 이란이 공개한 후트 어뢰\n\n해수흡입 추진기관 기술 동향 | 35한 연구를 수행한 바 있다[7-9].', '사출모타는 작동 후 어뢰로부터 분리된다.', '러시아서두에 언급한 바와 같이 해수흡입 추진기관을 초공동 어뢰에 적용한 사례는 러시아의 쉬크발이다.', '러시아(구 소련)는 미국의 고속 원자력 잠수함과의 교전과 항공모함을 공격하는 목적으로 초공동 어뢰 개발에 착수하였다.', '1960년대에 쉬크발(Shkval)이라는 명칭으로 개발을 시작하였으며, 약 200노트(370km/h)의 속력으로 바닷속에서 항주가 가능하여 기존 어뢰 대비 4~5배의 빠른 속력으로 알려져있다.', '이란  이란은 2006년 4월 2일과 3일 양일에 걸쳐 자체개발 초공동 어뢰인 후트의 발사시험을 진행하였고 성공적으로 목표물에 타격했다는 영상을 공개하였다.', '러시아의 초공동 어뢰인 쉬크발(Shkval)의 경우 초공동 현상 발생장치와 해수흡입 추진기관을 조합하여 약 200노트의 속도를 내는 것으로 알려져 있다.', '더불어 2004년도에는 새로운 초공동 어뢰개발을 착수하였으나 뚜렷한 프로젝트의 성과는 보여주지 못하고 있다.', '4mm/s의 고연소속도를 갖기 때문에 초고속 어뢰용 금속연료 추진제로 적용 가능할 것으로 판단된다.', '항적추적어뢰 기만을 위한 기포항적 생성기술 연구 | 43 참고문헌  1.', '[그림 1] 기포항적 생성을 이용한 항적추적어뢰 기만 개념\n\n34 | 국방과학기술플러스 +첫째, “기포발생 기술”은 항적추적어뢰 기만 효과를 가지는 미세기포를 대량으로 발생시키 위한 기술로, 기포발생물질의 조성 기술과 제조 방법, 분석 기법, 기포발생특성 조절 등을 연구하는 기술이다.', '셋째, “기포항적 생성 모델링 기술”은 측정된 자료를 모델화하여 항적추적어뢰 기만 효과 분석하기 위한 기술로, 기만 효과에 필요한 구성 모델을 연구하고 통계학적 방법으로 항적추적어뢰에 대한 기만 효과를 분석하는 기술이다.', '본 소개글에서는 항적추적어뢰 항적탐지 기능에 대해 기만 능력을 가지는 기포항적 생성기술 확보를 위해 요구되는 세 가지 핵심기술에 관하여 보다 자세하게 살펴보고자 한다.', '항적추적어뢰의 공격을 효과적으로 방어하기 위해서는 원하는 심도에서 원하는 크기를 가지는 기포를 원하는 시간 내에 발생시켜야 한다.', '[그림 2] 기포발생물질 및 기포 발생 장면의 예\n\n   항적추적어뢰 기만을 위한 기포항적 생성기술 연구 | 35나.', '기포특성 측정 기술제조된 기포발생물질이 항적추적어뢰의 공격을 기만할 수 있는 지의 여부를 판단하기 위해서는 기포발생물질에 의해 생성되는 기포항적의 음향학적 특성과 분포학적 특성을 측정할 필요가 있다.', '본 연구팀에서는 항적추적어뢰의 항적탐지 기능에 대해 기만 능력을 가지는 기포항적을 생성시키기 위하여 필요한 3가지 핵심 기술을 다음과 같이 식별하였다.', '대규모의 기포항적을 대상으로 측정된 음향학적, 분포학적 특성을 측정하고 분석함으로써, 제조된 기포발생물질의 조성이 항적추적어뢰 기만 효과가 있는지를 최종적으로 확인하였다.', '항적추적어뢰 기만 효과를 분석하기 위하여 기포항적의 생성 여부, 생성 개수, 생성된 기포항적의 길이, [그림 4] 기만 효과 분석 프레임 예시나리오 시물레이션실시간 결과 확인결과 저장 및 분석GUI 시뮬레이터기만 효과 분석 시물레이션변수설정•초기 입력변수 설정- 전장환경- 수상함- 수중유도무기- 음향 기만기- 항적 기만기•운동 모델- 직진기동- 회피기동•항적 생성 모델- 기본 항적- 수상함 정보 기반 항적•음향 기만기 모델- 부유식/자항식 기만기•항적 기만기 모델- 항적 기만기 형상/분포- 항적 기만기 산란 강도•음향 탐지 모델- 음원준위- 전달손실(기초모델, 음파전달모델)- 소음준위- 지향지수- 탐지문턱•음향 탐지 운동 모델- 발사단계- 탐색단계- 공격단계- 최종공격단계•항적 탐색 모델- 기본 항적 탐색- 수상함 정보 기반 항적- Pellet 기포 탐색•항적 탐색 운동 모델- 단축탐색 모드- 양측탐색 모드- 중앙탐색 모드- 국내어뢰 탐색 모드- 국외어뢰 탐색 모드수상함수중유도무기\n\n   항적추적어뢰 기만을 위한 기포항적 생성기술 연구 | 37폭, 생성 각도, 살포 밀도, 발생 심도, 발생 시간에 대한 영향을 모두 고려하여야 한다.', '또한 기포항적 기만 시 수상함 회피기동 여부, 음향기만기 사용 여부 및 종류, 개수 등과 어뢰 경보거리, 어뢰 및 수상함 속도, 계절, 해역 등 다양한 변수를 복합적으로 동시에 고려하여야 한다.', '본 연구팀은 이를 몬테카를로 방법(Monte-Carlo  ...
# 장갑차: 7건 -> ['(그림 3 참고)가상모의 시뮬레이터의 경우, 공수강하시뮬레이터, 상륙돌격장갑차 KAAV 시뮬레이터, 합동화력 시뮬레이터, KUH-1 시뮬레이터 등과 같은 다양한 시뮬레이터를 보유하고 있으며 이는 실제 장비와 유사한 환경에서 해당 체계를 운용하는 훈련여건을 제공하며 경제적인 훈련이 가능한 시스템이다(그림 4&5 참고).', '해병대의 경우도 그와 유사하게 공수강하시뮬레이터, 상륙돌격장갑차 KAAV 시뮬레이터, 합동화력 시뮬레이터, KUH-1 시뮬레이터 등과 같은 다양한 시뮬레이터를 보유하고 있으나 이것들은 개별 체계의 숙달 훈련 위주로 활용되고 있다.', 'JSGPM은 \n\n6 | 국방과학기술플러스 +운용요원에 따라 일반 지상 및 선상작전을 수행하는 전투원을 위한 M50과 전차/장갑차 승무원용인 M51 모델이 있다.', '무인포탑 기술은 미래의 유사체계(전차, 장갑차, 자주포, C-RAM)의 자동화 포탑 모듈 개발에 활용 가능한 장점이 있다.', '포탄 적재이송 자동화 기술탄약운반장갑차인 K56과 K10에 적용된 탄압지(Grip) 기술과 포탄 적재이송장치의 기구메커니즘 활용이 가능할 것이다.', '[그림 7] M1299 차세대자주포국내의 경우는 1999년 12월에 K9자주포가 전력화된 후, K10 탄약운반장갑차가 2006년에 개발되었고, K55자주포와 K9자주포 성능개량(PIP11)) 사업으로 K55A1, K9A1이 각각 개발되었다.', '목적은 사거리 증가, 경량화, 정확도 향상, 발사속도 증대이며, 주요연구분야는
향화생무기는 독성의 화생물질과 이들을 투발하기 위한  포탄, 미사일, 지뢰 등의 투발 수단을 총칭한다.', '지뢰탐지 작업 보조 착용 모듈은 지뢰탐지기 (무게: 4kg) 운용 병사의 집중도 향상 및 작업효율 증대를 위해, 지뢰탐지병사 하박에 부착되어 팔 근육 힘을 보조해 줄 수 있도록 무동력 타입으로 현재 개발 중이다.', '개발된 팔 근력보조장치를 착용한 후 지뢰탐지동작을 수행할 경우 이두근의 근활성도가 75% 감소되었다.', '근전도신호를 이용하여 지뢰탐지병사 보조를 위해 제작된 팔 근력보조 모듈 착용 유무에 따른 효과도를 분석하였다.', '[그림 17] 지뢰탐지 근력보조 모듈 효과도 분석을 위한 실험 환경[그림 18] 지뢰탐지 근력보조 모듈 사용 여부에 따른 근전도 신호 결과\n\n임무유형별 군사용 착용로봇 플랫폼 개발동향 ▒ 49이에 대한 결과가 그림 18 및 표 6에 제시된다.', '또한 DMZ 일대 유해발굴 작업을 동시에 진행해야함을 고려하여 현재는 병사에 의해 직접 지뢰탐지/제거 작업이 진행되고 있다.', '물론 개척전차 또는 폭파에 의해 지뢰제거 작업 속도를 증대시킬 수 있지만 이는 환경 파괴를 초래할 수 있다.', '팔 근력보조 모듈 없이 통상적인 지뢰탐지동작을 하는 경우 다른 근육 대비 이두근이 가장 많이 활성화되었다.', 'DMZ 일대에는 약 200만개의 지뢰가 묻혀있을 것이라 추정되며 이를 지뢰탐지병사들이 완전히 제거하기 위해서는 200년 이상 시간이 소요된다고 보고되었다.', '국방과학연구소는 지뢰탐지병사 팔 근력보조를 위하여 그림 15와 같은 무동력 팔 근력보조 모듈을 개발하고 있다.', '현재 우리나라에서는 남북경협 활성화를 준비하기 위하여 DMZ 일대 지뢰탐지/제거 필요성이 대두되고 있다.', '임무유형별 군사용 착용로봇 플랫폼 개발동향 ▒ 47[그림 15] 지뢰탐지 근력보조를 위한 착용형 근력보조모듈 구성 및 형상2) 핵심기술지뢰탐지기 무게보조를 위한 팔 근력보조 모듈은 크게 동작구현부와 중력보상부로 구성된다.', '지뢰탐지 병사는 약 4kg 정도 무게의 지뢰탐지기를 들고 임무를 수행하는데, 고도의 집중력이 요구되는 지뢰탐지 작업동안 팔에 집중되는 지뢰 탐지기 부하는 팔 근육의 피로도 발생을 가속화하여 약 20분 이상 작업을 지속하지 못하게 한다.', '동작구현부는 지뢰탐지병사가 지뢰탐지기를 좌우로 스위핑 (sweeping)하는 동작을 구현한다.', '대신 지뢰탐지기 무게 지지는 등쪽에 위치한 중력보상부에서 담당한다.', '지뢰탐지기 하단 구조물을 볼 조인트 끝단 홀에 삽입하는 간단한 조작으로 지뢰탐지기를 장착할 수 있으며, 볼 조인트 회전 운동에 의해 탐지 작업 시 지뢰탐지기 자세를 미세 조정할 수 있도록 설계하였다.', '모션캡쳐시스템을 이용하여 획득된 지뢰탐지 병사의 운동데이터를 이용하여 그림 16에 제시된 것처럼 중력보상 요구 토크를 분석하였다.', '[그림 16] 지뢰탐지 근력보조 모듈 중력보상 부 파라미터최적설계\n\n48 ▒ 국방과학기술플러스 +3) 성능검증제작된 지뢰탐지병사용 착용형 팔 근력보조장치 모듈의 효과도를 검증하기 위해 1명의 피험자를 모집하여 실험을 진행하였다.', '이를 위해 그림 17에 제시된 것과 같이 지뢰탐지기를 운용하는 팔 주요 근육에 근전도센서를 부착하였다.', '실험은 1) 팔 근력보조 모듈 없이 통상적인 지뢰탐지동작을 하는 경우, 2) 팔 근력보조장치 착용 후 근력보조를 받으며 지뢰탐지동작을 하는 경우, 2가지 경우에 대해서 진행하였다.', '지뢰탐지 근력보조 모듈1) 개요국방과학연구소는 2019년부터 민군기술협력사업을 통해 지뢰탐지 병사의 근력보조를 위한 엑소수트 시스템을 개발하고 있다.']
# 천궁: 1건 -> ['SM-3, GBI(Ground Based Intercepter)는 중간단계, 천궁-II, 사드(THAAD), 패트리어트(Patriot)는 종말단계 미사일 방어에 해당한다.']
# 프레데터: 4건 -> ['[9] 미국 CSIS 보고서는 프레데터 감시정찰 무인기를 이용하여 500km 거리에서 15초 만에 탄도미사일을 탐지 가능함을 인용하고 있다.', '앞서 설명한 기능을 지원할 수 있는 잠재적인 UAV 원격측정 플랫폼은 글로벌 호크, 프레데터, 록히드 마틴의 Structure Blimp 통합 센서 등이 있다.', '프레데터(미국) 복사판으로 알려진 Yi Long 는 2013년 파리 에어쇼에서 처음 공개 되었다.', '중국군 항공 무인 전자전 무기체계국가미국유럽중국드론명글로벌호크프레데터리퍼뉴런BarracudaXiang LongYi LongChiHong-5길이(m)148.']
# 함포: 7건 -> ['한편, 2003년 9월에는 미국 뉴멕시코주 White Sand 시험장에서는 5인치 함포탄인 B-TERM(Ballistic Trajectory Extended Range Munition)으로 100.', '미국의 ATK 社는 해군용 5인치 함포탄인 B-TERM(Ballistic Trajectory Extended Range Munition) 탄을 개발한 바 있는데, 텅스텐 케이스로 제작된 탄두와 저가형 유도항법장치를 채택한 것으로 알려져 있다.', '5인치 MK 45 함포와 155mm AGS(Advance Gun System)에서는 사거리가 각각 41NM, 40NM로 각각 75.', '스웨덴에서는 PzH2000 자주포(독일제)와 해안감시 레이더를 연동하여 해상 이동표적 제압 가능성을 시험하였고, 흑해연안에 전력화 배치된 러시아의 A-222E BEREG-E 해안포의 경우는 130mm 함포를 8×8 트럭에 탑재한 자주포와 사격통제장치 세트(탐지/사격통제 레이더+EOTS7)+사통컴퓨터)를 탑재한 사격지휘차를 연동하여 탐지거리 35km, 유효사거리 20km, 4개 표적 사격제원 계산 및 2개 표적 동시 교전 가능, 발사속도 10발/분의 성능으로 신속하고 효율적인 해안방어 수단으로 개발한 바 있다.', '또한 이 탄은 고정표적은 물론 이동표적에 대해서도 사격이 가능하며, 사격이후 표적변환이 가능하며, 5인치 함포에서는 100km, 155mm 야포에서는 85km의 사거리를 갖는다고 소개하고 있다.', 'Excalibur S를 함포에도 적용 가능한 127mm Excalibur N5를 개발 중이다.', '미국의 155mm AGS(Advanced Gun System) 함포의 경우는 사격통제 장치와 완전 자동화된 탄/장약 이송/장전 장치를 이용하여 빠른 반응성과 높은 생존성을 가지는 무인 포탑을 채택한 사례이다.']
# %%
total_matched = sum(len(v) for v in filtered_dict.values())
print(f"전체 매칭된 용례 개수: {total_matched}건")
# Out:
# 전체 매칭된 용례 개수: 236건

# %% [markdown]
# # 전처리 2 : 무공백 길이가 20이상 제거

# %%
def filter_examples(terms, examples, max_run=20):
    """
    terms: 용어 리스트
    examples: 모든 용례 리스트
    max_len: 이 길이 초과 문장은 제외
    max_run: 이 길이 초과 무공백(스페이스 없는) 구간이 있으면 제외
    반환: { term: [매칭된 용례들], … }
    """
    matched_dict = {}
    for term in terms:
        pattern = re.compile(r'(?<!\d)' + re.escape(term) + r'(?!\d)')
        filtered = []
        for ex in examples:

            #  용어 매칭 & 길이 제한
            if not (pattern.search(ex)) :
                continue

            #  “긴 무공백 구간” 검사:
            #    연속된 한글·영문·숫자 구간을 찾아,
            #    그 길이가 max_run 초과하면 제외
            runs = re.findall(r'[가-힣A-Za-z0-9]+', ex) # 공백을 쪼개서 부분 문자열로 만듦
            if any(len(run) > max_run for run in runs):
                continue

            filtered.append(ex) # 무공백이 20 이하인 용례만 append

        # 4) 순서 유지하며 중복 제거
        matched_dict[term] = list(dict.fromkeys(filtered))

    return matched_dict

# %%
all_examples = []
for row in weapon_ex['example']:
    try:
        all_examples.append(row)
    except:
        continue

# 2) terms 불러오기
terms = weapon_ex['term'].unique().tolist()

# 3) 필터링 수행
filtered_dict = filter_examples(terms, all_examples, max_run=20)

# 4) 중복값 제거
for term, exs in filtered_dict.items():
    # dict.fromkeys 이용해 순서는 유지하되 중복 값은 하나만 남김
    filtered_dict[term] = list(dict.fromkeys(exs))

# %%
have_example_term = [term for term, exs in filtered_dict.items() if exs]
print(have_example_term) # 용례가 있는 용어
num_terms_with_examples = sum(1 for exs in filtered_dict.values() if exs)
num_examples_with_examples = sum(len(exs) for exs in filtered_dict.values() if exs)
print(f"용례가 있는 용어의 개수: {num_terms_with_examples}개") # 37개로 유지
print(f"총 용례의 개수: {num_examples_with_examples}개") # 232개로 감소(236개->232개)
# Out:
# ['5세대 전투기', 'C-130 허큘리스', 'F-2', 'F-22 랩터', 'J-20', 'P-3C', 'SM-3', 'T-50', 'X-37B', '견인포', '공격기', '공대공 미사일', '기뢰', '기총', '대륙간탄도미사일', '대포병 레이더', '독도함', '랴오닝호', '무인전투기', '미사일 방어체계', '비살상무기', '사드', '상륙돌격장갑차', '알레이버크급 구축함', '어뢰', '장갑차', '장사정포', '전략 폭격기', '전익기', '전자전기', '정찰기', '정찰위성', '지뢰', '천궁', '프레데터', '함포', '화차']
# 용례가 있는 용어의 개수: 37개
# 총 용례의 개수: 232개

# %%
# 결과 확인
for term, exs in filtered_dict.items():
    if exs:
        print(f"{term} ({len(exs)}건):")
        for ex in exs:
            print("  -", ex)
        print()
# Out:
# 5세대 전투기 (1건):
#   - ■ PL-10 (중국)중국에서 2004년부터 5세대 전투기용으로 개발한  5세대 단거리공대공유도탄이다.
#
# C-130 허큘리스 (1건):
#   - 전술수송기의 결정판 C-130 허큘리스, 2017.
#
# F-2 (1건):
#   - 장착기종 으로 F-2, F-15J, F-4EJ에서 운용 중이며, 정밀도 높은 RLG(Ring Laser Gyro) IMU를 탑재하여 LOAL 모드 운용이 가능하다.
#
# F-22 랩터 (1건):
#   - 최근에는 국방예산에 있어 전세계 지출규모의 약 40%를 차지하는 미국에서 조차도 서울에서 개최한 ‘ADEX 2015’에서 전시 및 시험비행에 참여한 적이 있는 세계 최강의 스텔스 전투기로 평가받는 ‘F-22 랩터(Raptor)’의 과도한 획득 및 운영유지 비용으로 인하여 조기퇴역하고 대체할 차세대전투기를 고려하고 있다고 미공군 참모총장이 최근 개최된 맥앨리스 컨퍼런스에서 언급하였다.
#
# J-20 (1건):
#   - 중국의 최신전투기인 J-10, J-11, J-20, FC-31 전투기에 장착 예정이며  수출용 버전인 PL-10E도 개발하였다.
#
# P-3C (1건):
#   - 하지만, 이스라엘의 ELTA, IAI, Rafael 사의 장비에 의존하여 RF-16펠콘 유인정찰기, 송골매 무인정찰기, P-3C 성능개량기 등을 운용하였다.
#
# SM-3 (5건):
#   - [표 3] AEGIS 베이스라인별 보유 능력AEGIS B/L탑재 플랫폼주요 능력비  고B/L 5CG 59-65, 67,68,70-73 / DDG 51-78•AAW•MIL-SPEC 적용통합 AAW, 전장상황인식 능력 향상B/L 6CG 66, 69 / DDG79-90•AAW•MIL-SPEC/COTS 적용•Link-16, CEC네트워크 향상B/L 7DDG 91-112• AAW•COTS 적용•Link-16, CEC구역 대공방어 능력 향상B/L 8CG 52-58•B/L 7과 동일B/L 99ACG 59-64•AAW, CEC, NIFC-CA, SM-2, SM-6복합임무 구역 대공방어능력(ACB 12를 통한 AEGIS현대화)9CDDG 51-78•IAMD(BMD+AAW), AAW, CEC, NIFC-CA,    SM-2, SM-6, SM-3 Blk 1A/1B9DDDG 113 AF•B/L 9C와 동일9EAEGIS ASHORE•BMD, SM-3 Blk 1A/1B, Remote Launcher       Mods라.
#   - SM-3, GBI(Ground Based Intercepter)는 중간단계, 천궁-II, 사드(THAAD), 패트리어트(Patriot)는 종말단계 미사일 방어에 해당한다.
#   - 탄소섬유 기반 초고온 내열/내산화 복합소재 기술  	 1	개요초고온 내열 복합소재는 위에 대표 그림에서 나타나 있는 것과 같이 사드(THADD)와 유사한 유도탄 방어무기체계(SM-3)에 필수 핵심부품 소재이다.
#   - 2월에 미 해군도 함정발사용 미사일(RIM-161 SM-3)을 발사하여 고장 상태로 궤도를 돌고 있던 자국의 한 정찰위성(USA-193)을 요격하는 데 성공하였다.
#   - 국방과학연구소 국방첨단과학기술연구원 소재에너지센터선임연구원 이정민온도, 압력, 유량↑ 삭마↑X43-A온도, 압력, 유량↑ 강도↓, 기밀↓능동냉각유로리딩엣지스크램젯온도, 압력, 유량↑ 삭마↑SM-3노즐목위치•자세제어Pue, A.
#
# T-50 (2건):
#   - 최근의 또 다른 사례로는 한국항공우주산업주식회사(KAI)의 T-50 항공기 개발이라 할 수 있다.
#   - T-50 항공기 개발비는 약 2조원이었으며, 그 중 10%인 200억을 종합군수지원(IL그렇기S) 개발 비용으로 사용하였기에 후속군수지원을 지속적으로 가능하게 하면서 아랍에미리트와의 수출협상 시 한국 정부차원의 안정적 후속 군수지원 보장에 대한 요구를 충족하게 되며 큰 호평을 받고 있다.
#
# X-37B (1건):
#   - 러시아
#
# 국방과학기술플러스 +4849미국의 X-37B로 알려진 실험용 우주항공기도 비밀리에 우주에서 장기간 체류하면서 각종 시험을 수행하고 있다.
#
# 견인포 (6건):
#   - 우리나라의 경우 1980년대에 155mm 39구경장 KH179 견인포와 함께 미국의 M549A1 RAP 탄을 1984년도까지 모방 개발한 KM549A1 탄으로 30Km의  사거리를 달성한 바 있고, 1998년에는 155mm 52구경장 K9 자주포와 K307 베이스블리드탄을 개발하면서, 42km를 달성하여 당시 사거리분야에서 무기개발 선진국과의 격차를 뛰어넘은 바 있다.
#   - [그림 1] 포탄의 사거리 연장기법초장사정탄 기술동향55초장사정탄 기술동향2차 대전 이후 화포와 탄약이 이루는 무기체계의 사거리 경쟁은 이미 1950년대부터 시작되었는데, 구소련은 1960년대 후반에 130mm 52구경장 M-46 M1954 견인포에서 130mm 고폭탄을 사격하여 27.
#   - 이 결과는 미국이 2차 대전 때 사용하던 M114포와 M107 포탄 조합의 최대사거리가 14km인 점을 고려하면 2배에 달하여, 크게 자극을 받은 미국은 155mm M198 39구경장 견인포와 아울러 M549 (고폭약Comp B), M549A1(고폭약 TNT) 로켓 보조추진탄(RocketAssistance Projectile)을 1970년대 후반까지 개발하였는데, 최대사거리는 30km에 달하였다.
#   - [그림 10] 레이저 점화장치의 원리[그림 11] 레이저 점화장치(견인포)16) DPLIS : Diode Pumped Laser Ignition System
#
# 44 ▒ 국방과학기술플러스 +[그림 12] Laser Ignition System of LW155레이저 점화장치는 부품의 수량도 적고 기구적으로 단순하여 교체와 정비가 용이하고, 뇌관불발과 같은 결함을 완전히 해소할 수 있다.
#   - 1992년 개념에 대한 최초 입증 후, 2005년에는 화포용 레이저 점화장치(DPLIS16))를 개발하였으며, 개발기간동안 기존 자주포와 견인포에 적용하여 약 25,000발의 실 사격을 수행한 바 있다.
#   - 미래 포병이 지향하는 방향에 맞추어 국외의 최근 개발동향을 살펴보면, 각국의 전술환경변화를 고려한 소요에 따라 견인포의 차량탑재형을 개발하는 등의 개량형의 개발이나, 기존의 자주포 기술을 활용한 다양한 목적의 체계를 창출하여 제안하고, 소요를 확대할 수 있는 원격무인 포탑, C-RAM1)용 포탑 등을 연구하고 있다.
#
# 공격기 (1건):
#   - Yi Long은 전형적인 무인 공격기로 공대공 미사일, 레이저 유도탄, 대인폭탄, 50kg 소형 유도탄 등을 장착할 수 있다.
#
# 공대공 미사일 (1건):
#   - Yi Long은 전형적인 무인 공격기로 공대공 미사일, 레이저 유도탄, 대인폭탄, 50kg 소형 유도탄 등을 장착할 수 있다.
#
# 기뢰 (7건):
#   - 2008년부터 2년 동안 개념연구 형태로, 노르웨이 FFI와 함께 착저 잠수함 또는 기뢰 탐지를 위한 기술개발 과제를 수행하였다.
#   - 0 kW에너지량-6,000 kWh15,000 kWh6,000 kWh수행임무및임무장비MCM--------ISR○EO/IR------ASW--------정보수집○SAS------장비수송○Mine Laying○-○-○-항해장비FLS○---DVL○---BAS----USBL/ATM○---수상/수중통신거리----탐지소나 성능----탐지소나 제원----특징• 수상감시정찰,기뢰부설• 해저지형 mapping• 모듈형 무인잠수정 • 해저통제 모듈탑재• 모듈형 무인잠수정• 해저지형 탐색 ROV 탑재• 모듈형 무인잠수정• 시추장비 탑재"재구성 가능한 모듈형 수중모함 MUM AUV"무인잠수정의 기본 기능을 보유한 기본 모듈(base module)인 연료/산화제 저장탱크, 항법, 통신 정보처리기를 바탕으로 임무 및 운용목적에 따라 임무 모듈(mission module)을 추가하여 각 임무에 따라 플랫폼 재구성이 가능한 무인잠수정을 그림 8.
#   - Orca XLUUV의 주요특징은 전투 임무를 수행할 수 있는 기뢰모듈을 탑재하고 있으며, 수상감시정찰을 위해 마스트에 광학 장비를 탑재한 것을 알 수 있다.
#   - 군사목적으로 전력화 되어 있는 무인잠수정은 측면주사소나(Side Scan Sonar, SSS)를 탑재하여 해저기뢰탐색을 위해 활용되거나, 잠수함의 대잠전 훈련을 위해 소음을 방사/모의 할 수 있는 센서를 탑재하여 활용되고 있다.
#   - 무인잠수정 임무2004년 미 해군에서 발표한 UUV Master Plan에서는 무인잠수정의 주요 임무를 정보/감시/정찰, 대기뢰전, 대잠전, 조사/식별, 해양조사, 통신/항해 네트워크, 적재물 운송, 정보작전 그리고 적기신속타격으로 총 9가지로 분류하였다.
#   - 함정의 임무영역을 표현하는 운용성능은 그림 2와 같이 대공전, 대잠전, 대수상전, 기뢰전과 같은 주 임무수행  영역과 이를 가능케 하는 공격능력, 방어능력, 기동, 지속능력 등의 능력요소로 이루어진다.
#   - 이후 미 해군에서는 보잉사의 Echo voyager를 기반 으로한 기뢰부설목적 Orca XLUUV를 개발하여 2022년 4월에 최초로 공개하였고, 이는 그림 7.
#
# 기총 (5건):
#   - 070 gIIR/TVC/HMCS 연동[그림 7] Python 제원[6]항목크기총(탄도)사거리속도기동기타제원2.
#   - 5세대 단거리공대공유도탄 개발 사례항목크기총(탄도)사거리속도기동기타제원2.
#   - 070 gIIR/TVC/HMCS 연동[그림 5] ASRAAM 제원[4]75세대 단거리공대공유도탄 개발 동향
#
# 항목크기총(탄도)사거리속도기동기타제원2.
#   - 항목크기총(탄도)사거리속도기동기타제원3.
#   - 항목크기총(탄도)사거리속도기동기타제원2.
#
# 대륙간탄도미사일 (3건):
#   - [그림 5] MiG-31BM에 탑재된 킨잘[9][그림 6] 지르콘[10]29
#
# DF-ZF는 또한, DF-21 중거리 미사일과 DF-31 대륙간탄도미사일 등 중국의 다양한 탄도미사일에 장착이 가능하며, 2014년부터 개발되어 2017년 11월까지 최소 9차례 비행시험이 이루어진 것으로 알려져 있다.
#   - 이 기술은 대륙간탄도미사일(ICBM) 개발도 가능한 수준인 것으로 평가된다.
#   - 아방가르드는 러시아의 대륙간탄도미사일 탑재 극초 음속 활공체로, 최고속도 마하 27로 활공하며 별도의 추진기관이 없는 순수한 활공체이다.
#
# 대포병 레이더 (1건):
#   - 육군의 ISTAR3) 능력 보강, 대포병 레이더 보강, MET4)(기상) 장비 보강, 정밀타격능력 보강, C4I5) 능력 보강, 플랫폼 개선 등을 제시하고 있다.
#
# 독도함 (1건):
#   - 기본형은 현재 해군 상륙함인 독도함에 탑재되어 운용되고  있으며 성능개량형은 레이더 성능을 업그레이드하여  지상용 (SMART-L MM/F) 및 함정용 (SMART-L MM/N)  다중임무 디지털레이더로 개발되었다.
#
# 랴오닝호 (1건):
#   - 중국은 항공모함 랴오닝호에 리젠을  탑재해 미국령 괌 인근까지 감시 정찰에 나설 것으로  예상되고 있다.
#
# 무인전투기 (1건):
#   - 'GJ(攻擊·공지)-11' 스텔스 드론은 미국의 B-2  스피릿 폭격기, 항공모함 베이스의 장거리 무인전투기 X-47B와 비교되고 있다.
#
# 미사일 방어체계 (10건):
#   - 항공기반 방어의 장점  상승단계 탄도미사일 방어를 위해 항공기에 적외선센서와 요격미사일을 장착하여 Sensor-to-Shooter 방식의 미사일 방어체계를 구성하면 상승단계 탄도미사일 방어에 여러 가지 장점이 있다.
#   - 즉, 정지 궤도상의 위성체에 조기경보 IR 탐지장비를 탑재하여, 초기 탄도탄  발사 화염을 탐지하여 식별하고, 지상 조기경보 체계 및  조기경보 레이더에 식별된 정보를 제공하여 신속히 경보  발령을 내리게 하고, 지상 대미사일 방어체계의 신속한 대응 타격을 가능케하며, 나아가서는 탄도탄 발사점 및 탄착점을 예측하는 기능을 갖는다.
#   - 낮은 고도에서의 극초음속 비행은 극초음속 순항미사일이 미사일 방어체계를 침투할 수 있도록 하며, 극초음속 활공체와 달리 종말 단계까지 가속할 수 있어 복잡한 기동에 더욱 유리하다.
#   - 항공기반 상승단계 탄도미사일 방어체계는 북한과 같이 폭이 좁고 긴 지리적 특성이 있는 지역 가까이 접근하여 요격이 이루어지므로 탄도미사일 방어에 효과적인 것으로 이 연구는 결론 내고 있다.
#   - 이경행 외, “해상기반 탄도미사일 방어체계의 임무효과에 관한 연구”, Journal of Aerospace System Engineering, pp.
#   - 항공기반 상승단계 탄도미사일 방어체계가 개발되어 기존 중간단계/종말단계 방어에 추가되면 다층방어의 효과를 증대시킬 수 있을 것으로 기대된다.
#   - 반면 탐지센서와 요격미사일을 무인항공기에 통합하여 Sensor-to-Shooter 방식으로 항공기반 탄도미사일 방어체계가 구현되면 탐지부터 요격까지 소요되는 시간을 줄여 대응 능력을 개선할 수 있다.
#   - [그림 20] 항공기반 상승단계 탄도미사일 방어체계다.
#   - 항공기반 탄도미사일 방어체계 구성에 필요한 무인항공기는 적외선센서와 요격미사일을 장착 가능해야 하며 그림20은 이에 따른 개념도이다.
#   - 항공기반 상승단계 탄도미사일 방어체계 구성항공기반 상승단계 탄도미사일 방어체계는 교전시간 확보를 위해 탐지센서와 요격미사일을 장착한 Sen­sor-to-Shooter 방식이 되어야 한다.
#
# 비살상무기 (1건):
#   - 그리고 드론, 전투 차량, 통신 기지국 등 체계를  직접적으로 파괴하지 않으면서 무력화시킬 수 있는 기술이므로 비살상무기로 분류된다.
#
# 사드 (3건):
#   - SM-3, GBI(Ground Based Intercepter)는 중간단계, 천궁-II, 사드(THAAD), 패트리어트(Patriot)는 종말단계 미사일 방어에 해당한다.
#   - 탄소섬유 기반 초고온 내열/내산화 복합소재 기술  	 1	개요초고온 내열 복합소재는 위에 대표 그림에서 나타나 있는 것과 같이 사드(THADD)와 유사한 유도탄 방어무기체계(SM-3)에 필수 핵심부품 소재이다.
#   - 무선기기가 폭증함에 따라 전자파에 대한 관심이 높아지고 이에 대한 우려로 인해서 사회적으로 과도한 비용이 발생하고 있으며, 기상청 레이다 논란, 해상관제용 레이다 논란, 사드 논란 등 전자파 영향 여부를 둘러싼 진실 공방으로 사회적 갈등이 확산되고 있다.
#
# 상륙돌격장갑차 (2건):
#   - (그림 3 참고)가상모의 시뮬레이터의 경우, 공수강하시뮬레이터, 상륙돌격장갑차 KAAV 시뮬레이터, 합동화력 시뮬레이터, KUH-1 시뮬레이터 등과 같은 다양한 시뮬레이터를 보유하고 있으며 이는 실제 장비와 유사한 환경에서 해당 체계를 운용하는 훈련여건을 제공하며 경제적인 훈련이 가능한 시스템이다(그림 4&5 참고).
#   - 해병대의 경우도 그와 유사하게 공수강하시뮬레이터, 상륙돌격장갑차 KAAV 시뮬레이터, 합동화력 시뮬레이터, KUH-1 시뮬레이터 등과 같은 다양한 시뮬레이터를 보유하고 있으나 이것들은 개별 체계의 숙달 훈련 위주로 활용되고 있다.
#
# 알레이버크급 구축함 (1건):
#   - 55m, 무게는 50kg, GPS/INS 유도항법 기능을 갖고  있어, CEP 20m의 정확도 사격이 가능한 것으로 알려졌고, 알레이버크급 구축함에서 발사하여 최대 110km 떨어진 지상표적 타격이 가능한 것으로 알려졌다.
#
# 어뢰 (69건):
#   - [그림 19] 교육훈련 패러다임 변화해군 병기탄약창에서는 전력화예정인 무기체계인 중어뢰-II(범상어)에 대한 정비요원들의 정비능력 사전 확보를 위한 교육훈련 필요성에 따라 가상정비교육훈련지원장비(VmTSE, Virtual maintenance Training Support Equipment) 확보방안을 2018년도에 수립하였으며, 2019년에 국방기술의 민수기술이전을 통하여 국과연 보유기술을 제작사인 (주)IVRSYSTEMS에서 기술 확보 후 VmTSE 구축 사업을 착수하였다.
#   - 국방과학연구소(해양기술연구원)에서는 이 QUEST 프레임워크를 이용하여 국과연 주관 연구개발 체계인 함정전투체계, 어뢰체계, 음탐기체계 등의 개발 과정에서 어뢰전/대어뢰전/대잠전 모델을 개발하고 효과도분석, 전술 개발 등에 적용하고 있다.
#   - 이때 만재 배수량 = 베이스 중량 + 조합에 참여하는 구성요소 중량 + 기타 중량 (유형1의 예제에서는 경어뢰와 중어뢰 관련 시스템과 무장의 중량)이다.
#   - 이 예제에서는 운용개념 분석을 통해 임무수행 영역을 대잠전, 대어뢰전, 대함전, 대공전으로 분류하고  각각의 수행영역에 8, 8, 5, 6개의 탑재체계 대안을 상정한다.
#   - 또한 함정내 탑재장비, 유도무기, 어뢰와 같은 실물장비를 자주 접하지 못하는 고가의 장비일수록 더욱 교육훈련이 중요하기에 대체재로서 가상교육훈련장비의 구축 및 운용이 필요하다.
#   - 해당 순항 속도에서는 초공동 어뢰의 운동으로 인해 초공동 어뢰 입구에서 약 50bar에 이르는 고압으로 해수를 흡입하게 되며, 흡입된 해수는 해수흡입 연소기의 인젝터와 수반응 추진제 이송을 위한 피스톤으로 공급된다.
#   - 이러한 문제를 보완하기 위하여 그림 1과 같이 중요한 시설 보호를 위하여 고정식 발사 플랫폼을 활용하거나 수상함에서 발사하는 개념이 제안되고 있으며, 이란의 초공동 어뢰인 후트(Hoot)의 경우 수상함에서 시험 발사하는 장면을 확인할 수 있다.
#   - 하지만 이러한 초공동 어뢰의 경우 소음이 크고, 상대적으로 사거리가 짧으며 유도기능이 제한적이라는 단점이 존재한다.
#   - Mg/NaNO3 추진제는 전통적인 조명제의 조성으로 러시아와 이란을 제외하고 초공동 어뢰에 적용한 사례가 없으며, 금속연료 추진제를 대형으로 제작하는 관련 기술도 공개되어 있지 않다.
#   - 개발기관인 DIEHL BGT Defence에 의하면 바라쿠다는 수중 및 수상의 타켓뿐만이 아니라 러시아에서 운용하고 있는 쉬크발 어뢰를 직접적으로 요격이 가능하다고 공개하였다.
#   - 독일  1988년 독일은 초공동화연구를 시작하여 최근까지 최대속력 400km/h 이상을 만족하는 바라쿠다(Barracuda) 어뢰를 개발중에 있다.
#   - 순항 심도에 도달한 초공동 어뢰는 시동부스터를 점화하여 순항 속도인 100m/s까지 가속한다.
#   - 해수흡입 추진기관 기술 동향[그림 1] 초공동-해수흡입 추진기관 적용 어뢰 (A) 운용개념 (B) 이란 후트(Hoot) 발사 장면
#
# 32 | 국방과학기술플러스 +기체계이다.
#   - 초공동 어뢰는 발사관에서 발사된 후, 사출모타를 통해 초기 가속되며 순항 심도까지 이동한다.
#   - 전기모터 혹은 내연기관 방식의 어뢰가 50노트 수준임을 고려하면 표적이 회피하거나 반응할 시간을 제한하는 개념의 무수중 유도무기 패러다임의 변화 해수흡입 추진기관!
#   - 중국 National university of defense technology, China에서는 수반응 추진제 및 연소특성에 대한 다양[그림 6] 독일의 바라쿠다 어뢰 개념도 [7][그림 7] 이란이 공개한 후트 어뢰
#
# 해수흡입 추진기관 기술 동향 | 35한 연구를 수행한 바 있다[7-9].
#   - 사출모타는 작동 후 어뢰로부터 분리된다.
#   - 러시아서두에 언급한 바와 같이 해수흡입 추진기관을 초공동 어뢰에 적용한 사례는 러시아의 쉬크발이다.
#   - 러시아(구 소련)는 미국의 고속 원자력 잠수함과의 교전과 항공모함을 공격하는 목적으로 초공동 어뢰 개발에 착수하였다.
#   - 1960년대에 쉬크발(Shkval)이라는 명칭으로 개발을 시작하였으며, 약 200노트(370km/h)의 속력으로 바닷속에서 항주가 가능하여 기존 어뢰 대비 4~5배의 빠른 속력으로 알려져있다.
#   - 이란  이란은 2006년 4월 2일과 3일 양일에 걸쳐 자체개발 초공동 어뢰인 후트의 발사시험을 진행하였고 성공적으로 목표물에 타격했다는 영상을 공개하였다.
#   - 러시아의 초공동 어뢰인 쉬크발(Shkval)의 경우 초공동 현상 발생장치와 해수흡입 추진기관을 조합하여 약 200노트의 속도를 내는 것으로 알려져 있다.
#   - 더불어 2004년도에는 새로운 초공동 어뢰개발을 착수하였으나 뚜렷한 프로젝트의 성과는 보여주지 못하고 있다.
#   - 4mm/s의 고연소속도를 갖기 때문에 초고속 어뢰용 금속연료 추진제로 적용 가능할 것으로 판단된다.
#   - 항적추적어뢰 기만을 위한 기포항적 생성기술 연구 | 43 참고문헌  1.
#   - [그림 1] 기포항적 생성을 이용한 항적추적어뢰 기만 개념
#
# 34 | 국방과학기술플러스 +첫째, “기포발생 기술”은 항적추적어뢰 기만 효과를 가지는 미세기포를 대량으로 발생시키 위한 기술로, 기포발생물질의 조성 기술과 제조 방법, 분석 기법, 기포발생특성 조절 등을 연구하는 기술이다.
#   - 셋째, “기포항적 생성 모델링 기술”은 측정된 자료를 모델화하여 항적추적어뢰 기만 효과 분석하기 위한 기술로, 기만 효과에 필요한 구성 모델을 연구하고 통계학적 방법으로 항적추적어뢰에 대한 기만 효과를 분석하는 기술이다.
#   - 본 소개글에서는 항적추적어뢰 항적탐지 기능에 대해 기만 능력을 가지는 기포항적 생성기술 확보를 위해 요구되는 세 가지 핵심기술에 관하여 보다 자세하게 살펴보고자 한다.
#   - 항적추적어뢰의 공격을 효과적으로 방어하기 위해서는 원하는 심도에서 원하는 크기를 가지는 기포를 원하는 시간 내에 발생시켜야 한다.
#   - [그림 2] 기포발생물질 및 기포 발생 장면의 예
#
#    항적추적어뢰 기만을 위한 기포항적 생성기술 연구 | 35나.
#   - 기포특성 측정 기술제조된 기포발생물질이 항적추적어뢰의 공격을 기만할 수 있는 지의 여부를 판단하기 위해서는 기포발생물질에 의해 생성되는 기포항적의 음향학적 특성과 분포학적 특성을 측정할 필요가 있다.
#   - 본 연구팀에서는 항적추적어뢰의 항적탐지 기능에 대해 기만 능력을 가지는 기포항적을 생성시키기 위하여 필요한 3가지 핵심 기술을 다음과 같이 식별하였다.
#   - 대규모의 기포항적을 대상으로 측정된 음향학적, 분포학적 특성을 측정하고 분석함으로써, 제조된 기포발생물질의 조성이 항적추적어뢰 기만 효과가 있는지를 최종적으로 확인하였다.
#   - 항적추적어뢰 기만 효과를 분석하기 위하여 기포항적의 생성 여부, 생성 개수, 생성된 기포항적의 길이, [그림 4] 기만 효과 분석 프레임 예시나리오 시물레이션실시간 결과 확인결과 저장 및 분석GUI 시뮬레이터기만 효과 분석 시물레이션변수설정•초기 입력변수 설정- 전장환경- 수상함- 수중유도무기- 음향 기만기- 항적 기만기•운동 모델- 직진기동- 회피기동•항적 생성 모델- 기본 항적- 수상함 정보 기반 항적•음향 기만기 모델- 부유식/자항식 기만기•항적 기만기 모델- 항적 기만기 형상/분포- 항적 기만기 산란 강도•음향 탐지 모델- 음원준위- 전달손실(기초모델, 음파전달모델)- 소음준위- 지향지수- 탐지문턱•음향 탐지 운동 모델- 발사단계- 탐색단계- 공격단계- 최종공격단계•항적 탐색 모델- 기본 항적 탐색- 수상함 정보 기반 항적- Pellet 기포 탐색•항적 탐색 운동 모델- 단축탐색 모드- 양측탐색 모드- 중앙탐색 모드- 국내어뢰 탐색 모드- 국외어뢰 탐색 모드수상함수중유도무기
#
#    항적추적어뢰 기만을 위한 기포항적 생성기술 연구 | 37폭, 생성 각도, 살포 밀도, 발생 심도, 발생 시간에 대한 영향을 모두 고려하여야 한다.
#   - 또한 기포항적 기만 시 수상함 회피기동 여부, 음향기만기 사용 여부 및 종류, 개수 등과 어뢰 경보거리, 어뢰 및 수상함 속도, 계절, 해역 등 다양한 변수를 복합적으로 동시에 고려하여야 한다.
#   - 본 연구팀은 이를 몬테카를로 방법(Monte-Carlo method)을 통해 항적추적어뢰 공격에 대한 기만 효과를 통계학적으로 분석하였다.
#   - [그림 7] 기포항적 산란강도 도출 결과 예제 기포발생물질 조성, 밀도, 무게, 형상 등 조건에 따른 측정실험을 반복적으로 수행하여, 기포발생물질에 의해 발생되는 기포항적의 산란강도 프로파일 단면을 데이터베이스화하였으며, 최종적으로 항적추적어뢰 탐지기능을 기만하기 위한 효과도 분석 구성모델로 활용하였다.
#   - 음향 신호를 획득하기 위하여 송수신센서가 설치된 측
#
#    항적추적어뢰 기만을 위한 기포항적 생성기술 연구 | 39정부이를 측정 대상이 되는 기포항적을 중심으로 일정거리 이격시켜 위치시켰다.
#   - [그림 10] 기포의 분포 영상화 결과 예제  5  기포항적에 의한 기만 효과 분석 연구제조된 기포발생물질에 의해 발생되는 기포항적의 물리적, 음향적 및 분포적 특성은 수조실험, 호수실험, 해상실험 등 단계적인 검증 실험을 통해 신뢰도 있는 자료를 확보하였으며, 확보된 자료는 최종적으로 항적추적어뢰 공격을 기만하기 위한 효과 분석 모델에 적용하였다.
#   - 본 연구팀은 기포층에 의한 음파 산란, 음파 흡수, 감쇠 및 음속변화 등 기포층의 음향 성능변화에 집중하여 음향탐지 모델 개발에 주력하였으며, 어뢰체계 탐지/로직 등 유사과제 개발 경험을 바탕으로 실제 전장환경에 근사한 기만 효과 구성 모델을 성공적으로 구축하였다.
#   - 따라서, 우리는 대량의 기포항적을 빠르게 생성시킬 수 있을 뿐만 아니라, 항적추적어뢰 기만에 효과적인 크기를 가지는 기포를 발생시키고, 기포의 발생 심도, 생존 시간 등을 제어할 수 있도록 화학물질을 이용하여 기포항적을 생성시키는 방법을 연구하였다.
#   - 3  기술개발에 필요한 핵심기술수상함에서 항적추적어뢰의 공격이 식별되면 어뢰의 추적을 방해하기 위하여 매우 짧은 시간에 충분한 양의 기포항적을 생성시켜야 한다.
#   - 한국 해군이 항적추적어뢰의 위협으로부터 한시라도 빠르게 벗어나기 위해서는 후속 연구수행이 시급히 요구되는 상황이다.
#   - 추진제 이송시스템 개발  해수흡입 추진기관의 경우 어뢰의 속도로 인한 유입되는 유체의 동압을 통하여 유체가 연소기 내부로 분무되고 이를 바탕으로 추진력을 얻는 것으로 알려져 있다.
#   - 이러한 과정을 통하여 도출된 해수흡입 추진기관 기술이 초공동 형성 및 제어 기술과 통합된다면 향후 요격어뢰 혹은 중어뢰 기술 등으로 발전 가능할 것으로 판단되며 추진기관 기술에 대한 개발 뿐 아니라 운용개념 및 적용 체계에 대한 연구 개발이 종합적으로 이루어져야 요소기술이 활용될 수 있는 것으로 판단된다.
#   - 수반응 금속연료 추진제 개발  수반응 금속연료 추진제는 초공동 어뢰의 핵심 구성품으로서, 금속 기반의 연료과농 고체 추진제가 물과 화학반응을 할 때 생성되는 열과 추력을 이용한다.
#   - 따라서 어뢰 체계 요구조건에 따른 수반응 추진제의 연소속도가 해수흡입 추진기관의 핵심기술이라 할 수 있다.
#   - 어뢰 체계의 형상 제한 조건에 따라 수반응 추진제 끝단의 면적은 정해지므로 수반응 추진제의 연소속도가 해수흡입 추진기관의 추력을 결정한다.
#   - 시동부스터는 어뢰를 순항 속도까지 가속시키는 역할과 함께 수반응 추진제를 점화시키는 역할도 동시에 수행하며, 시동부스터의 작동 중단에 따라 연소실로 유입된 해수는 수반응 추진제 연소가스와 반응하여 추력을 발생시키게 된다.
#   - 결론3항적추적어뢰 기만을 위한 기포항적 생성기술 연구해양기술연구원 : 선임연구원 배호석321.
#   - 출처
#
# 32 | 국방과학기술플러스 +  항적추적어뢰 기만을 위한 기포항적 생성기술 연구   1  개요 수상함이 기동하면 선체와 유체간의 마찰, 프로펠러의 회전 등으로 항적이 필연적으로 발생된다.
#   - 최근 어뢰는 음향추적 기능과 함께 항적추적 기능을 추가하여 운용한다.
#   - 항적추적어뢰는 항적탐지 기능을 이용하여 수상함 항적을 추적하여 공격하는 어뢰로, 항적이 존재하는 수상함에게는 매우 치명적인 위협을 가하는 수중 유도무기이다.
#   - 항적추적어뢰는 현재 존재하는 기만기 주파수 보다 높은 고주파의 항적탐지기를 이용하여 근접거리의 항적을 탐지하며 추적하기 때문에 현재 개발되어 있는 부유식/자항식 기만기로는 대응이 불가한 것이 현실이다.
#   - 항적추적어뢰의 위협으로부터 수상함을 안전하게 보호하기 위해서는 항적추적어뢰를 기만할 수 있는 방항적추적어뢰 기만을 위한 기포항적 생성기술 연구          “항적추적어뢰의 위협으로부터 수상함을 보호하기 위한 기포항적 생성기술”국방과학연구소 해양기술연구원선임연구원 배호석
#
#    항적추적어뢰 기만을 위한 기포항적 생성기술 연구 | 33법이 새롭게 요구된다.
#   - 본지에서는 항적추적어뢰를 기만할 수 있는 방법 중 하나로, 그림 1과 같이 인공적인 기포항적을 수상함 항적 인근에 생성시켜 항적추적어뢰의 추적을 방해하는 방법을 소개한다.
#   - 2  기술현황선진국의 어뢰방어체계 기술은 함정의 생존과 직결되는 매우 중요한 기술로써 구체적인 정보의 접근이 제한된다.
#   - 이어 국방과학연구소 해양기술연구원에서는 미사일연구원과 함께 2019년부터 2022년까지 선행핵심 과제를 통해 기포발생물질에 의한 기포발생 기술, 기포특성 측정 기술, 그리고 기포항적에 대한 항적추적어뢰 기만 효과를 분석하는 기포항적 모델링 기술 등 기포항적 생성을 위한 핵심기술을 확보하였다.
#   - 그림 11은 항적추적어뢰가 특정 방위각에서 수상함을 공격하는 특정 시나리오를 가정하였을 때, 기포항적에 의한 기만 효과를 분석한 예제를 보여준다.
#   - 항적추적어뢰가 공격하는 것을 수상함에서 식별하게 되면, 수상함은 회피 기동 및 음향 기만기를 투하하는 등 어뢰공격에 적극 대응하는데, 기포항적을 이용한 기만 대응을 수행함에 따른 아군 수상함 생존률의 변화 정도를 시나리오 조건에 따라 분석하였다.
#   - 항적추적어뢰 기만 효과를 분석하기 위해서는 기포발생물질과 기포항적 모델 외에도 매우 많은 구성모델이 필요하다.
#   - 기포발생물질에 의해 생성된 기포항적은 실해역 실험을 통해 항적추적어뢰 기만에 필요한 충분한 산란강도를 가지는 것을 확인하였으며, 기포 분포에 대한 3차원 영상화를 통해 기포항적 발달 전주기를 가독성있게 관찰할 수 있었다.
#   - 그림 12는 특정 조건에서의 어뢰대응 상황에 따른 기만 효과를 보여주는 일례이다.
#   - 몬테카를로 방법이란 난수에 따라 결정되는 함수의 값을 확률적으로 계산하는 알고리즘으로, 계산하려는 값이 닫힌 형식으로 표현되지 않거나 복잡한 경우 근사적으로 계산할
#
#    항적추적어뢰 기만을 위한 기포항적 생성기술 연구 | 41때 사용된다.
#   - [그림 12] 어뢰 대응상황에 따른 기만 효과 분석 예제 본 연구를 통해 구축된 기만 효과도 모델은 다양한 시나리오 환경에서 기만 효과도를 예측할 수 있기 때문에 시험개발 또는 체계개발 시 체계사양 도출을 위한 도구로 활용 가치가 클 것으로 기대된다.
#   - [그림 11] 시나리오 기반 항적추적어뢰 기만 효과 예제
#
# 42 | 국방과학기술플러스 + 6  맺음말우리는 항적추적어뢰의 위협으로부터 한국 해군 함정의 생존력 증대를 위해, 항적추적어뢰를 기만할 수 있는 방법 중 인공적인 기포항적을 수상함 항적 인근에 생성시켜 항적추적어뢰의 추적을 방해하는 방법을 소개하였다.
#   - 수상함의 경우 운동모델 및 어뢰 경보거리를 초기변수로 적용하였고, 수중 유도무기는 탐색방식, 운동모델, 초기발사조건 등을 초기변수로 적용하였다.
#   - 수상함과 수중 유도무기, 기만기에 대한 시나리오 조건을 설정하고, 해양환경에 따라 임의적으로 달라질 수 있는 조건을 확률적 변수로 적용하여 항적추적어뢰 공격에 대한 기만 성공률을 반복적으로 도출하였다.
#   - 본 연구를 통해 확보한 핵심기술은 후속 개발될 항적추적어뢰 기만기체계 개발에 적극 활용되어, 한국 해군 수상함의 생존력 증대에 기여할 수 있기를 기대한다.
#
# 장갑차 (7건):
#   - (그림 3 참고)가상모의 시뮬레이터의 경우, 공수강하시뮬레이터, 상륙돌격장갑차 KAAV 시뮬레이터, 합동화력 시뮬레이터, KUH-1 시뮬레이터 등과 같은 다양한 시뮬레이터를 보유하고 있으며 이는 실제 장비와 유사한 환경에서 해당 체계를 운용하는 훈련여건을 제공하며 경제적인 훈련이 가능한 시스템이다(그림 4&5 참고).
#   - 해병대의 경우도 그와 유사하게 공수강하시뮬레이터, 상륙돌격장갑차 KAAV 시뮬레이터, 합동화력 시뮬레이터, KUH-1 시뮬레이터 등과 같은 다양한 시뮬레이터를 보유하고 있으나 이것들은 개별 체계의 숙달 훈련 위주로 활용되고 있다.
#   - JSGPM은
#
# 6 | 국방과학기술플러스 +운용요원에 따라 일반 지상 및 선상작전을 수행하는 전투원을 위한 M50과 전차/장갑차 승무원용인 M51 모델이 있다.
#   - 무인포탑 기술은 미래의 유사체계(전차, 장갑차, 자주포, C-RAM)의 자동화 포탑 모듈 개발에 활용 가능한 장점이 있다.
#   - 포탄 적재이송 자동화 기술탄약운반장갑차인 K56과 K10에 적용된 탄압지(Grip) 기술과 포탄 적재이송장치의 기구메커니즘 활용이 가능할 것이다.
#   - [그림 7] M1299 차세대자주포국내의 경우는 1999년 12월에 K9자주포가 전력화된 후, K10 탄약운반장갑차가 2006년에 개발되었고, K55자주포와 K9자주포 성능개량(PIP11)) 사업으로 K55A1, K9A1이 각각 개발되었다.
#   - 목적은 사거리 증가, 경량화, 정확도 향상, 발사속도 증대이며, 주요연구분야는 무장 경량화와 크기 축소를 위한 소재 개발, 탄약 취급의 자동화를 통한 발사속도 향상과 탄약 재보급 및 관리 능력의 향상, 추진제 개선을 통한 포구초속 증가, 마모 감소, 압력 감소 및 둔감화 성능 확보, 탄약(탄체, 회전탄대/밀폐링) 개선을 통한 중량 감소, 파편 효과 증대 및 정확도 향상 등을 제시하고 있으며, 브래들리(Bradley) 장갑차 차체를 공용으로 사용하여 군수지원성도 높이고 있다.
#
# 장사정포 (3건):
#   - 북한 장사정포 위협 등 북한 대비 수적 열세인 포병화력 증강과 미래 지상군의 작전수행개념인 네트워크 기반하의 합동작전 수행과 효과 중심의 작전 수행을 위해서는 포병의 표적획득, 지휘통제 및 타격 능력 등 각 분야의 능력 보강이 필요하며, 탐지-타격(Sensor to Shooter) 연동과 정밀탄약을 이용한 포병의 적시 정밀타격능력 확보가 긴요한 사항임에는 틀림없다.
#   - 2006년에는 서울 불바다 발언으로 인한 장사정포대응 무기체계개선 TF15)가 구성되었고, 연구결과에 따라 ‘K9 전자신관 적용 사통장치체계 개선’을 수행하여 현재 K9A1 성능개량 자주포에 적용하고 있다.
#   - 우리나라 수도권의 최대 위협으로 간주되는 북한의 장사정포인 170mm M1989 자주포와 240mm M1991 방사포의 경우 사거리가 60km에 달하여, 70km이상의 초장사정 포탄 개발이 시급한 실정이다.
#
# 전략 폭격기 (1건):
#   - 미 항공모함 및 함정 격침을 목표로 하며, 향후 핵잠수함, 전략 폭격기, 스텔스 폭격기에도 장착할 예정이다.
#
# 전익기 (1건):
#   - 90년대 후반 미국에서도 유사 기능의 상태감시 시스템을 허니웰(Honeywell)에서 개발하여 육군 회전익기(UH-60, AH-64, CH-47D)에 장착하였다.
#
# 전자전기 (12건):
#   - 국방과학기술플러스 +14해당 개념의 원격운용 디코이는 평시 및 전시에 모두  운용될 수 있으리라 사료되며, 평시에는 중국 정찰기  출현 시 허위 레이더 신호를 송출하여 신호수집을 방해 하거나 오정보 수집을 유도할 수 있으며, 전시에는 주변국 대방사 미사일 대응을 위한 디코이(유인체)로 활용되어 아군 조기경보 레이더 및 지대공 미사일 기지를 보호할 수 있다.
#   - KADIZ 침범 대응전자전 분야 대응방안(안)4· 디코이를 조기경보 레이더 및 지대공 미사일 운용기지     인근에 고정형 또는 이동형으로 설치(그림 19해외 유사     무기체계 참조)· 중국 정찰기 출현시, 설치된 디코이를 원격으로 운용    하여 허위 레이더 신호를 방사하여 레이더 신호수집 방해    및 오정보 수집 유도(a) AN/TLQ-32 ARM-D,Anti-radiation missile decoy(미국)[26](b) KRTZ-125-2M, Radio-frequency decoy system(러시아/벨라루스)[27](c) SRTZ-2TM, Self protection system(벨라루스)[28]중국군 전자전 능력과 우리의 대응방안
#
# 2) 소형무인기 통합대응 방안 구축날로 증대하는 적 위협 무인기의 주요시설 정찰/공격에 대응하기 위해 “소형무인기 통합대응 방안” 이 필요할 것으로 사료된다.
#   - KADIZ 침범 사례한반도 주변 전자전 및 잠재적 위협 사례3중국군 전자전 능력과 우리의 대응방안
#
# 국방과학기술플러스 +1011서북방에서 KADIZ로 최초 진입해 10시51분쯤 이어도 동방으로 이탈했다”고 밝혔으며, 중국 군용기는 Y-9 전자전 정찰기인 것으로 전해졌다[19].
#   - 무인기 테러 사례1) 디코이 이용 신호수집 방해KADIZ를 침범하는 중국 정찰기의 주요 목적은 한반도內 레이더 등 방공망의 신호정보를 수집하는 것으로  추정되고 있다.
#
# 정찰위성 (20건):
#   - 2월에 미 해군도 함정발사용 미사일(RIM-161 SM-3)을 발사하여 고장 상태로 궤도를 돌고 있던 자국의 한 정찰위성(USA-193)을 요격하는 데 성공하였다.
#   - [그림 25] 미국 우주군 위성 탑재 재머 개념도[그림 26] 고출력 슈퍼 재머 개념도[그림 28] 원격지원 전자전기(SOJ)개념도[그림 29] 신호정보정찰위성 개념도[그림 27] 미 우주군의 고출력 통신재머적 위성 대응 방안으로 저궤도 위성 및 무인기에 탑재하여 운용되는 재머를 개발하는 방안이 있다.
#   - 결론313236414303
#
# 중국군 전자전 능력과 우리의 대응방안중국은 전자전정찰기를 이용하여 지속이고 정례적 으로 KADIZ 침범을 하고 있으며, 한반도 상공에는  중국의 신호정보정찰위성 및 SAR 위성들이 정지궤도 및 저궤도에서 운용되고 있다.
#   - 대표적으로 감시정찰위성 KeyHole 시리즈[ 5 ] 를 美국가정찰국( N RO ;  N a t i o n a l Reconnaissance Office)에서 운용하고 있다.
#   - 예를 들면 지구의 특정 지역을 항상 유지해야 하는 임무를 지닌 통신위성의 경우에는 정지궤도(GEO, Geostationary Orbit)에서 운용되고, 지구를 촬영하고 관측하기 위한 지구관측위성과 정찰위성은 센서 해상도와 밀접한 관계가 있으므로 주로 저궤도(LEO, Low Earth Orbit)에서 운용되고, 지구 전역을 돌면서 넓은 지역을 커버해야 하는 항법위성은 중궤도(MEO, Medium Earth Orbit)에서 운용된다.
#   - 저궤도 군 정찰위성 체계는  다수의 SAR위성체, EO/IR위성체를 이용하여, 관심지역의 전략 표적에 대한 감시 및 정찰을 수행하며 전천후 영상 정보를 획득하는 체계이다(그림 22).
#   - 잠재적  위협에 대비하여 고성능 군 정찰위성과 초소형 저가 감시 위성을 상호 보완적 운용을 통하여 감시.
#
# 지뢰 (25건):
#   - 50 ▒ 국방과학기술플러스 +하지 착용로봇 기술 외에도 국방과학연구소에서는 임무 특화 상지 기술로, 1) 임무장비를 어깨에 보다 쉽게 견착할 수 있는 무동력 임무장비 견착 모듈 및 2) 지뢰탐지 작업 보조를 위한 무동력 팔 근력보조 모듈에 대한 연구를 수행하였다.
#   - [표 6] 지뢰탐지 근력보조 모듈 성능시험 결과CaseCase 1(근력보조 없는 경우)Case 2(근력보조 모듈을 사용할 경우)근전도신호(%MVC)삼두근6.
#   - [표 8] 군용 드론의 용도별 분류(안)[11]구분용도내  용무기체계정찰용- 원거리, 근거리 정찰- 초소형, 수직이착륙형 등공격용- 자폭, 폭탄투하, 소총, 유탄발사 - 군집형 공격 등특수목적용- 통신중계, 지뢰/폭발물 탐지- 화생방, 안티, 전자전 등전력지원체계감시지원용- 경계 및 감시 작전 지원작전지속지원용- 수송, 구난, 방역, 소방- 맵핑, 조명, 영상촬영 등교육훈련용- 교육, 방공표적추적- 전투실험 등 중점 추진해야할 분야로 두 가지 예를 들자면, 첫 번째로는 ‘군집형’ 자율드론이다.
#   - 지뢰탐지병사가 제안된 팔 근력보조 모듈을 이용하면 지뢰탐지기 운용 중 근육력 및 사용에너지가 감소되어 지뢰탐지 임무시간이 상당히 연장될 것으로 기대된다.
#   - 화생무기 폐기시스템 기술 동향대량살상무기 제거를 위한 화생무기 폐기기술국방과학연구소 Chem-Bio기술센터 책임연구원 김현석개요국방과학기술플러스 +1화생무기 폐기시스템 기술 동향화생무기는 독성의 화생물질과 이들을 투발하기 위한  포탄, 미사일, 지뢰 등의 투발 수단을 총칭한다.
#   - 지뢰탐지 작업 보조 착용 모듈은 지뢰탐지기 (무게: 4kg) 운용 병사의 집중도 향상 및 작업효율 증대를 위해, 지뢰탐지병사 하박에 부착되어 팔 근육 힘을 보조해 줄 수 있도록 무동력 타입으로 현재 개발 중이다.
#   - 개발된 팔 근력보조장치를 착용한 후 지뢰탐지동작을 수행할 경우 이두근의 근활성도가 75% 감소되었다.
#   - 근전도신호를 이용하여 지뢰탐지병사 보조를 위해 제작된 팔 근력보조 모듈 착용 유무에 따른 효과도를 분석하였다.
#   - [그림 17] 지뢰탐지 근력보조 모듈 효과도 분석을 위한 실험 환경[그림 18] 지뢰탐지 근력보조 모듈 사용 여부에 따른 근전도 신호 결과
#
# 임무유형별 군사용 착용로봇 플랫폼 개발동향 ▒ 49이에 대한 결과가 그림 18 및 표 6에 제시된다.
#   - 또한 DMZ 일대 유해발굴 작업을 동시에 진행해야함을 고려하여 현재는 병사에 의해 직접 지뢰탐지/제거 작업이 진행되고 있다.
#   - 물론 개척전차 또는 폭파에 의해 지뢰제거 작업 속도를 증대시킬 수 있지만 이는 환경 파괴를 초래할 수 있다.
#   - 팔 근력보조 모듈 없이 통상적인 지뢰탐지동작을 하는 경우 다른 근육 대비 이두근이 가장 많이 활성화되었다.
#   - DMZ 일대에는 약 200만개의 지뢰가 묻혀있을 것이라 추정되며 이를 지뢰탐지병사들이 완전히 제거하기 위해서는 200년 이상 시간이 소요된다고 보고되었다.
#   - 국방과학연구소는 지뢰탐지병사 팔 근력보조를 위하여 그림 15와 같은 무동력 팔 근력보조 모듈을 개발하고 있다.
#   - 현재 우리나라에서는 남북경협 활성화를 준비하기 위하여 DMZ 일대 지뢰탐지/제거 필요성이 대두되고 있다.
#   - 임무유형별 군사용 착용로봇 플랫폼 개발동향 ▒ 47[그림 15] 지뢰탐지 근력보조를 위한 착용형 근력보조모듈 구성 및 형상2) 핵심기술지뢰탐지기 무게보조를 위한 팔 근력보조 모듈은 크게 동작구현부와 중력보상부로 구성된다.
#   - 지뢰탐지 병사는 약 4kg 정도 무게의 지뢰탐지기를 들고 임무를 수행하는데, 고도의 집중력이 요구되는 지뢰탐지 작업동안 팔에 집중되는 지뢰 탐지기 부하는 팔 근육의 피로도 발생을 가속화하여 약 20분 이상 작업을 지속하지 못하게 한다.
#   - 동작구현부는 지뢰탐지병사가 지뢰탐지기를 좌우로 스위핑 (sweeping)하는 동작을 구현한다.
#   - 대신 지뢰탐지기 무게 지지는 등쪽에 위치한 중력보상부에서 담당한다.
#   - 지뢰탐지기 하단 구조물을 볼 조인트 끝단 홀에 삽입하는 간단한 조작으로 지뢰탐지기를 장착할 수 있으며, 볼 조인트 회전 운동에 의해 탐지 작업 시 지뢰탐지기 자세를 미세 조정할 수 있도록 설계하였다.
#   - 모션캡쳐시스템을 이용하여 획득된 지뢰탐지 병사의 운동데이터를 이용하여 그림 16에 제시된 것처럼 중력보상 요구 토크를 분석하였다.
#   - [그림 16] 지뢰탐지 근력보조 모듈 중력보상 부 파라미터최적설계
#
# 48 ▒ 국방과학기술플러스 +3) 성능검증제작된 지뢰탐지병사용 착용형 팔 근력보조장치 모듈의 효과도를 검증하기 위해 1명의 피험자를 모집하여 실험을 진행하였다.
#   - 이를 위해 그림 17에 제시된 것과 같이 지뢰탐지기를 운용하는 팔 주요 근육에 근전도센서를 부착하였다.
#   - 실험은 1) 팔 근력보조 모듈 없이 통상적인 지뢰탐지동작을 하는 경우, 2) 팔 근력보조장치 착용 후 근력보조를 받으며 지뢰탐지동작을 하는 경우, 2가지 경우에 대해서 진행하였다.
#   - 지뢰탐지 근력보조 모듈1) 개요국방과학연구소는 2019년부터 민군기술협력사업을 통해 지뢰탐지 병사의 근력보조를 위한 엑소수트 시스템을 개발하고 있다.
#
# 천궁 (1건):
#   - SM-3, GBI(Ground Based Intercepter)는 중간단계, 천궁-II, 사드(THAAD), 패트리어트(Patriot)는 종말단계 미사일 방어에 해당한다.
#
# 프레데터 (3건):
#   - [9] 미국 CSIS 보고서는 프레데터 감시정찰 무인기를 이용하여 500km 거리에서 15초 만에 탄도미사일을 탐지 가능함을 인용하고 있다.
#   - 앞서 설명한 기능을 지원할 수 있는 잠재적인 UAV 원격측정 플랫폼은 글로벌 호크, 프레데터, 록히드 마틴의 Structure Blimp 통합 센서 등이 있다.
#   - 프레데터(미국) 복사판으로 알려진 Yi Long 는 2013년 파리 에어쇼에서 처음 공개 되었다.
#
# 함포 (7건):
#   - 한편, 2003년 9월에는 미국 뉴멕시코주 White Sand 시험장에서는 5인치 함포탄인 B-TERM(Ballistic Trajectory Extended Range Munition)으로 100.
#   - 미국의 ATK 社는 해군용 5인치 함포탄인 B-TERM(Ballistic Trajectory Extended Range Munition) 탄을 개발한 바 있는데, 텅스텐 케이스로 제작된 탄두와 저가형 유도항법장치를 채택한 것으로 알려져 있다.
#   - 5인치 MK 45 함포와 155mm AGS(Advance Gun System)에서는 사거리가 각각 41NM, 40NM로 각각 75.
#   - 스웨덴에서는 PzH2000 자주포(독일제)와 해안감시 레이더를 연동하여 해상 이동표적 제압 가능성을 시험하였고, 흑해연안에 전력화 배치된 러시아의 A-222E BEREG-E 해안포의 경우는 130mm 함포를 8×8 트럭에 탑재한 자주포와 사격통제장치 세트(탐지/사격통제 레이더+EOTS7)+사통컴퓨터)를 탑재한 사격지휘차를 연동하여 탐지거리 35km, 유효사거리 20km, 4개 표적 사격제원 계산 및 2개 표적 동시 교전 가능, 발사속도 10발/분의 성능으로 신속하고 효율적인 해안방어 수단으로 개발한 바 있다.
#   - 또한 이 탄은 고정표적은 물론 이동표적에 대해서도 사격이 가능하며, 사격이후 표적변환이 가능하며, 5인치 함포에서는 100km, 155mm 야포에서는 85km의 사거리를 갖는다고 소개하고 있다.
#   - Excalibur S를 함포에도 적용 가능한 127mm Excalibur N5를 개발 중이다.
#   - 미국의 155mm AGS(Advanced Gun System) 함포의 경우는 사격통제 장치와 완전 자동화된 탄/장약 이송/장전 장치를 이용하여 빠른 반응성과 높은 생존성을 가지는 무인 포탑을 채택한 사례이다.
#
# 화차 (1건):
#   - 0%)민간분야 매출파급효과1,021억원2,100억원참여기업 수204개390개실용화율(국방+민간)70%80% 이상❶ 민·군 기술혁신❷ 생태계 경쟁력 강화❸ 글로벌 진출 지원 확대 등     3대축을 중심으로 역량     집중방위산업의 지능화·첨단화를 위한 대규모 R&D 프로젝트 추진민·관의 소통과 협업을 위한 강력한 추진체계 가동
#
# 민‧군기술협력사업 정책동향 및 개선방향 분석 | 77[그림 6]  민‧군기술협력사업 2023년 시행계획(안)민·군기술협력 생태계 경쟁력 강화민·군 기술자산 공유 및 사업화 촉진생태계 밸류체인 경쟁력 제고핵심인력 양성 추진• 드론-로봇, 해양무인시스템 등   실증인프라 구축  • 국방기술 공개 및 민-군 기술 매칭 강화• 방위산업소재부품 기술개발 로드맵 마련 • K9 자주포 엔진 등 소재부품 국산화 • 방위산업 SW 인력양성 신규 추진 • 기계, 우주항공 등 기반분야 인재육성민·군기술협력 글로벌 진출 지원 확대타 산업과의 연계 협력 강화해외 기술협력 인프라 확충연구협력 네트워크 강화한-UAE 산업첨단기술전략회의 구성 폴란드 방산전시회(MSPO) 참가美보잉사와 공동 R&D MOU 체결• 기업종합지원시스템 가동 • 방산협력사에 맞춤형 금융지원(1천억원 규모)  • 방산선도무역관 확대(20 -> 31개소) • 군·산·학·연 기술교류회 확대 운영 • 지식재산권 및 연구개발 협력체계 강화 • 민군 표준협력 및 국방표준화 발전세미나 개최 중동유럽미국강력한 민·군 협력체계 가동• 방위산업발전협의회(산업부·국방부)    참여범위 확대 및 운영 활성화• 민군기술협의회 위상 격상 추진기술협력-금융지원-판로 확보 등 기업지원 강화를 위해 방산물자교역지원센터 등 유관기관 기능 강화범정부협력협업 지원체계2023년 민·군기술협력 R&D 투자 확대전년대비 11% 증가한 2,781억원 투입16대 중점기술분야 R&D 강화민·군겸용 기술개발2,230억원민·군 상호 기술이전456억원민·군 규격 표준화 등95억원기반기술전자공학/레이저 센서레이다/소나/항법 센서가시화차세대 통신바이오소재핵심기반 소재기능성 소재생화학물질 및 방사능 탐지/식별보호 및 해독우주에너지발사체위성체/우주선친환경/차세대에너지지향성에너지첨단지능로봇드론/무인기/AAV사이버/가상현실인공지능도전적인 R&D 확대• 지능화‧첨단화를 위한 신규과제 착수  (초소형 지능형 드론 개발 등)• 고위험·고성과 대규모 R&D   신규 기획민·군 상호기술혁신민 →   군 AR·VR 훈련체계/정비장비 등 군 →   민 악성코드 탐지기술 이전 등• 무인기 감시정찰체계 구축 신규 기획우주산업화 기반 마련• 우주 소재부품 자립화 추진  (우주물체 감시 레이다 핵심기술 개발 등) • 민‧군겸용 위성개발사업 통한 우주실증202220232,5042,781억원
#
# 78 | 국방과학기술플러스 +	 6	민‧군기술협력사업 개선 방향 분석민‧군기술협력사업은 앞서 언급한 다양한 성과와 제2의 도약을 위한 많은 준비를 추진하고 있지만, 산업통상자원부에서 주관하는 R&D 사업으로 국가 R&D와 국방 R&D의 특성을 모두 포함하고 있다.

# %% [markdown]
# # 전처리3 : \n\n이 있는 문장 제거

# %% [markdown]
# ex) 관련없는 문장까지 가져와지는 경우 다수
#  - 실험은 1) 팔 근력보조 모듈 없이 통상적인 지뢰탐지동작을 하는 경우, 2) 팔 근력보조장치 착용 후 근력보조를 받으며 지뢰탐지동작을 하는 경우, 2가지 경우에 대해서 진행하였다.[그림 17] 지뢰탐지 근력보조 모듈 효과도 분석을 위한 실험 환경[그림 18] 지뢰탐지 근력보조 모듈 사용 여부에 따른 근전도 신호 결과
#
# 임무유형별 군사용 착용로봇 플랫폼 개발동향 ▒ 49이에 대한 결과가 그림 18 및 표 6에 제시된다.
#
# - 중력보상부 기구부에서 스프링에 의해 전달되는 보상토크를 기구학적으로 해석하였고 이 보상토크가 중력보상 요구토크와 유사하게 될 수 있도록 기구 파라미터에 대한 최적설계를 수행하였다.[그림 16] 지뢰탐지 근력보조 모듈 중력보상 부 파라미터최적설계
#
# 48 ▒ 국방과학기술플러스 +3) 성능검증제작된 지뢰탐지병사용 착용형 팔 근력보조장치 모듈의 효과도를 검증하기 위해 1명의 피험자를 모집하여 실험을 진행하였다.

# %%
def filter_examples(terms, examples,
                    max_run: int = 20,) -> dict[str, list[str]]:
    matched_dict = {}
    for term in terms:
        pattern = re.compile(r'(?<!\d)' + re.escape(term) + r'(?!\d)')
        filtered = []
        for ex in examples:

            #  용어 매칭 & 길이 제한
            if not (pattern.search(ex)) :
                continue

            if "\n\n" in ex:
                continue

            # 3) “긴 무공백 구간” 검사 (이전과 동일)
            runs = re.findall(r'[가-힣A-Za-z0-9]+', ex)
            if any(len(run) > max_run for run in runs):
                continue

            filtered.append(ex)


        # 4) 순서 유지하며 중복 제거
        matched_dict[term] = list(dict.fromkeys(filtered))

    return matched_dict

# %%
all_examples = []
for row in weapon_ex['example']:
    try:
        all_examples.append(row)
    except:
        continue

# 2) terms 불러오기
terms = weapon_ex['term'].unique().tolist()

# 3) 필터링 수행
filtered_dict = filter_examples(terms, all_examples, max_run=20)

# 4) 중복값 제거
for term, exs in filtered_dict.items():
    # dict.fromkeys 이용해 순서는 유지하되 중복 값은 하나만 남김
    filtered_dict[term] = list(dict.fromkeys(exs))

# %%
have_example_term = [term for term, exs in filtered_dict.items() if exs]
print(have_example_term) # 용례가 있는 용어
num_terms_with_examples = sum(1 for exs in filtered_dict.values() if exs)
num_examples_with_examples = sum(len(exs) for exs in filtered_dict.values() if exs)
print(f"용례가 있는 용어의 개수: {num_terms_with_examples}개") # 35개로 감소(37개 -> 35개)
print(f"총 용례의 개수: {num_examples_with_examples}개") # 205개로 감소(236개->232개->205개)
# Out:
# ['5세대 전투기', 'C-130 허큘리스', 'F-2', 'F-22 랩터', 'J-20', 'P-3C', 'SM-3', 'T-50', '견인포', '공격기', '공대공 미사일', '기뢰', '기총', '대륙간탄도미사일', '대포병 레이더', '독도함', '랴오닝호', '무인전투기', '미사일 방어체계', '비살상무기', '사드', '상륙돌격장갑차', '알레이버크급 구축함', '어뢰', '장갑차', '장사정포', '전략 폭격기', '전익기', '전자전기', '정찰기', '정찰위성', '지뢰', '천궁', '프레데터', '함포']
# 용례가 있는 용어의 개수: 35개
# 총 용례의 개수: 205개

# %%
# 결과 확인
for term, exs in filtered_dict.items():
    if exs:
        print(f"{term} ({len(exs)}건):")
        for ex in exs:
            print("  -", ex)
        print()
# Out:
# 5세대 전투기 (1건):
#   - ■ PL-10 (중국)중국에서 2004년부터 5세대 전투기용으로 개발한  5세대 단거리공대공유도탄이다.
#
# C-130 허큘리스 (1건):
#   - 전술수송기의 결정판 C-130 허큘리스, 2017.
#
# F-2 (1건):
#   - 장착기종 으로 F-2, F-15J, F-4EJ에서 운용 중이며, 정밀도 높은 RLG(Ring Laser Gyro) IMU를 탑재하여 LOAL 모드 운용이 가능하다.
#
# F-22 랩터 (1건):
#   - 최근에는 국방예산에 있어 전세계 지출규모의 약 40%를 차지하는 미국에서 조차도 서울에서 개최한 ‘ADEX 2015’에서 전시 및 시험비행에 참여한 적이 있는 세계 최강의 스텔스 전투기로 평가받는 ‘F-22 랩터(Raptor)’의 과도한 획득 및 운영유지 비용으로 인하여 조기퇴역하고 대체할 차세대전투기를 고려하고 있다고 미공군 참모총장이 최근 개최된 맥앨리스 컨퍼런스에서 언급하였다.
#
# J-20 (1건):
#   - 중국의 최신전투기인 J-10, J-11, J-20, FC-31 전투기에 장착 예정이며  수출용 버전인 PL-10E도 개발하였다.
#
# P-3C (1건):
#   - 하지만, 이스라엘의 ELTA, IAI, Rafael 사의 장비에 의존하여 RF-16펠콘 유인정찰기, 송골매 무인정찰기, P-3C 성능개량기 등을 운용하였다.
#
# SM-3 (5건):
#   - [표 3] AEGIS 베이스라인별 보유 능력AEGIS B/L탑재 플랫폼주요 능력비  고B/L 5CG 59-65, 67,68,70-73 / DDG 51-78•AAW•MIL-SPEC 적용통합 AAW, 전장상황인식 능력 향상B/L 6CG 66, 69 / DDG79-90•AAW•MIL-SPEC/COTS 적용•Link-16, CEC네트워크 향상B/L 7DDG 91-112• AAW•COTS 적용•Link-16, CEC구역 대공방어 능력 향상B/L 8CG 52-58•B/L 7과 동일B/L 99ACG 59-64•AAW, CEC, NIFC-CA, SM-2, SM-6복합임무 구역 대공방어능력(ACB 12를 통한 AEGIS현대화)9CDDG 51-78•IAMD(BMD+AAW), AAW, CEC, NIFC-CA,    SM-2, SM-6, SM-3 Blk 1A/1B9DDDG 113 AF•B/L 9C와 동일9EAEGIS ASHORE•BMD, SM-3 Blk 1A/1B, Remote Launcher       Mods라.
#   - SM-3, GBI(Ground Based Intercepter)는 중간단계, 천궁-II, 사드(THAAD), 패트리어트(Patriot)는 종말단계 미사일 방어에 해당한다.
#   - 탄소섬유 기반 초고온 내열/내산화 복합소재 기술  	 1	개요초고온 내열 복합소재는 위에 대표 그림에서 나타나 있는 것과 같이 사드(THADD)와 유사한 유도탄 방어무기체계(SM-3)에 필수 핵심부품 소재이다.
#   - 2월에 미 해군도 함정발사용 미사일(RIM-161 SM-3)을 발사하여 고장 상태로 궤도를 돌고 있던 자국의 한 정찰위성(USA-193)을 요격하는 데 성공하였다.
#   - 국방과학연구소 국방첨단과학기술연구원 소재에너지센터선임연구원 이정민온도, 압력, 유량↑ 삭마↑X43-A온도, 압력, 유량↑ 강도↓, 기밀↓능동냉각유로리딩엣지스크램젯온도, 압력, 유량↑ 삭마↑SM-3노즐목위치•자세제어Pue, A.
#
# T-50 (2건):
#   - 최근의 또 다른 사례로는 한국항공우주산업주식회사(KAI)의 T-50 항공기 개발이라 할 수 있다.
#   - T-50 항공기 개발비는 약 2조원이었으며, 그 중 10%인 200억을 종합군수지원(IL그렇기S) 개발 비용으로 사용하였기에 후속군수지원을 지속적으로 가능하게 하면서 아랍에미리트와의 수출협상 시 한국 정부차원의 안정적 후속 군수지원 보장에 대한 요구를 충족하게 되며 큰 호평을 받고 있다.
#
# 견인포 (5건):
#   - 우리나라의 경우 1980년대에 155mm 39구경장 KH179 견인포와 함께 미국의 M549A1 RAP 탄을 1984년도까지 모방 개발한 KM549A1 탄으로 30Km의  사거리를 달성한 바 있고, 1998년에는 155mm 52구경장 K9 자주포와 K307 베이스블리드탄을 개발하면서, 42km를 달성하여 당시 사거리분야에서 무기개발 선진국과의 격차를 뛰어넘은 바 있다.
#   - [그림 1] 포탄의 사거리 연장기법초장사정탄 기술동향55초장사정탄 기술동향2차 대전 이후 화포와 탄약이 이루는 무기체계의 사거리 경쟁은 이미 1950년대부터 시작되었는데, 구소련은 1960년대 후반에 130mm 52구경장 M-46 M1954 견인포에서 130mm 고폭탄을 사격하여 27.
#   - 이 결과는 미국이 2차 대전 때 사용하던 M114포와 M107 포탄 조합의 최대사거리가 14km인 점을 고려하면 2배에 달하여, 크게 자극을 받은 미국은 155mm M198 39구경장 견인포와 아울러 M549 (고폭약Comp B), M549A1(고폭약 TNT) 로켓 보조추진탄(RocketAssistance Projectile)을 1970년대 후반까지 개발하였는데, 최대사거리는 30km에 달하였다.
#   - 1992년 개념에 대한 최초 입증 후, 2005년에는 화포용 레이저 점화장치(DPLIS16))를 개발하였으며, 개발기간동안 기존 자주포와 견인포에 적용하여 약 25,000발의 실 사격을 수행한 바 있다.
#   - 미래 포병이 지향하는 방향에 맞추어 국외의 최근 개발동향을 살펴보면, 각국의 전술환경변화를 고려한 소요에 따라 견인포의 차량탑재형을 개발하는 등의 개량형의 개발이나, 기존의 자주포 기술을 활용한 다양한 목적의 체계를 창출하여 제안하고, 소요를 확대할 수 있는 원격무인 포탑, C-RAM1)용 포탑 등을 연구하고 있다.
#
# 공격기 (1건):
#   - Yi Long은 전형적인 무인 공격기로 공대공 미사일, 레이저 유도탄, 대인폭탄, 50kg 소형 유도탄 등을 장착할 수 있다.
#
# 공대공 미사일 (1건):
#   - Yi Long은 전형적인 무인 공격기로 공대공 미사일, 레이저 유도탄, 대인폭탄, 50kg 소형 유도탄 등을 장착할 수 있다.
#
# 기뢰 (7건):
#   - 2008년부터 2년 동안 개념연구 형태로, 노르웨이 FFI와 함께 착저 잠수함 또는 기뢰 탐지를 위한 기술개발 과제를 수행하였다.
#   - 0 kW에너지량-6,000 kWh15,000 kWh6,000 kWh수행임무및임무장비MCM--------ISR○EO/IR------ASW--------정보수집○SAS------장비수송○Mine Laying○-○-○-항해장비FLS○---DVL○---BAS----USBL/ATM○---수상/수중통신거리----탐지소나 성능----탐지소나 제원----특징• 수상감시정찰,기뢰부설• 해저지형 mapping• 모듈형 무인잠수정 • 해저통제 모듈탑재• 모듈형 무인잠수정• 해저지형 탐색 ROV 탑재• 모듈형 무인잠수정• 시추장비 탑재"재구성 가능한 모듈형 수중모함 MUM AUV"무인잠수정의 기본 기능을 보유한 기본 모듈(base module)인 연료/산화제 저장탱크, 항법, 통신 정보처리기를 바탕으로 임무 및 운용목적에 따라 임무 모듈(mission module)을 추가하여 각 임무에 따라 플랫폼 재구성이 가능한 무인잠수정을 그림 8.
#   - Orca XLUUV의 주요특징은 전투 임무를 수행할 수 있는 기뢰모듈을 탑재하고 있으며, 수상감시정찰을 위해 마스트에 광학 장비를 탑재한 것을 알 수 있다.
#   - 군사목적으로 전력화 되어 있는 무인잠수정은 측면주사소나(Side Scan Sonar, SSS)를 탑재하여 해저기뢰탐색을 위해 활용되거나, 잠수함의 대잠전 훈련을 위해 소음을 방사/모의 할 수 있는 센서를 탑재하여 활용되고 있다.
#   - 무인잠수정 임무2004년 미 해군에서 발표한 UUV Master Plan에서는 무인잠수정의 주요 임무를 정보/감시/정찰, 대기뢰전, 대잠전, 조사/식별, 해양조사, 통신/항해 네트워크, 적재물 운송, 정보작전 그리고 적기신속타격으로 총 9가지로 분류하였다.
#   - 함정의 임무영역을 표현하는 운용성능은 그림 2와 같이 대공전, 대잠전, 대수상전, 기뢰전과 같은 주 임무수행  영역과 이를 가능케 하는 공격능력, 방어능력, 기동, 지속능력 등의 능력요소로 이루어진다.
#   - 이후 미 해군에서는 보잉사의 Echo voyager를 기반 으로한 기뢰부설목적 Orca XLUUV를 개발하여 2022년 4월에 최초로 공개하였고, 이는 그림 7.
#
# 기총 (4건):
#   - 070 gIIR/TVC/HMCS 연동[그림 7] Python 제원[6]항목크기총(탄도)사거리속도기동기타제원2.
#   - 5세대 단거리공대공유도탄 개발 사례항목크기총(탄도)사거리속도기동기타제원2.
#   - 항목크기총(탄도)사거리속도기동기타제원3.
#   - 항목크기총(탄도)사거리속도기동기타제원2.
#
# 대륙간탄도미사일 (2건):
#   - 이 기술은 대륙간탄도미사일(ICBM) 개발도 가능한 수준인 것으로 평가된다.
#   - 아방가르드는 러시아의 대륙간탄도미사일 탑재 극초 음속 활공체로, 최고속도 마하 27로 활공하며 별도의 추진기관이 없는 순수한 활공체이다.
#
# 대포병 레이더 (1건):
#   - 육군의 ISTAR3) 능력 보강, 대포병 레이더 보강, MET4)(기상) 장비 보강, 정밀타격능력 보강, C4I5) 능력 보강, 플랫폼 개선 등을 제시하고 있다.
#
# 독도함 (1건):
#   - 기본형은 현재 해군 상륙함인 독도함에 탑재되어 운용되고  있으며 성능개량형은 레이더 성능을 업그레이드하여  지상용 (SMART-L MM/F) 및 함정용 (SMART-L MM/N)  다중임무 디지털레이더로 개발되었다.
#
# 랴오닝호 (1건):
#   - 중국은 항공모함 랴오닝호에 리젠을  탑재해 미국령 괌 인근까지 감시 정찰에 나설 것으로  예상되고 있다.
#
# 무인전투기 (1건):
#   - 'GJ(攻擊·공지)-11' 스텔스 드론은 미국의 B-2  스피릿 폭격기, 항공모함 베이스의 장거리 무인전투기 X-47B와 비교되고 있다.
#
# 미사일 방어체계 (10건):
#   - 항공기반 방어의 장점  상승단계 탄도미사일 방어를 위해 항공기에 적외선센서와 요격미사일을 장착하여 Sensor-to-Shooter 방식의 미사일 방어체계를 구성하면 상승단계 탄도미사일 방어에 여러 가지 장점이 있다.
#   - 즉, 정지 궤도상의 위성체에 조기경보 IR 탐지장비를 탑재하여, 초기 탄도탄  발사 화염을 탐지하여 식별하고, 지상 조기경보 체계 및  조기경보 레이더에 식별된 정보를 제공하여 신속히 경보  발령을 내리게 하고, 지상 대미사일 방어체계의 신속한 대응 타격을 가능케하며, 나아가서는 탄도탄 발사점 및 탄착점을 예측하는 기능을 갖는다.
#   - 낮은 고도에서의 극초음속 비행은 극초음속 순항미사일이 미사일 방어체계를 침투할 수 있도록 하며, 극초음속 활공체와 달리 종말 단계까지 가속할 수 있어 복잡한 기동에 더욱 유리하다.
#   - 항공기반 상승단계 탄도미사일 방어체계는 북한과 같이 폭이 좁고 긴 지리적 특성이 있는 지역 가까이 접근하여 요격이 이루어지므로 탄도미사일 방어에 효과적인 것으로 이 연구는 결론 내고 있다.
#   - 이경행 외, “해상기반 탄도미사일 방어체계의 임무효과에 관한 연구”, Journal of Aerospace System Engineering, pp.
#   - 항공기반 상승단계 탄도미사일 방어체계가 개발되어 기존 중간단계/종말단계 방어에 추가되면 다층방어의 효과를 증대시킬 수 있을 것으로 기대된다.
#   - 반면 탐지센서와 요격미사일을 무인항공기에 통합하여 Sensor-to-Shooter 방식으로 항공기반 탄도미사일 방어체계가 구현되면 탐지부터 요격까지 소요되는 시간을 줄여 대응 능력을 개선할 수 있다.
#   - [그림 20] 항공기반 상승단계 탄도미사일 방어체계다.
#   - 항공기반 탄도미사일 방어체계 구성에 필요한 무인항공기는 적외선센서와 요격미사일을 장착 가능해야 하며 그림20은 이에 따른 개념도이다.
#   - 항공기반 상승단계 탄도미사일 방어체계 구성항공기반 상승단계 탄도미사일 방어체계는 교전시간 확보를 위해 탐지센서와 요격미사일을 장착한 Sen­sor-to-Shooter 방식이 되어야 한다.
#
# 비살상무기 (1건):
#   - 그리고 드론, 전투 차량, 통신 기지국 등 체계를  직접적으로 파괴하지 않으면서 무력화시킬 수 있는 기술이므로 비살상무기로 분류된다.
#
# 사드 (3건):
#   - SM-3, GBI(Ground Based Intercepter)는 중간단계, 천궁-II, 사드(THAAD), 패트리어트(Patriot)는 종말단계 미사일 방어에 해당한다.
#   - 탄소섬유 기반 초고온 내열/내산화 복합소재 기술  	 1	개요초고온 내열 복합소재는 위에 대표 그림에서 나타나 있는 것과 같이 사드(THADD)와 유사한 유도탄 방어무기체계(SM-3)에 필수 핵심부품 소재이다.
#   - 무선기기가 폭증함에 따라 전자파에 대한 관심이 높아지고 이에 대한 우려로 인해서 사회적으로 과도한 비용이 발생하고 있으며, 기상청 레이다 논란, 해상관제용 레이다 논란, 사드 논란 등 전자파 영향 여부를 둘러싼 진실 공방으로 사회적 갈등이 확산되고 있다.
#
# 상륙돌격장갑차 (2건):
#   - (그림 3 참고)가상모의 시뮬레이터의 경우, 공수강하시뮬레이터, 상륙돌격장갑차 KAAV 시뮬레이터, 합동화력 시뮬레이터, KUH-1 시뮬레이터 등과 같은 다양한 시뮬레이터를 보유하고 있으며 이는 실제 장비와 유사한 환경에서 해당 체계를 운용하는 훈련여건을 제공하며 경제적인 훈련이 가능한 시스템이다(그림 4&5 참고).
#   - 해병대의 경우도 그와 유사하게 공수강하시뮬레이터, 상륙돌격장갑차 KAAV 시뮬레이터, 합동화력 시뮬레이터, KUH-1 시뮬레이터 등과 같은 다양한 시뮬레이터를 보유하고 있으나 이것들은 개별 체계의 숙달 훈련 위주로 활용되고 있다.
#
# 알레이버크급 구축함 (1건):
#   - 55m, 무게는 50kg, GPS/INS 유도항법 기능을 갖고  있어, CEP 20m의 정확도 사격이 가능한 것으로 알려졌고, 알레이버크급 구축함에서 발사하여 최대 110km 떨어진 지상표적 타격이 가능한 것으로 알려졌다.
#
# 어뢰 (59건):
#   - [그림 19] 교육훈련 패러다임 변화해군 병기탄약창에서는 전력화예정인 무기체계인 중어뢰-II(범상어)에 대한 정비요원들의 정비능력 사전 확보를 위한 교육훈련 필요성에 따라 가상정비교육훈련지원장비(VmTSE, Virtual maintenance Training Support Equipment) 확보방안을 2018년도에 수립하였으며, 2019년에 국방기술의 민수기술이전을 통하여 국과연 보유기술을 제작사인 (주)IVRSYSTEMS에서 기술 확보 후 VmTSE 구축 사업을 착수하였다.
#   - 국방과학연구소(해양기술연구원)에서는 이 QUEST 프레임워크를 이용하여 국과연 주관 연구개발 체계인 함정전투체계, 어뢰체계, 음탐기체계 등의 개발 과정에서 어뢰전/대어뢰전/대잠전 모델을 개발하고 효과도분석, 전술 개발 등에 적용하고 있다.
#   - 이때 만재 배수량 = 베이스 중량 + 조합에 참여하는 구성요소 중량 + 기타 중량 (유형1의 예제에서는 경어뢰와 중어뢰 관련 시스템과 무장의 중량)이다.
#   - 이 예제에서는 운용개념 분석을 통해 임무수행 영역을 대잠전, 대어뢰전, 대함전, 대공전으로 분류하고  각각의 수행영역에 8, 8, 5, 6개의 탑재체계 대안을 상정한다.
#   - 또한 함정내 탑재장비, 유도무기, 어뢰와 같은 실물장비를 자주 접하지 못하는 고가의 장비일수록 더욱 교육훈련이 중요하기에 대체재로서 가상교육훈련장비의 구축 및 운용이 필요하다.
#   - 해당 순항 속도에서는 초공동 어뢰의 운동으로 인해 초공동 어뢰 입구에서 약 50bar에 이르는 고압으로 해수를 흡입하게 되며, 흡입된 해수는 해수흡입 연소기의 인젝터와 수반응 추진제 이송을 위한 피스톤으로 공급된다.
#   - 이러한 문제를 보완하기 위하여 그림 1과 같이 중요한 시설 보호를 위하여 고정식 발사 플랫폼을 활용하거나 수상함에서 발사하는 개념이 제안되고 있으며, 이란의 초공동 어뢰인 후트(Hoot)의 경우 수상함에서 시험 발사하는 장면을 확인할 수 있다.
#   - 하지만 이러한 초공동 어뢰의 경우 소음이 크고, 상대적으로 사거리가 짧으며 유도기능이 제한적이라는 단점이 존재한다.
#   - Mg/NaNO3 추진제는 전통적인 조명제의 조성으로 러시아와 이란을 제외하고 초공동 어뢰에 적용한 사례가 없으며, 금속연료 추진제를 대형으로 제작하는 관련 기술도 공개되어 있지 않다.
#   - 개발기관인 DIEHL BGT Defence에 의하면 바라쿠다는 수중 및 수상의 타켓뿐만이 아니라 러시아에서 운용하고 있는 쉬크발 어뢰를 직접적으로 요격이 가능하다고 공개하였다.
#   - 독일  1988년 독일은 초공동화연구를 시작하여 최근까지 최대속력 400km/h 이상을 만족하는 바라쿠다(Barracuda) 어뢰를 개발중에 있다.
#   - 순항 심도에 도달한 초공동 어뢰는 시동부스터를 점화하여 순항 속도인 100m/s까지 가속한다.
#   - 초공동 어뢰는 발사관에서 발사된 후, 사출모타를 통해 초기 가속되며 순항 심도까지 이동한다.
#   - 전기모터 혹은 내연기관 방식의 어뢰가 50노트 수준임을 고려하면 표적이 회피하거나 반응할 시간을 제한하는 개념의 무수중 유도무기 패러다임의 변화 해수흡입 추진기관!
#   - 사출모타는 작동 후 어뢰로부터 분리된다.
#   - 러시아서두에 언급한 바와 같이 해수흡입 추진기관을 초공동 어뢰에 적용한 사례는 러시아의 쉬크발이다.
#   - 러시아(구 소련)는 미국의 고속 원자력 잠수함과의 교전과 항공모함을 공격하는 목적으로 초공동 어뢰 개발에 착수하였다.
#   - 1960년대에 쉬크발(Shkval)이라는 명칭으로 개발을 시작하였으며, 약 200노트(370km/h)의 속력으로 바닷속에서 항주가 가능하여 기존 어뢰 대비 4~5배의 빠른 속력으로 알려져있다.
#   - 이란  이란은 2006년 4월 2일과 3일 양일에 걸쳐 자체개발 초공동 어뢰인 후트의 발사시험을 진행하였고 성공적으로 목표물에 타격했다는 영상을 공개하였다.
#   - 러시아의 초공동 어뢰인 쉬크발(Shkval)의 경우 초공동 현상 발생장치와 해수흡입 추진기관을 조합하여 약 200노트의 속도를 내는 것으로 알려져 있다.
#   - 더불어 2004년도에는 새로운 초공동 어뢰개발을 착수하였으나 뚜렷한 프로젝트의 성과는 보여주지 못하고 있다.
#   - 4mm/s의 고연소속도를 갖기 때문에 초고속 어뢰용 금속연료 추진제로 적용 가능할 것으로 판단된다.
#   - 항적추적어뢰 기만을 위한 기포항적 생성기술 연구 | 43 참고문헌  1.
#   - 셋째, “기포항적 생성 모델링 기술”은 측정된 자료를 모델화하여 항적추적어뢰 기만 효과 분석하기 위한 기술로, 기만 효과에 필요한 구성 모델을 연구하고 통계학적 방법으로 항적추적어뢰에 대한 기만 효과를 분석하는 기술이다.
#   - 본 소개글에서는 항적추적어뢰 항적탐지 기능에 대해 기만 능력을 가지는 기포항적 생성기술 확보를 위해 요구되는 세 가지 핵심기술에 관하여 보다 자세하게 살펴보고자 한다.
#   - 항적추적어뢰의 공격을 효과적으로 방어하기 위해서는 원하는 심도에서 원하는 크기를 가지는 기포를 원하는 시간 내에 발생시켜야 한다.
#   - 기포특성 측정 기술제조된 기포발생물질이 항적추적어뢰의 공격을 기만할 수 있는 지의 여부를 판단하기 위해서는 기포발생물질에 의해 생성되는 기포항적의 음향학적 특성과 분포학적 특성을 측정할 필요가 있다.
#   - 본 연구팀에서는 항적추적어뢰의 항적탐지 기능에 대해 기만 능력을 가지는 기포항적을 생성시키기 위하여 필요한 3가지 핵심 기술을 다음과 같이 식별하였다.
#   - 대규모의 기포항적을 대상으로 측정된 음향학적, 분포학적 특성을 측정하고 분석함으로써, 제조된 기포발생물질의 조성이 항적추적어뢰 기만 효과가 있는지를 최종적으로 확인하였다.
#   - 또한 기포항적 기만 시 수상함 회피기동 여부, 음향기만기 사용 여부 및 종류, 개수 등과 어뢰 경보거리, 어뢰 및 수상함 속도, 계절, 해역 등 다양한 변수를 복합적으로 동시에 고려하여야 한다.
#   - 본 연구팀은 이를 몬테카를로 방법(Monte-Carlo method)을 통해 항적추적어뢰 공격에 대한 기만 효과를 통계학적으로 분석하였다.
#   - [그림 7] 기포항적 산란강도 도출 결과 예제 기포발생물질 조성, 밀도, 무게, 형상 등 조건에 따른 측정실험을 반복적으로 수행하여, 기포발생물질에 의해 발생되는 기포항적의 산란강도 프로파일 단면을 데이터베이스화하였으며, 최종적으로 항적추적어뢰 탐지기능을 기만하기 위한 효과도 분석 구성모델로 활용하였다.
#   - [그림 10] 기포의 분포 영상화 결과 예제  5  기포항적에 의한 기만 효과 분석 연구제조된 기포발생물질에 의해 발생되는 기포항적의 물리적, 음향적 및 분포적 특성은 수조실험, 호수실험, 해상실험 등 단계적인 검증 실험을 통해 신뢰도 있는 자료를 확보하였으며, 확보된 자료는 최종적으로 항적추적어뢰 공격을 기만하기 위한 효과 분석 모델에 적용하였다.
#   - 본 연구팀은 기포층에 의한 음파 산란, 음파 흡수, 감쇠 및 음속변화 등 기포층의 음향 성능변화에 집중하여 음향탐지 모델 개발에 주력하였으며, 어뢰체계 탐지/로직 등 유사과제 개발 경험을 바탕으로 실제 전장환경에 근사한 기만 효과 구성 모델을 성공적으로 구축하였다.
#   - 따라서, 우리는 대량의 기포항적을 빠르게 생성시킬 수 있을 뿐만 아니라, 항적추적어뢰 기만에 효과적인 크기를 가지는 기포를 발생시키고, 기포의 발생 심도, 생존 시간 등을 제어할 수 있도록 화학물질을 이용하여 기포항적을 생성시키는 방법을 연구하였다.
#   - 3  기술개발에 필요한 핵심기술수상함에서 항적추적어뢰의 공격이 식별되면 어뢰의 추적을 방해하기 위하여 매우 짧은 시간에 충분한 양의 기포항적을 생성시켜야 한다.
#   - 한국 해군이 항적추적어뢰의 위협으로부터 한시라도 빠르게 벗어나기 위해서는 후속 연구수행이 시급히 요구되는 상황이다.
#   - 추진제 이송시스템 개발  해수흡입 추진기관의 경우 어뢰의 속도로 인한 유입되는 유체의 동압을 통하여 유체가 연소기 내부로 분무되고 이를 바탕으로 추진력을 얻는 것으로 알려져 있다.
#   - 이러한 과정을 통하여 도출된 해수흡입 추진기관 기술이 초공동 형성 및 제어 기술과 통합된다면 향후 요격어뢰 혹은 중어뢰 기술 등으로 발전 가능할 것으로 판단되며 추진기관 기술에 대한 개발 뿐 아니라 운용개념 및 적용 체계에 대한 연구 개발이 종합적으로 이루어져야 요소기술이 활용될 수 있는 것으로 판단된다.
#   - 수반응 금속연료 추진제 개발  수반응 금속연료 추진제는 초공동 어뢰의 핵심 구성품으로서, 금속 기반의 연료과농 고체 추진제가 물과 화학반응을 할 때 생성되는 열과 추력을 이용한다.
#   - 따라서 어뢰 체계 요구조건에 따른 수반응 추진제의 연소속도가 해수흡입 추진기관의 핵심기술이라 할 수 있다.
#   - 어뢰 체계의 형상 제한 조건에 따라 수반응 추진제 끝단의 면적은 정해지므로 수반응 추진제의 연소속도가 해수흡입 추진기관의 추력을 결정한다.
#   - 시동부스터는 어뢰를 순항 속도까지 가속시키는 역할과 함께 수반응 추진제를 점화시키는 역할도 동시에 수행하며, 시동부스터의 작동 중단에 따라 연소실로 유입된 해수는 수반응 추진제 연소가스와 반응하여 추력을 발생시키게 된다.
#   - 결론3항적추적어뢰 기만을 위한 기포항적 생성기술 연구해양기술연구원 : 선임연구원 배호석321.
#   - 최근 어뢰는 음향추적 기능과 함께 항적추적 기능을 추가하여 운용한다.
#   - 항적추적어뢰는 항적탐지 기능을 이용하여 수상함 항적을 추적하여 공격하는 어뢰로, 항적이 존재하는 수상함에게는 매우 치명적인 위협을 가하는 수중 유도무기이다.
#   - 항적추적어뢰는 현재 존재하는 기만기 주파수 보다 높은 고주파의 항적탐지기를 이용하여 근접거리의 항적을 탐지하며 추적하기 때문에 현재 개발되어 있는 부유식/자항식 기만기로는 대응이 불가한 것이 현실이다.
#   - 본지에서는 항적추적어뢰를 기만할 수 있는 방법 중 하나로, 그림 1과 같이 인공적인 기포항적을 수상함 항적 인근에 생성시켜 항적추적어뢰의 추적을 방해하는 방법을 소개한다.
#   - 2  기술현황선진국의 어뢰방어체계 기술은 함정의 생존과 직결되는 매우 중요한 기술로써 구체적인 정보의 접근이 제한된다.
#   - 이어 국방과학연구소 해양기술연구원에서는 미사일연구원과 함께 2019년부터 2022년까지 선행핵심 과제를 통해 기포발생물질에 의한 기포발생 기술, 기포특성 측정 기술, 그리고 기포항적에 대한 항적추적어뢰 기만 효과를 분석하는 기포항적 모델링 기술 등 기포항적 생성을 위한 핵심기술을 확보하였다.
#   - 그림 11은 항적추적어뢰가 특정 방위각에서 수상함을 공격하는 특정 시나리오를 가정하였을 때, 기포항적에 의한 기만 효과를 분석한 예제를 보여준다.
#   - 항적추적어뢰가 공격하는 것을 수상함에서 식별하게 되면, 수상함은 회피 기동 및 음향 기만기를 투하하는 등 어뢰공격에 적극 대응하는데, 기포항적을 이용한 기만 대응을 수행함에 따른 아군 수상함 생존률의 변화 정도를 시나리오 조건에 따라 분석하였다.
#   - 항적추적어뢰 기만 효과를 분석하기 위해서는 기포발생물질과 기포항적 모델 외에도 매우 많은 구성모델이 필요하다.
#   - 기포발생물질에 의해 생성된 기포항적은 실해역 실험을 통해 항적추적어뢰 기만에 필요한 충분한 산란강도를 가지는 것을 확인하였으며, 기포 분포에 대한 3차원 영상화를 통해 기포항적 발달 전주기를 가독성있게 관찰할 수 있었다.
#   - 그림 12는 특정 조건에서의 어뢰대응 상황에 따른 기만 효과를 보여주는 일례이다.
#   - [그림 12] 어뢰 대응상황에 따른 기만 효과 분석 예제 본 연구를 통해 구축된 기만 효과도 모델은 다양한 시나리오 환경에서 기만 효과도를 예측할 수 있기 때문에 시험개발 또는 체계개발 시 체계사양 도출을 위한 도구로 활용 가치가 클 것으로 기대된다.
#   - 수상함의 경우 운동모델 및 어뢰 경보거리를 초기변수로 적용하였고, 수중 유도무기는 탐색방식, 운동모델, 초기발사조건 등을 초기변수로 적용하였다.
#   - 수상함과 수중 유도무기, 기만기에 대한 시나리오 조건을 설정하고, 해양환경에 따라 임의적으로 달라질 수 있는 조건을 확률적 변수로 적용하여 항적추적어뢰 공격에 대한 기만 성공률을 반복적으로 도출하였다.
#   - 본 연구를 통해 확보한 핵심기술은 후속 개발될 항적추적어뢰 기만기체계 개발에 적극 활용되어, 한국 해군 수상함의 생존력 증대에 기여할 수 있기를 기대한다.
#
# 장갑차 (6건):
#   - (그림 3 참고)가상모의 시뮬레이터의 경우, 공수강하시뮬레이터, 상륙돌격장갑차 KAAV 시뮬레이터, 합동화력 시뮬레이터, KUH-1 시뮬레이터 등과 같은 다양한 시뮬레이터를 보유하고 있으며 이는 실제 장비와 유사한 환경에서 해당 체계를 운용하는 훈련여건을 제공하며 경제적인 훈련이 가능한 시스템이다(그림 4&5 참고).
#   - 해병대의 경우도 그와 유사하게 공수강하시뮬레이터, 상륙돌격장갑차 KAAV 시뮬레이터, 합동화력 시뮬레이터, KUH-1 시뮬레이터 등과 같은 다양한 시뮬레이터를 보유하고 있으나 이것들은 개별 체계의 숙달 훈련 위주로 활용되고 있다.
#   - 무인포탑 기술은 미래의 유사체계(전차, 장갑차, 자주포, C-RAM)의 자동화 포탑 모듈 개발에 활용 가능한 장점이 있다.
#   - 포탄 적재이송 자동화 기술탄약운반장갑차인 K56과 K10에 적용된 탄압지(Grip) 기술과 포탄 적재이송장치의 기구메커니즘 활용이 가능할 것이다.
#   - [그림 7] M1299 차세대자주포국내의 경우는 1999년 12월에 K9자주포가 전력화된 후, K10 탄약운반장갑차가 2006년에 개발되었고, K55자주포와 K9자주포 성능개량(PIP11)) 사업으로 K55A1, K9A1이 각각 개발되었다.
#   - 목적은 사거리 증가, 경량화, 정확도 향상, 발사속도 증대이며, 주요연구분야는 무장 경량화와 크기 축소를 위한 소재 개발, 탄약 취급의 자동화를 통한 발사속도 향상과 탄약 재보급 및 관리 능력의 향상, 추진제 개선을 통한 포구초속 증가, 마모 감소, 압력 감소 및 둔감화 성능 확보, 탄약(탄체, 회전탄대/밀폐링) 개선을 통한 중량 감소, 파편 효과 증대 및 정확도 향상 등을 제시하고 있으며, 브래들리(Bradley) 장갑차 차체를 공용으로 사용하여 군수지원성도 높이고 있다.
#
# 장사정포 (3건):
#   - 북한 장사정포 위협 등 북한 대비 수적 열세인 포병화력 증강과 미래 지상군의 작전수행개념인 네트워크 기반하의 합동작전 수행과 효과 중심의 작전 수행을 위해서는 포병의 표적획득, 지휘통제 및 타격 능력 등 각 분야의 능력 보강이 필요하며, 탐지-타격(Sensor to Shooter) 연동과 정밀탄약을 이용한 포병의 적시 정밀타격능력 확보가 긴요한 사항임에는 틀림없다.
#   - 2006년에는 서울 불바다 발언으로 인한 장사정포대응 무기체계개선 TF15)가 구성되었고, 연구결과에 따라 ‘K9 전자신관 적용 사통장치체계 개선’을 수행하여 현재 K9A1 성능개량 자주포에 적용하고 있다.
#   - 우리나라 수도권의 최대 위협으로 간주되는 북한의 장사정포인 170mm M1989 자주포와 240mm M1991 방사포의 경우 사거리가 60km에 달하여, 70km이상의 초장사정 포탄 개발이 시급한 실정이다.
#
# 전략 폭격기 (1건):
#   - 미 항공모함 및 함정 격침을 목표로 하며, 향후 핵잠수함, 전략 폭격기, 스텔스 폭격기에도 장착할 예정이다.
#
# 전익기 (1건):
#   - 90년대 후반 미국에서도 유사 기능의 상태감시 시스템을 허니웰(Honeywell)에서 개발하여 육군 회전익기(UH-60, AH-64, CH-47D)에 장착하였다.
#
# 전자전기 (9건):
#   - 또한, 2014년도 이후부터는 중국, 구·소련, 러시아의 무인기를 변형하거나 복제한  모델을 이용한 북한 소형무인기의 침범이 다수 발생하고 있어, 중국의 스텔스 무인기를 이용한 한반도 상공 정찰, 중국의 항공 유인 전자전 무기체계는 한반도주변 에서 자주 목격되고 있는 정찰기와 전자전기로 대표된다.
#   - 중국은 2010년 시안 항공사에서 Y-8 을 대체하기 위한 용도로 Y-9 수송기를 개발하여 공개한 이후, 육·해·공군에서 Y-9을 다양한 용도(수송기, 정찰기, 전자전기 등)로 개조하여 운용중 이다.
#   - 미 공군은 C-130H 수송기를 개조해 각종 센서 및 전자전 장비를 장착하여 통신용 원격전자전기 EC-130H(Compass Call)을 개발하여 운용중이다 (1982년 실전배치).
#   - [그림 25] 미국 우주군 위성 탑재 재머 개념도[그림 26] 고출력 슈퍼 재머 개념도[그림 28] 원격지원 전자전기(SOJ)개념도[그림 29] 신호정보정찰위성 개념도[그림 27] 미 우주군의 고출력 통신재머적 위성 대응 방안으로 저궤도 위성 및 무인기에 탑재하여 운용되는 재머를 개발하는 방안이 있다.
#   - 그림 28은 원격지원 전자전기의  운용개념을 보여준다.
#   - 전략급 작전 수행 간 합동 전력의 생존성 보장 및 작전 성공율· 효율성 향상을 위해서는 공세적 광역교란을 위한 원격 지원 전자전 능력이 반드시 요구되며, 미국 등 국방 선진국 에서는 EC-130H 등의 원격지원 전자전기를 개발 및  운용하고 있다.
#   - 원격지원 전자전기는 기존 자체보호 전자전장비와 호위용 재머와는 달리 수백km 에 달하는 신호정보 정찰 및 교란능력을 갖출 수 있는 전자전 무기체계 이다.
#   - 따라서, 원격지원 전자전기 보유는 수동적인 방어 에서 벗어나 능동적이며 공세적인 광역 전자교란을 통해 한반도 주변에서 전장 주도권을 확보할 수 있게 해주며, 잠재적 위협국에 대한 최선의 방어이자 공격이 가능한  무기체계라 판단된다.
#   - 현재, 중국 육군은 Y-9 항공기를 수송기, 공군 및  해군은 전자전기 용도로 개조하여 운용 중인 것으로  파악되고 있다.
#
# 정찰기 (19건):
#   - 하지만, 이스라엘의 ELTA, IAI, Rafael 사의 장비에 의존하여 RF-16펠콘 유인정찰기, 송골매 무인정찰기, P-3C 성능개량기 등을 운용하였다.
#   - 또한, 2014년도 이후부터는 중국, 구·소련, 러시아의 무인기를 변형하거나 복제한  모델을 이용한 북한 소형무인기의 침범이 다수 발생하고 있어, 중국의 스텔스 무인기를 이용한 한반도 상공 정찰, 중국의 항공 유인 전자전 무기체계는 한반도주변 에서 자주 목격되고 있는 정찰기와 전자전기로 대표된다.
#   - 적 정찰기 KADIZ 침범은 영공 침범이 아니므로 잡음 재밍으로 운항을 방해한다면 국제 분쟁으로 이어질 가능성도 배제할 수 없다.
#   - “위성항법장치 수신기 교란기술” 은 크게  두 종류로 나뉘는데, “잡음재밍” 을 통해 위성신호 수신을  전체적으로 방해할 수 있으며, 다음으로, “기만재밍(스푸핑)” 을 수행하여 적 정찰기가 잘못된 위성신호를 수신하게 함으로써, 정상운항을 방해 할 수 있다.
#   - 3) GNSS 수신기 기만을 통한 정찰기 운항 방해보다 공세적인 방안으로는 중국 정찰기에 사용되는 위성항법장치(GNSS, Global Navigation Satellite System) 수신기를 전자파로 교란하여 정찰기의 운항을 방해하는  방법이 있다.
#   - 그림 21은 적 정찰기에 대응하기 위한 위성항법수신기 기만 재머 형상(예)과 기만 재머 예상 위치로써, 해당 재머는 KADIZ 침범 경로주변에 배치되어야할 것이며, 기만  재머의 성능은 정찰기 종류, 접근 거리, 고도, 탑재된 항법수신기 등의 제원에 따라 결정될 수 있으리라 판단된다.
#   - 국방과학기술플러스 +14해당 개념의 원격운용 디코이는 평시 및 전시에 모두  운용될 수 있으리라 사료되며, 평시에는 중국 정찰기  출현 시 허위 레이더 신호를 송출하여 신호수집을 방해 하거나 오정보 수집을 유도할 수 있으며, 전시에는 주변국 대방사 미사일 대응을 위한 디코이(유인체)로 활용되어 아군 조기경보 레이더 및 지대공 미사일 기지를 보호할 수 있다.
#   - 무인기 테러 사례1) 디코이 이용 신호수집 방해KADIZ를 침범하는 중국 정찰기의 주요 목적은 한반도內 레이더 등 방공망의 신호정보를 수집하는 것으로  추정되고 있다.
#
# 정찰위성 (19건):
#   - 2월에 미 해군도 함정발사용 미사일(RIM-161 SM-3)을 발사하여 고장 상태로 궤도를 돌고 있던 자국의 한 정찰위성(USA-193)을 요격하는 데 성공하였다.
#   - [그림 25] 미국 우주군 위성 탑재 재머 개념도[그림 26] 고출력 슈퍼 재머 개념도[그림 28] 원격지원 전자전기(SOJ)개념도[그림 29] 신호정보정찰위성 개념도[그림 27] 미 우주군의 고출력 통신재머적 위성 대응 방안으로 저궤도 위성 및 무인기에 탑재하여 운용되는 재머를 개발하는 방안이 있다.
#   - 대표적으로 감시정찰위성 KeyHole 시리즈[ 5 ] 를 美국가정찰국( N RO ;  N a t i o n a l Reconnaissance Office)에서 운용하고 있다.
#   - 예를 들면 지구의 특정 지역을 항상 유지해야 하는 임무를 지닌 통신위성의 경우에는 정지궤도(GEO, Geostationary Orbit)에서 운용되고, 지구를 촬영하고 관측하기 위한 지구관측위성과 정찰위성은 센서 해상도와 밀접한 관계가 있으므로 주로 저궤도(LEO, Low Earth Orbit)에서 운용되고, 지구 전역을 돌면서 넓은 지역을 커버해야 하는 항법위성은 중궤도(MEO, Medium Earth Orbit)에서 운용된다.
#   - 저궤도 군 정찰위성 체계는  다수의 SAR위성체, EO/IR위성체를 이용하여, 관심지역의 전략 표적에 대한 감시 및 정찰을 수행하며 전천후 영상 정보를 획득하는 체계이다(그림 22).
#   - 잠재적  위협에 대비하여 고성능 군 정찰위성과 초소형 저가 감시 위성을 상호 보완적 운용을 통하여 감시.
#
# 지뢰 (23건):
#   - 50 ▒ 국방과학기술플러스 +하지 착용로봇 기술 외에도 국방과학연구소에서는 임무 특화 상지 기술로, 1) 임무장비를 어깨에 보다 쉽게 견착할 수 있는 무동력 임무장비 견착 모듈 및 2) 지뢰탐지 작업 보조를 위한 무동력 팔 근력보조 모듈에 대한 연구를 수행하였다.
#   - [표 6] 지뢰탐지 근력보조 모듈 성능시험 결과CaseCase 1(근력보조 없는 경우)Case 2(근력보조 모듈을 사용할 경우)근전도신호(%MVC)삼두근6.
#   - [표 8] 군용 드론의 용도별 분류(안)[11]구분용도내  용무기체계정찰용- 원거리, 근거리 정찰- 초소형, 수직이착륙형 등공격용- 자폭, 폭탄투하, 소총, 유탄발사 - 군집형 공격 등특수목적용- 통신중계, 지뢰/폭발물 탐지- 화생방, 안티, 전자전 등전력지원체계감시지원용- 경계 및 감시 작전 지원작전지속지원용- 수송, 구난, 방역, 소방- 맵핑, 조명, 영상촬영 등교육훈련용- 교육, 방공표적추적- 전투실험 등 중점 추진해야할 분야로 두 가지 예를 들자면, 첫 번째로는 ‘군집형’ 자율드론이다.
#   - 지뢰탐지병사가 제안된 팔 근력보조 모듈을 이용하면 지뢰탐지기 운용 중 근육력 및 사용에너지가 감소되어 지뢰탐지 임무시간이 상당히 연장될 것으로 기대된다.
#   - 화생무기 폐기시스템 기술 동향대량살상무기 제거를 위한 화생무기 폐기기술국방과학연구소 Chem-Bio기술센터 책임연구원 김현석개요국방과학기술플러스 +1화생무기 폐기시스템 기술 동향화생무기는 독성의 화생물질과 이들을 투발하기 위한  포탄, 미사일, 지뢰 등의 투발 수단을 총칭한다.
#   - 지뢰탐지 작업 보조 착용 모듈은 지뢰탐지기 (무게: 4kg) 운용 병사의 집중도 향상 및 작업효율 증대를 위해, 지뢰탐지병사 하박에 부착되어 팔 근육 힘을 보조해 줄 수 있도록 무동력 타입으로 현재 개발 중이다.
#   - 개발된 팔 근력보조장치를 착용한 후 지뢰탐지동작을 수행할 경우 이두근의 근활성도가 75% 감소되었다.
#   - 근전도신호를 이용하여 지뢰탐지병사 보조를 위해 제작된 팔 근력보조 모듈 착용 유무에 따른 효과도를 분석하였다.
#   - 또한 DMZ 일대 유해발굴 작업을 동시에 진행해야함을 고려하여 현재는 병사에 의해 직접 지뢰탐지/제거 작업이 진행되고 있다.
#   - 물론 개척전차 또는 폭파에 의해 지뢰제거 작업 속도를 증대시킬 수 있지만 이는 환경 파괴를 초래할 수 있다.
#   - 팔 근력보조 모듈 없이 통상적인 지뢰탐지동작을 하는 경우 다른 근육 대비 이두근이 가장 많이 활성화되었다.
#   - DMZ 일대에는 약 200만개의 지뢰가 묻혀있을 것이라 추정되며 이를 지뢰탐지병사들이 완전히 제거하기 위해서는 200년 이상 시간이 소요된다고 보고되었다.
#   - 국방과학연구소는 지뢰탐지병사 팔 근력보조를 위하여 그림 15와 같은 무동력 팔 근력보조 모듈을 개발하고 있다.
#   - 현재 우리나라에서는 남북경협 활성화를 준비하기 위하여 DMZ 일대 지뢰탐지/제거 필요성이 대두되고 있다.
#   - 임무유형별 군사용 착용로봇 플랫폼 개발동향 ▒ 47[그림 15] 지뢰탐지 근력보조를 위한 착용형 근력보조모듈 구성 및 형상2) 핵심기술지뢰탐지기 무게보조를 위한 팔 근력보조 모듈은 크게 동작구현부와 중력보상부로 구성된다.
#   - 지뢰탐지 병사는 약 4kg 정도 무게의 지뢰탐지기를 들고 임무를 수행하는데, 고도의 집중력이 요구되는 지뢰탐지 작업동안 팔에 집중되는 지뢰 탐지기 부하는 팔 근육의 피로도 발생을 가속화하여 약 20분 이상 작업을 지속하지 못하게 한다.
#   - 동작구현부는 지뢰탐지병사가 지뢰탐지기를 좌우로 스위핑 (sweeping)하는 동작을 구현한다.
#   - 대신 지뢰탐지기 무게 지지는 등쪽에 위치한 중력보상부에서 담당한다.
#   - 지뢰탐지기 하단 구조물을 볼 조인트 끝단 홀에 삽입하는 간단한 조작으로 지뢰탐지기를 장착할 수 있으며, 볼 조인트 회전 운동에 의해 탐지 작업 시 지뢰탐지기 자세를 미세 조정할 수 있도록 설계하였다.
#   - 모션캡쳐시스템을 이용하여 획득된 지뢰탐지 병사의 운동데이터를 이용하여 그림 16에 제시된 것처럼 중력보상 요구 토크를 분석하였다.
#   - 이를 위해 그림 17에 제시된 것과 같이 지뢰탐지기를 운용하는 팔 주요 근육에 근전도센서를 부착하였다.
#   - 실험은 1) 팔 근력보조 모듈 없이 통상적인 지뢰탐지동작을 하는 경우, 2) 팔 근력보조장치 착용 후 근력보조를 받으며 지뢰탐지동작을 하는 경우, 2가지 경우에 대해서 진행하였다.
#   - 지뢰탐지 근력보조 모듈1) 개요국방과학연구소는 2019년부터 민군기술협력사업을 통해 지뢰탐지 병사의 근력보조를 위한 엑소수트 시스템을 개발하고 있다.
#
# 천궁 (1건):
#   - SM-3, GBI(Ground Based Intercepter)는 중간단계, 천궁-II, 사드(THAAD), 패트리어트(Patriot)는 종말단계 미사일 방어에 해당한다.
#
# 프레데터 (3건):
#   - [9] 미국 CSIS 보고서는 프레데터 감시정찰 무인기를 이용하여 500km 거리에서 15초 만에 탄도미사일을 탐지 가능함을 인용하고 있다.
#   - 앞서 설명한 기능을 지원할 수 있는 잠재적인 UAV 원격측정 플랫폼은 글로벌 호크, 프레데터, 록히드 마틴의 Structure Blimp 통합 센서 등이 있다.
#   - 프레데터(미국) 복사판으로 알려진 Yi Long 는 2013년 파리 에어쇼에서 처음 공개 되었다.
#
# 함포 (7건):
#   - 한편, 2003년 9월에는 미국 뉴멕시코주 White Sand 시험장에서는 5인치 함포탄인 B-TERM(Ballistic Trajectory Extended Range Munition)으로 100.
#   - 미국의 ATK 社는 해군용 5인치 함포탄인 B-TERM(Ballistic Trajectory Extended Range Munition) 탄을 개발한 바 있는데, 텅스텐 케이스로 제작된 탄두와 저가형 유도항법장치를 채택한 것으로 알려져 있다.
#   - 5인치 MK 45 함포와 155mm AGS(Advance Gun System)에서는 사거리가 각각 41NM, 40NM로 각각 75.
#   - 스웨덴에서는 PzH2000 자주포(독일제)와 해안감시 레이더를 연동하여 해상 이동표적 제압 가능성을 시험하였고, 흑해연안에 전력화 배치된 러시아의 A-222E BEREG-E 해안포의 경우는 130mm 함포를 8×8 트럭에 탑재한 자주포와 사격통제장치 세트(탐지/사격통제 레이더+EOTS7)+사통컴퓨터)를 탑재한 사격지휘차를 연동하여 탐지거리 35km, 유효사거리 20km, 4개 표적 사격제원 계산 및 2개 표적 동시 교전 가능, 발사속도 10발/분의 성능으로 신속하고 효율적인 해안방어 수단으로 개발한 바 있다.
#   - 또한 이 탄은 고정표적은 물론 이동표적에 대해서도 사격이 가능하며, 사격이후 표적변환이 가능하며, 5인치 함포에서는 100km, 155mm 야포에서는 85km의 사거리를 갖는다고 소개하고 있다.
#   - Excalibur S를 함포에도 적용 가능한 127mm Excalibur N5를 개발 중이다.
#   - 미국의 155mm AGS(Advanced Gun System) 함포의 경우는 사격통제 장치와 완전 자동화된 탄/장약 이송/장전 장치를 이용하여 빠른 반응성과 높은 생존성을 가지는 무인 포탑을 채택한 사례이다.

# %% [markdown]
# # 전처리4 : 연속된 공백이 너무 긴 경우 제거

# %%
weapon_ex = pd.read_csv('/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/test.csv')
weapon_ex.head()

# %%
weapon_ex = pd.read_csv('/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/test.csv')

def filter_examples(terms, examples,
                    max_run: int = 20, max_space_run: int = 5, max_len = 100) -> dict[str, list[str]]:
    matched_dict = {}
    for term in terms:
        pattern = re.compile(r'(?<!\d)' + re.escape(term) + r'(?!\d)')
        filtered = []
        for ex in examples:

            # 1) 용어 매칭
            if not (pattern.search(ex)) :
                continue

            # 2) 줄바꿈 검사
            if "\n\n" in ex:
                continue

            # 3) 최대 길이 검사
            if len(ex) > max_len :
                continue

            # 4) “긴 무공백 구간” 검사
            runs = re.findall(r'[가-힣A-Za-z0-9]+', ex)
            if any(len(run) > max_run for run in runs):
                continue

            # 5) 연속된 공백 찾기
            if ' ' * max_space_run in ex:
                continue

            # 6) **‘다.’ 로 끝나지 않는 문장 제외**
            if not ex.strip().endswith("다."):
                continue

            filtered.append(ex)


        # 4) 순서 유지하며 중복 제거
        matched_dict[term] = list(dict.fromkeys(filtered))

    return matched_dict

# %%
all_examples = []
for row in weapon_ex['example']:
    try:
        all_examples.append(row)
    except:
        continue

# 2) terms 불러오기
terms = weapon_ex['term'].unique().tolist()

# 3) 필터링 수행
filtered_dict = filter_examples(terms, all_examples, max_run=20, max_space_run= 3,max_len = 200)

# 4) 중복값 제거
for term, exs in filtered_dict.items():
    # dict.fromkeys 이용해 순서는 유지하되 중복 값은 하나만 남김
    filtered_dict[term] = list(dict.fromkeys(exs))

# %%
have_example_term = [term for term, exs in filtered_dict.items() if exs]
print(have_example_term) # 용례가 있는 용어
num_terms_with_examples = sum(1 for exs in filtered_dict.values() if exs)
num_examples_with_examples = sum(len(exs) for exs in filtered_dict.values() if exs)
print(f"용례가 있는 용어의 개수: {num_terms_with_examples}개") # 33개로 감소(37개 -> 35개->32개)
print(f"총 용례의 개수: {num_examples_with_examples}개") # 190개로 감소(236개->232개->205개->167개)
# Out:
# ['5세대 전투기', 'F-2', 'J-20', 'P-3C', 'SM-3', 'T-50', '견인포', '공격기', '공대공 미사일', '기뢰', '대륙간탄도미사일', '대포병 레이더', '독도함', '랴오닝호', '무인전투기', '미사일 방어체계', '비살상무기', '사드', '상륙돌격장갑차', '알레이버크급 구축함', '어뢰', '장갑차', '장사정포', '전략 폭격기', '전익기', '전자전기', '정찰기', '정찰위성', '지뢰', '천궁', '프레데터', '함포']
# 용례가 있는 용어의 개수: 32개
# 총 용례의 개수: 167개

# %%
# 결과 확인
for term, exs in filtered_dict.items():
    if exs:
        print(f"{term} ({len(exs)}건):")
        for ex in exs:
            print("  -", ex)
        print()
# Out:
# 5세대 전투기 (1건):
#   - ■ PL-10 (중국)중국에서 2004년부터 5세대 전투기용으로 개발한  5세대 단거리공대공유도탄이다.
#
# F-2 (1건):
#   - 장착기종 으로 F-2, F-15J, F-4EJ에서 운용 중이며, 정밀도 높은 RLG(Ring Laser Gyro) IMU를 탑재하여 LOAL 모드 운용이 가능하다.
#
# J-20 (1건):
#   - 중국의 최신전투기인 J-10, J-11, J-20, FC-31 전투기에 장착 예정이며  수출용 버전인 PL-10E도 개발하였다.
#
# P-3C (1건):
#   - 하지만, 이스라엘의 ELTA, IAI, Rafael 사의 장비에 의존하여 RF-16펠콘 유인정찰기, 송골매 무인정찰기, P-3C 성능개량기 등을 운용하였다.
#
# SM-3 (3건):
#   - SM-3, GBI(Ground Based Intercepter)는 중간단계, 천궁-II, 사드(THAAD), 패트리어트(Patriot)는 종말단계 미사일 방어에 해당한다.
#   - 탄소섬유 기반 초고온 내열/내산화 복합소재 기술  	 1	개요초고온 내열 복합소재는 위에 대표 그림에서 나타나 있는 것과 같이 사드(THADD)와 유사한 유도탄 방어무기체계(SM-3)에 필수 핵심부품 소재이다.
#   - 2월에 미 해군도 함정발사용 미사일(RIM-161 SM-3)을 발사하여 고장 상태로 궤도를 돌고 있던 자국의 한 정찰위성(USA-193)을 요격하는 데 성공하였다.
#
# T-50 (2건):
#   - 최근의 또 다른 사례로는 한국항공우주산업주식회사(KAI)의 T-50 항공기 개발이라 할 수 있다.
#   - T-50 항공기 개발비는 약 2조원이었으며, 그 중 10%인 200억을 종합군수지원(IL그렇기S) 개발 비용으로 사용하였기에 후속군수지원을 지속적으로 가능하게 하면서 아랍에미리트와의 수출협상 시 한국 정부차원의 안정적 후속 군수지원 보장에 대한 요구를 충족하게 되며 큰 호평을 받고 있다.
#
# 견인포 (2건):
#   - 1992년 개념에 대한 최초 입증 후, 2005년에는 화포용 레이저 점화장치(DPLIS16))를 개발하였으며, 개발기간동안 기존 자주포와 견인포에 적용하여 약 25,000발의 실 사격을 수행한 바 있다.
#   - 미래 포병이 지향하는 방향에 맞추어 국외의 최근 개발동향을 살펴보면, 각국의 전술환경변화를 고려한 소요에 따라 견인포의 차량탑재형을 개발하는 등의 개량형의 개발이나, 기존의 자주포 기술을 활용한 다양한 목적의 체계를 창출하여 제안하고, 소요를 확대할 수 있는 원격무인 포탑, C-RAM1)용 포탑 등을 연구하고 있다.
#
# 공격기 (1건):
#   - Yi Long은 전형적인 무인 공격기로 공대공 미사일, 레이저 유도탄, 대인폭탄, 50kg 소형 유도탄 등을 장착할 수 있다.
#
# 공대공 미사일 (1건):
#   - Yi Long은 전형적인 무인 공격기로 공대공 미사일, 레이저 유도탄, 대인폭탄, 50kg 소형 유도탄 등을 장착할 수 있다.
#
# 기뢰 (5건):
#   - 2008년부터 2년 동안 개념연구 형태로, 노르웨이 FFI와 함께 착저 잠수함 또는 기뢰 탐지를 위한 기술개발 과제를 수행하였다.
#   - Orca XLUUV의 주요특징은 전투 임무를 수행할 수 있는 기뢰모듈을 탑재하고 있으며, 수상감시정찰을 위해 마스트에 광학 장비를 탑재한 것을 알 수 있다.
#   - 군사목적으로 전력화 되어 있는 무인잠수정은 측면주사소나(Side Scan Sonar, SSS)를 탑재하여 해저기뢰탐색을 위해 활용되거나, 잠수함의 대잠전 훈련을 위해 소음을 방사/모의 할 수 있는 센서를 탑재하여 활용되고 있다.
#   - 무인잠수정 임무2004년 미 해군에서 발표한 UUV Master Plan에서는 무인잠수정의 주요 임무를 정보/감시/정찰, 대기뢰전, 대잠전, 조사/식별, 해양조사, 통신/항해 네트워크, 적재물 운송, 정보작전 그리고 적기신속타격으로 총 9가지로 분류하였다.
#   - 함정의 임무영역을 표현하는 운용성능은 그림 2와 같이 대공전, 대잠전, 대수상전, 기뢰전과 같은 주 임무수행  영역과 이를 가능케 하는 공격능력, 방어능력, 기동, 지속능력 등의 능력요소로 이루어진다.
#
# 대륙간탄도미사일 (2건):
#   - 이 기술은 대륙간탄도미사일(ICBM) 개발도 가능한 수준인 것으로 평가된다.
#   - 아방가르드는 러시아의 대륙간탄도미사일 탑재 극초 음속 활공체로, 최고속도 마하 27로 활공하며 별도의 추진기관이 없는 순수한 활공체이다.
#
# 대포병 레이더 (1건):
#   - 육군의 ISTAR3) 능력 보강, 대포병 레이더 보강, MET4)(기상) 장비 보강, 정밀타격능력 보강, C4I5) 능력 보강, 플랫폼 개선 등을 제시하고 있다.
#
# 독도함 (1건):
#   - 기본형은 현재 해군 상륙함인 독도함에 탑재되어 운용되고  있으며 성능개량형은 레이더 성능을 업그레이드하여  지상용 (SMART-L MM/F) 및 함정용 (SMART-L MM/N)  다중임무 디지털레이더로 개발되었다.
#
# 랴오닝호 (1건):
#   - 중국은 항공모함 랴오닝호에 리젠을  탑재해 미국령 괌 인근까지 감시 정찰에 나설 것으로  예상되고 있다.
#
# 무인전투기 (1건):
#   - 'GJ(攻擊·공지)-11' 스텔스 드론은 미국의 B-2  스피릿 폭격기, 항공모함 베이스의 장거리 무인전투기 X-47B와 비교되고 있다.
#
# 미사일 방어체계 (9건):
#   - 항공기반 방어의 장점  상승단계 탄도미사일 방어를 위해 항공기에 적외선센서와 요격미사일을 장착하여 Sensor-to-Shooter 방식의 미사일 방어체계를 구성하면 상승단계 탄도미사일 방어에 여러 가지 장점이 있다.
#   - 즉, 정지 궤도상의 위성체에 조기경보 IR 탐지장비를 탑재하여, 초기 탄도탄  발사 화염을 탐지하여 식별하고, 지상 조기경보 체계 및  조기경보 레이더에 식별된 정보를 제공하여 신속히 경보  발령을 내리게 하고, 지상 대미사일 방어체계의 신속한 대응 타격을 가능케하며, 나아가서는 탄도탄 발사점 및 탄착점을 예측하는 기능을 갖는다.
#   - 낮은 고도에서의 극초음속 비행은 극초음속 순항미사일이 미사일 방어체계를 침투할 수 있도록 하며, 극초음속 활공체와 달리 종말 단계까지 가속할 수 있어 복잡한 기동에 더욱 유리하다.
#   - 항공기반 상승단계 탄도미사일 방어체계는 북한과 같이 폭이 좁고 긴 지리적 특성이 있는 지역 가까이 접근하여 요격이 이루어지므로 탄도미사일 방어에 효과적인 것으로 이 연구는 결론 내고 있다.
#   - 항공기반 상승단계 탄도미사일 방어체계가 개발되어 기존 중간단계/종말단계 방어에 추가되면 다층방어의 효과를 증대시킬 수 있을 것으로 기대된다.
#   - 반면 탐지센서와 요격미사일을 무인항공기에 통합하여 Sensor-to-Shooter 방식으로 항공기반 탄도미사일 방어체계가 구현되면 탐지부터 요격까지 소요되는 시간을 줄여 대응 능력을 개선할 수 있다.
#   - [그림 20] 항공기반 상승단계 탄도미사일 방어체계다.
#   - 항공기반 탄도미사일 방어체계 구성에 필요한 무인항공기는 적외선센서와 요격미사일을 장착 가능해야 하며 그림20은 이에 따른 개념도이다.
#   - 항공기반 상승단계 탄도미사일 방어체계 구성항공기반 상승단계 탄도미사일 방어체계는 교전시간 확보를 위해 탐지센서와 요격미사일을 장착한 Sen­sor-to-Shooter 방식이 되어야 한다.
#
# 비살상무기 (1건):
#   - 그리고 드론, 전투 차량, 통신 기지국 등 체계를  직접적으로 파괴하지 않으면서 무력화시킬 수 있는 기술이므로 비살상무기로 분류된다.
#
# 사드 (3건):
#   - SM-3, GBI(Ground Based Intercepter)는 중간단계, 천궁-II, 사드(THAAD), 패트리어트(Patriot)는 종말단계 미사일 방어에 해당한다.
#   - 탄소섬유 기반 초고온 내열/내산화 복합소재 기술  	 1	개요초고온 내열 복합소재는 위에 대표 그림에서 나타나 있는 것과 같이 사드(THADD)와 유사한 유도탄 방어무기체계(SM-3)에 필수 핵심부품 소재이다.
#   - 무선기기가 폭증함에 따라 전자파에 대한 관심이 높아지고 이에 대한 우려로 인해서 사회적으로 과도한 비용이 발생하고 있으며, 기상청 레이다 논란, 해상관제용 레이다 논란, 사드 논란 등 전자파 영향 여부를 둘러싼 진실 공방으로 사회적 갈등이 확산되고 있다.
#
# 상륙돌격장갑차 (1건):
#   - 해병대의 경우도 그와 유사하게 공수강하시뮬레이터, 상륙돌격장갑차 KAAV 시뮬레이터, 합동화력 시뮬레이터, KUH-1 시뮬레이터 등과 같은 다양한 시뮬레이터를 보유하고 있으나 이것들은 개별 체계의 숙달 훈련 위주로 활용되고 있다.
#
# 알레이버크급 구축함 (1건):
#   - 55m, 무게는 50kg, GPS/INS 유도항법 기능을 갖고  있어, CEP 20m의 정확도 사격이 가능한 것으로 알려졌고, 알레이버크급 구축함에서 발사하여 최대 110km 떨어진 지상표적 타격이 가능한 것으로 알려졌다.
#
# 어뢰 (55건):
#   - 국방과학연구소(해양기술연구원)에서는 이 QUEST 프레임워크를 이용하여 국과연 주관 연구개발 체계인 함정전투체계, 어뢰체계, 음탐기체계 등의 개발 과정에서 어뢰전/대어뢰전/대잠전 모델을 개발하고 효과도분석, 전술 개발 등에 적용하고 있다.
#   - 이때 만재 배수량 = 베이스 중량 + 조합에 참여하는 구성요소 중량 + 기타 중량 (유형1의 예제에서는 경어뢰와 중어뢰 관련 시스템과 무장의 중량)이다.
#   - 이 예제에서는 운용개념 분석을 통해 임무수행 영역을 대잠전, 대어뢰전, 대함전, 대공전으로 분류하고  각각의 수행영역에 8, 8, 5, 6개의 탑재체계 대안을 상정한다.
#   - 또한 함정내 탑재장비, 유도무기, 어뢰와 같은 실물장비를 자주 접하지 못하는 고가의 장비일수록 더욱 교육훈련이 중요하기에 대체재로서 가상교육훈련장비의 구축 및 운용이 필요하다.
#   - 해당 순항 속도에서는 초공동 어뢰의 운동으로 인해 초공동 어뢰 입구에서 약 50bar에 이르는 고압으로 해수를 흡입하게 되며, 흡입된 해수는 해수흡입 연소기의 인젝터와 수반응 추진제 이송을 위한 피스톤으로 공급된다.
#   - 이러한 문제를 보완하기 위하여 그림 1과 같이 중요한 시설 보호를 위하여 고정식 발사 플랫폼을 활용하거나 수상함에서 발사하는 개념이 제안되고 있으며, 이란의 초공동 어뢰인 후트(Hoot)의 경우 수상함에서 시험 발사하는 장면을 확인할 수 있다.
#   - 하지만 이러한 초공동 어뢰의 경우 소음이 크고, 상대적으로 사거리가 짧으며 유도기능이 제한적이라는 단점이 존재한다.
#   - Mg/NaNO3 추진제는 전통적인 조명제의 조성으로 러시아와 이란을 제외하고 초공동 어뢰에 적용한 사례가 없으며, 금속연료 추진제를 대형으로 제작하는 관련 기술도 공개되어 있지 않다.
#   - 개발기관인 DIEHL BGT Defence에 의하면 바라쿠다는 수중 및 수상의 타켓뿐만이 아니라 러시아에서 운용하고 있는 쉬크발 어뢰를 직접적으로 요격이 가능하다고 공개하였다.
#   - 독일  1988년 독일은 초공동화연구를 시작하여 최근까지 최대속력 400km/h 이상을 만족하는 바라쿠다(Barracuda) 어뢰를 개발중에 있다.
#   - 순항 심도에 도달한 초공동 어뢰는 시동부스터를 점화하여 순항 속도인 100m/s까지 가속한다.
#   - 초공동 어뢰는 발사관에서 발사된 후, 사출모타를 통해 초기 가속되며 순항 심도까지 이동한다.
#   - 사출모타는 작동 후 어뢰로부터 분리된다.
#   - 러시아서두에 언급한 바와 같이 해수흡입 추진기관을 초공동 어뢰에 적용한 사례는 러시아의 쉬크발이다.
#   - 러시아(구 소련)는 미국의 고속 원자력 잠수함과의 교전과 항공모함을 공격하는 목적으로 초공동 어뢰 개발에 착수하였다.
#   - 1960년대에 쉬크발(Shkval)이라는 명칭으로 개발을 시작하였으며, 약 200노트(370km/h)의 속력으로 바닷속에서 항주가 가능하여 기존 어뢰 대비 4~5배의 빠른 속력으로 알려져있다.
#   - 이란  이란은 2006년 4월 2일과 3일 양일에 걸쳐 자체개발 초공동 어뢰인 후트의 발사시험을 진행하였고 성공적으로 목표물에 타격했다는 영상을 공개하였다.
#   - 러시아의 초공동 어뢰인 쉬크발(Shkval)의 경우 초공동 현상 발생장치와 해수흡입 추진기관을 조합하여 약 200노트의 속도를 내는 것으로 알려져 있다.
#   - 더불어 2004년도에는 새로운 초공동 어뢰개발을 착수하였으나 뚜렷한 프로젝트의 성과는 보여주지 못하고 있다.
#   - 4mm/s의 고연소속도를 갖기 때문에 초고속 어뢰용 금속연료 추진제로 적용 가능할 것으로 판단된다.
#   - 셋째, “기포항적 생성 모델링 기술”은 측정된 자료를 모델화하여 항적추적어뢰 기만 효과 분석하기 위한 기술로, 기만 효과에 필요한 구성 모델을 연구하고 통계학적 방법으로 항적추적어뢰에 대한 기만 효과를 분석하는 기술이다.
#   - 본 소개글에서는 항적추적어뢰 항적탐지 기능에 대해 기만 능력을 가지는 기포항적 생성기술 확보를 위해 요구되는 세 가지 핵심기술에 관하여 보다 자세하게 살펴보고자 한다.
#   - 항적추적어뢰의 공격을 효과적으로 방어하기 위해서는 원하는 심도에서 원하는 크기를 가지는 기포를 원하는 시간 내에 발생시켜야 한다.
#   - 기포특성 측정 기술제조된 기포발생물질이 항적추적어뢰의 공격을 기만할 수 있는 지의 여부를 판단하기 위해서는 기포발생물질에 의해 생성되는 기포항적의 음향학적 특성과 분포학적 특성을 측정할 필요가 있다.
#   - 본 연구팀에서는 항적추적어뢰의 항적탐지 기능에 대해 기만 능력을 가지는 기포항적을 생성시키기 위하여 필요한 3가지 핵심 기술을 다음과 같이 식별하였다.
#   - 대규모의 기포항적을 대상으로 측정된 음향학적, 분포학적 특성을 측정하고 분석함으로써, 제조된 기포발생물질의 조성이 항적추적어뢰 기만 효과가 있는지를 최종적으로 확인하였다.
#   - 또한 기포항적 기만 시 수상함 회피기동 여부, 음향기만기 사용 여부 및 종류, 개수 등과 어뢰 경보거리, 어뢰 및 수상함 속도, 계절, 해역 등 다양한 변수를 복합적으로 동시에 고려하여야 한다.
#   - 본 연구팀은 이를 몬테카를로 방법(Monte-Carlo method)을 통해 항적추적어뢰 공격에 대한 기만 효과를 통계학적으로 분석하였다.
#   - [그림 7] 기포항적 산란강도 도출 결과 예제 기포발생물질 조성, 밀도, 무게, 형상 등 조건에 따른 측정실험을 반복적으로 수행하여, 기포발생물질에 의해 발생되는 기포항적의 산란강도 프로파일 단면을 데이터베이스화하였으며, 최종적으로 항적추적어뢰 탐지기능을 기만하기 위한 효과도 분석 구성모델로 활용하였다.
#   - [그림 10] 기포의 분포 영상화 결과 예제  5  기포항적에 의한 기만 효과 분석 연구제조된 기포발생물질에 의해 발생되는 기포항적의 물리적, 음향적 및 분포적 특성은 수조실험, 호수실험, 해상실험 등 단계적인 검증 실험을 통해 신뢰도 있는 자료를 확보하였으며, 확보된 자료는 최종적으로 항적추적어뢰 공격을 기만하기 위한 효과 분석 모델에 적용하였다.
#   - 본 연구팀은 기포층에 의한 음파 산란, 음파 흡수, 감쇠 및 음속변화 등 기포층의 음향 성능변화에 집중하여 음향탐지 모델 개발에 주력하였으며, 어뢰체계 탐지/로직 등 유사과제 개발 경험을 바탕으로 실제 전장환경에 근사한 기만 효과 구성 모델을 성공적으로 구축하였다.
#   - 따라서, 우리는 대량의 기포항적을 빠르게 생성시킬 수 있을 뿐만 아니라, 항적추적어뢰 기만에 효과적인 크기를 가지는 기포를 발생시키고, 기포의 발생 심도, 생존 시간 등을 제어할 수 있도록 화학물질을 이용하여 기포항적을 생성시키는 방법을 연구하였다.
#   - 3  기술개발에 필요한 핵심기술수상함에서 항적추적어뢰의 공격이 식별되면 어뢰의 추적을 방해하기 위하여 매우 짧은 시간에 충분한 양의 기포항적을 생성시켜야 한다.
#   - 한국 해군이 항적추적어뢰의 위협으로부터 한시라도 빠르게 벗어나기 위해서는 후속 연구수행이 시급히 요구되는 상황이다.
#   - 추진제 이송시스템 개발  해수흡입 추진기관의 경우 어뢰의 속도로 인한 유입되는 유체의 동압을 통하여 유체가 연소기 내부로 분무되고 이를 바탕으로 추진력을 얻는 것으로 알려져 있다.
#   - 이러한 과정을 통하여 도출된 해수흡입 추진기관 기술이 초공동 형성 및 제어 기술과 통합된다면 향후 요격어뢰 혹은 중어뢰 기술 등으로 발전 가능할 것으로 판단되며 추진기관 기술에 대한 개발 뿐 아니라 운용개념 및 적용 체계에 대한 연구 개발이 종합적으로 이루어져야 요소기술이 활용될 수 있는 것으로 판단된다.
#   - 수반응 금속연료 추진제 개발  수반응 금속연료 추진제는 초공동 어뢰의 핵심 구성품으로서, 금속 기반의 연료과농 고체 추진제가 물과 화학반응을 할 때 생성되는 열과 추력을 이용한다.
#   - 따라서 어뢰 체계 요구조건에 따른 수반응 추진제의 연소속도가 해수흡입 추진기관의 핵심기술이라 할 수 있다.
#   - 어뢰 체계의 형상 제한 조건에 따라 수반응 추진제 끝단의 면적은 정해지므로 수반응 추진제의 연소속도가 해수흡입 추진기관의 추력을 결정한다.
#   - 시동부스터는 어뢰를 순항 속도까지 가속시키는 역할과 함께 수반응 추진제를 점화시키는 역할도 동시에 수행하며, 시동부스터의 작동 중단에 따라 연소실로 유입된 해수는 수반응 추진제 연소가스와 반응하여 추력을 발생시키게 된다.
#   - 최근 어뢰는 음향추적 기능과 함께 항적추적 기능을 추가하여 운용한다.
#   - 항적추적어뢰는 항적탐지 기능을 이용하여 수상함 항적을 추적하여 공격하는 어뢰로, 항적이 존재하는 수상함에게는 매우 치명적인 위협을 가하는 수중 유도무기이다.
#   - 항적추적어뢰는 현재 존재하는 기만기 주파수 보다 높은 고주파의 항적탐지기를 이용하여 근접거리의 항적을 탐지하며 추적하기 때문에 현재 개발되어 있는 부유식/자항식 기만기로는 대응이 불가한 것이 현실이다.
#   - 본지에서는 항적추적어뢰를 기만할 수 있는 방법 중 하나로, 그림 1과 같이 인공적인 기포항적을 수상함 항적 인근에 생성시켜 항적추적어뢰의 추적을 방해하는 방법을 소개한다.
#   - 2  기술현황선진국의 어뢰방어체계 기술은 함정의 생존과 직결되는 매우 중요한 기술로써 구체적인 정보의 접근이 제한된다.
#   - 이어 국방과학연구소 해양기술연구원에서는 미사일연구원과 함께 2019년부터 2022년까지 선행핵심 과제를 통해 기포발생물질에 의한 기포발생 기술, 기포특성 측정 기술, 그리고 기포항적에 대한 항적추적어뢰 기만 효과를 분석하는 기포항적 모델링 기술 등 기포항적 생성을 위한 핵심기술을 확보하였다.
#   - 그림 11은 항적추적어뢰가 특정 방위각에서 수상함을 공격하는 특정 시나리오를 가정하였을 때, 기포항적에 의한 기만 효과를 분석한 예제를 보여준다.
#   - 항적추적어뢰가 공격하는 것을 수상함에서 식별하게 되면, 수상함은 회피 기동 및 음향 기만기를 투하하는 등 어뢰공격에 적극 대응하는데, 기포항적을 이용한 기만 대응을 수행함에 따른 아군 수상함 생존률의 변화 정도를 시나리오 조건에 따라 분석하였다.
#   - 항적추적어뢰 기만 효과를 분석하기 위해서는 기포발생물질과 기포항적 모델 외에도 매우 많은 구성모델이 필요하다.
#   - 기포발생물질에 의해 생성된 기포항적은 실해역 실험을 통해 항적추적어뢰 기만에 필요한 충분한 산란강도를 가지는 것을 확인하였으며, 기포 분포에 대한 3차원 영상화를 통해 기포항적 발달 전주기를 가독성있게 관찰할 수 있었다.
#   - 그림 12는 특정 조건에서의 어뢰대응 상황에 따른 기만 효과를 보여주는 일례이다.
#   - [그림 12] 어뢰 대응상황에 따른 기만 효과 분석 예제 본 연구를 통해 구축된 기만 효과도 모델은 다양한 시나리오 환경에서 기만 효과도를 예측할 수 있기 때문에 시험개발 또는 체계개발 시 체계사양 도출을 위한 도구로 활용 가치가 클 것으로 기대된다.
#   - 수상함의 경우 운동모델 및 어뢰 경보거리를 초기변수로 적용하였고, 수중 유도무기는 탐색방식, 운동모델, 초기발사조건 등을 초기변수로 적용하였다.
#   - 수상함과 수중 유도무기, 기만기에 대한 시나리오 조건을 설정하고, 해양환경에 따라 임의적으로 달라질 수 있는 조건을 확률적 변수로 적용하여 항적추적어뢰 공격에 대한 기만 성공률을 반복적으로 도출하였다.
#   - 본 연구를 통해 확보한 핵심기술은 후속 개발될 항적추적어뢰 기만기체계 개발에 적극 활용되어, 한국 해군 수상함의 생존력 증대에 기여할 수 있기를 기대한다.
#
# 장갑차 (4건):
#   - 해병대의 경우도 그와 유사하게 공수강하시뮬레이터, 상륙돌격장갑차 KAAV 시뮬레이터, 합동화력 시뮬레이터, KUH-1 시뮬레이터 등과 같은 다양한 시뮬레이터를 보유하고 있으나 이것들은 개별 체계의 숙달 훈련 위주로 활용되고 있다.
#   - 무인포탑 기술은 미래의 유사체계(전차, 장갑차, 자주포, C-RAM)의 자동화 포탑 모듈 개발에 활용 가능한 장점이 있다.
#   - 포탄 적재이송 자동화 기술탄약운반장갑차인 K56과 K10에 적용된 탄압지(Grip) 기술과 포탄 적재이송장치의 기구메커니즘 활용이 가능할 것이다.
#   - [그림 7] M1299 차세대자주포국내의 경우는 1999년 12월에 K9자주포가 전력화된 후, K10 탄약운반장갑차가 2006년에 개발되었고, K55자주포와 K9자주포 성능개량(PIP11)) 사업으로 K55A1, K9A1이 각각 개발되었다.
#
# 장사정포 (2건):
#   - 2006년에는 서울 불바다 발언으로 인한 장사정포대응 무기체계개선 TF15)가 구성되었고, 연구결과에 따라 ‘K9 전자신관 적용 사통장치체계 개선’을 수행하여 현재 K9A1 성능개량 자주포에 적용하고 있다.
#   - 우리나라 수도권의 최대 위협으로 간주되는 북한의 장사정포인 170mm M1989 자주포와 240mm M1991 방사포의 경우 사거리가 60km에 달하여, 70km이상의 초장사정 포탄 개발이 시급한 실정이다.
#
# 전략 폭격기 (1건):
#   - 미 항공모함 및 함정 격침을 목표로 하며, 향후 핵잠수함, 전략 폭격기, 스텔스 폭격기에도 장착할 예정이다.
#
# 전익기 (1건):
#   - 90년대 후반 미국에서도 유사 기능의 상태감시 시스템을 허니웰(Honeywell)에서 개발하여 육군 회전익기(UH-60, AH-64, CH-47D)에 장착하였다.
#
# 전자전기 (8건):
#   - 또한, 2014년도 이후부터는 중국, 구·소련, 러시아의 무인기를 변형하거나 복제한  모델을 이용한 북한 소형무인기의 침범이 다수 발생하고 있어, 중국의 스텔스 무인기를 이용한 한반도 상공 정찰, 중국의 항공 유인 전자전 무기체계는 한반도주변 에서 자주 목격되고 있는 정찰기와 전자전기로 대표된다.
#   - 중국은 2010년 시안 항공사에서 Y-8 을 대체하기 위한 용도로 Y-9 수송기를 개발하여 공개한 이후, 육·해·공군에서 Y-9을 다양한 용도(수송기, 정찰기, 전자전기 등)로 개조하여 운용중 이다.
#   - [그림 25] 미국 우주군 위성 탑재 재머 개념도[그림 26] 고출력 슈퍼 재머 개념도[그림 28] 원격지원 전자전기(SOJ)개념도[그림 29] 신호정보정찰위성 개념도[그림 27] 미 우주군의 고출력 통신재머적 위성 대응 방안으로 저궤도 위성 및 무인기에 탑재하여 운용되는 재머를 개발하는 방안이 있다.
#   - 그림 28은 원격지원 전자전기의  운용개념을 보여준다.
#   - 전략급 작전 수행 간 합동 전력의 생존성 보장 및 작전 성공율· 효율성 향상을 위해서는 공세적 광역교란을 위한 원격 지원 전자전 능력이 반드시 요구되며, 미국 등 국방 선진국 에서는 EC-130H 등의 원격지원 전자전기를 개발 및  운용하고 있다.
#   - 원격지원 전자전기는 기존 자체보호 전자전장비와 호위용 재머와는 달리 수백km 에 달하는 신호정보 정찰 및 교란능력을 갖출 수 있는 전자전 무기체계 이다.
#   - 따라서, 원격지원 전자전기 보유는 수동적인 방어 에서 벗어나 능동적이며 공세적인 광역 전자교란을 통해 한반도 주변에서 전장 주도권을 확보할 수 있게 해주며, 잠재적 위협국에 대한 최선의 방어이자 공격이 가능한  무기체계라 판단된다.
#   - 그림 21은 적 정찰기에 대응하기 위한 위성항법수신기 기만 재머 형상(예)과 기만 재머 예상 위치로써, 해당 재머는 KADIZ 침범 경로주변에 배치되어야할 것이며, 기만  재머의 성능은 정찰기 종류, 접근 거리, 고도, 탑재된 항법수신기 등의 제원에 따라 결정될 수 있으리라 판단된다.
#   - 국방과학기술플러스 +14해당 개념의 원격운용 디코이는 평시 및 전시에 모두  운용될 수 있으리라 사료되며, 평시에는 중국 정찰기  출현 시 허위 레이더 신호를 송출하여 신호수집을 방해 하거나 오정보 수집을 유도할 수 있으며, 전시에는 주변국 대방사 미사일 대응을 위한 디코이(유인체)로 활용되어 아군 조기경보 레이더 및 지대공 미사일 기지를 보호할 수 있다.
#   - 무인기 테러 사례1) 디코이 이용 신호수집 방해KADIZ를 침범하는 중국 정찰기의 주요 목적은 한반도內 레이더 등 방공망의 신호정보를 수집하는 것으로  추정되고 있다.
#
# 정찰위성 (13건):
#   - 2월에 미 해군도 함정발사용 미사일(RIM-161 SM-3)을 발사하여 고장 상태로 궤도를 돌고 있던 자국의 한 정찰위성(USA-193)을 요격하는 데 성공하였다.
#   - [그림 25] 미국 우주군 위성 탑재 재머 개념도[그림 26] 고출력 슈퍼 재머 개념도[그림 28] 원격지원 전자전기(SOJ)개념도[그림 29] 신호정보정찰위성 개념도[그림 27] 미 우주군의 고출력 통신재머적 위성 대응 방안으로 저궤도 위성 및 무인기에 탑재하여 운용되는 재머를 개발하는 방안이 있다.
#   - 대표적으로 감시정찰위성 KeyHole 시리즈[ 5 ] 를 美국가정찰국( N RO ;  N a t i o n a l Reconnaissance Office)에서 운용하고 있다.
#   - '15년에 미 국방부가 공개한 보고서는 “중국이 통신위성과 감시정찰위성, 위성항법,  기상위성, 유·무인 행성탐사 등에 이르는 여러 민간 우주 프로그램 투자와 병행하여 지향성에너지 무기와 위성 재머 등과 같은 적(敵) 우주자산을 공격하기 위한 다양한 역량 들의 개발을 하고 있다”고 기술하고 있다.
#   - 그림 29는 신호정보정찰위성의 운용개념도 이며, 신호정보정찰위성은 정지궤도 위성체에 초고감도 신호정보 수신장비를 탑재하여 고고도 환경에서 한반도 주변의 전략/전술 표적에 대한 광역 감시 및 실시간 신호정보를 획득하는 것이다.
#   - 지상시스템은 위성의 정밀 궤도 추정 4) 정찰위성군 체계정찰위성 체계는 주변국의 전방위 위협에 대비한 신속한 징후감시 및 조기경보 능력 확보를 위한 것이다.
#   - 중국의 정찰위성은 Yaogan(야오간) 시리즈로 대표 된다.
#   - [그림 22] 군 정찰위성 개념도[그림 23] 우주감시소 전경(마우이 섬)[그림 24] 광학 우주감시체계 개념도우주 전장감시체계는 평시에는 주변국 위협에 대비하여 도발 징후를 탐색하거나 정찰하고, 전시에는 군사 전략 정보를 수집하고 분석하는 핵심적인 역할을 수행한다.
#   - 고출력레이저 위성추적체계는 자국 우주자산에 대한  추적·보호, 군 정찰위성 등 국가위성의 안정적인 운용 지원 및 미확인 우주물체에 대한 추적·감시능력 확보하여, 위성 정밀추적을 통해 적성 정찰위성에 대한 Soft Kill 능력을  확보하는 위성감시용 능동방어 체계이다.
#   - 정지궤도 신호정보정찰위성을 개발하고 운용하는 것은 거의 실시간으로 적 위협을 정찰하고 추적하여 표적화할 수 있는 능력을 갖추게 된다는 것을  의미하며, 아울려 지휘관의 군사 전략적 결심을 내리는데 결정적인 정보를 제공해 준다는데 그 의미가 크다 하겠다.
#   - 그림 25에서 알 수 있듯이 미국 우주군은 정지궤도/저궤도 위성을 이용하여 적 정찰위성(ES/SIGINT)을 재밍하려는 개념을 지니고 있다.
#   - 정지궤도 신호정보 정찰위성은 주변국 지상, 해상, 공중에 대한 광역 전자 신호 수집능력을 확보할 수 있는 가장 확실한 방안이라  사료된다.
#   - 군 정찰위성 체계는 및 정밀 시각동기 등을 수행하여 항법체계의 전체적인  운용을 담당한다.
#
# 지뢰 (21건):
#   - 50 ▒ 국방과학기술플러스 +하지 착용로봇 기술 외에도 국방과학연구소에서는 임무 특화 상지 기술로, 1) 임무장비를 어깨에 보다 쉽게 견착할 수 있는 무동력 임무장비 견착 모듈 및 2) 지뢰탐지 작업 보조를 위한 무동력 팔 근력보조 모듈에 대한 연구를 수행하였다.
#   - 지뢰탐지병사가 제안된 팔 근력보조 모듈을 이용하면 지뢰탐지기 운용 중 근육력 및 사용에너지가 감소되어 지뢰탐지 임무시간이 상당히 연장될 것으로 기대된다.
#   - 화생무기 폐기시스템 기술 동향대량살상무기 제거를 위한 화생무기 폐기기술국방과학연구소 Chem-Bio기술센터 책임연구원 김현석개요국방과학기술플러스 +1화생무기 폐기시스템 기술 동향화생무기는 독성의 화생물질과 이들을 투발하기 위한  포탄, 미사일, 지뢰 등의 투발 수단을 총칭한다.
#   - 지뢰탐지 작업 보조 착용 모듈은 지뢰탐지기 (무게: 4kg) 운용 병사의 집중도 향상 및 작업효율 증대를 위해, 지뢰탐지병사 하박에 부착되어 팔 근육 힘을 보조해 줄 수 있도록 무동력 타입으로 현재 개발 중이다.
#   - 개발된 팔 근력보조장치를 착용한 후 지뢰탐지동작을 수행할 경우 이두근의 근활성도가 75% 감소되었다.
#   - 근전도신호를 이용하여 지뢰탐지병사 보조를 위해 제작된 팔 근력보조 모듈 착용 유무에 따른 효과도를 분석하였다.
#   - 또한 DMZ 일대 유해발굴 작업을 동시에 진행해야함을 고려하여 현재는 병사에 의해 직접 지뢰탐지/제거 작업이 진행되고 있다.
#   - 물론 개척전차 또는 폭파에 의해 지뢰제거 작업 속도를 증대시킬 수 있지만 이는 환경 파괴를 초래할 수 있다.
#   - 팔 근력보조 모듈 없이 통상적인 지뢰탐지동작을 하는 경우 다른 근육 대비 이두근이 가장 많이 활성화되었다.
#   - DMZ 일대에는 약 200만개의 지뢰가 묻혀있을 것이라 추정되며 이를 지뢰탐지병사들이 완전히 제거하기 위해서는 200년 이상 시간이 소요된다고 보고되었다.
#   - 국방과학연구소는 지뢰탐지병사 팔 근력보조를 위하여 그림 15와 같은 무동력 팔 근력보조 모듈을 개발하고 있다.
#   - 현재 우리나라에서는 남북경협 활성화를 준비하기 위하여 DMZ 일대 지뢰탐지/제거 필요성이 대두되고 있다.
#   - 임무유형별 군사용 착용로봇 플랫폼 개발동향 ▒ 47[그림 15] 지뢰탐지 근력보조를 위한 착용형 근력보조모듈 구성 및 형상2) 핵심기술지뢰탐지기 무게보조를 위한 팔 근력보조 모듈은 크게 동작구현부와 중력보상부로 구성된다.
#   - 지뢰탐지 병사는 약 4kg 정도 무게의 지뢰탐지기를 들고 임무를 수행하는데, 고도의 집중력이 요구되는 지뢰탐지 작업동안 팔에 집중되는 지뢰 탐지기 부하는 팔 근육의 피로도 발생을 가속화하여 약 20분 이상 작업을 지속하지 못하게 한다.
#   - 동작구현부는 지뢰탐지병사가 지뢰탐지기를 좌우로 스위핑 (sweeping)하는 동작을 구현한다.
#   - 대신 지뢰탐지기 무게 지지는 등쪽에 위치한 중력보상부에서 담당한다.
#   - 지뢰탐지기 하단 구조물을 볼 조인트 끝단 홀에 삽입하는 간단한 조작으로 지뢰탐지기를 장착할 수 있으며, 볼 조인트 회전 운동에 의해 탐지 작업 시 지뢰탐지기 자세를 미세 조정할 수 있도록 설계하였다.
#   - 모션캡쳐시스템을 이용하여 획득된 지뢰탐지 병사의 운동데이터를 이용하여 그림 16에 제시된 것처럼 중력보상 요구 토크를 분석하였다.
#   - 이를 위해 그림 17에 제시된 것과 같이 지뢰탐지기를 운용하는 팔 주요 근육에 근전도센서를 부착하였다.
#   - 실험은 1) 팔 근력보조 모듈 없이 통상적인 지뢰탐지동작을 하는 경우, 2) 팔 근력보조장치 착용 후 근력보조를 받으며 지뢰탐지동작을 하는 경우, 2가지 경우에 대해서 진행하였다.
#   - 지뢰탐지 근력보조 모듈1) 개요국방과학연구소는 2019년부터 민군기술협력사업을 통해 지뢰탐지 병사의 근력보조를 위한 엑소수트 시스템을 개발하고 있다.
#
# 천궁 (1건):
#   - SM-3, GBI(Ground Based Intercepter)는 중간단계, 천궁-II, 사드(THAAD), 패트리어트(Patriot)는 종말단계 미사일 방어에 해당한다.
#
# 프레데터 (3건):
#   - [9] 미국 CSIS 보고서는 프레데터 감시정찰 무인기를 이용하여 500km 거리에서 15초 만에 탄도미사일을 탐지 가능함을 인용하고 있다.
#   - 앞서 설명한 기능을 지원할 수 있는 잠재적인 UAV 원격측정 플랫폼은 글로벌 호크, 프레데터, 록히드 마틴의 Structure Blimp 통합 센서 등이 있다.
#   - 프레데터(미국) 복사판으로 알려진 Yi Long 는 2013년 파리 에어쇼에서 처음 공개 되었다.
#
# 함포 (4건):
#   - 미국의 ATK 社는 해군용 5인치 함포탄인 B-TERM(Ballistic Trajectory Extended Range Munition) 탄을 개발한 바 있는데, 텅스텐 케이스로 제작된 탄두와 저가형 유도항법장치를 채택한 것으로 알려져 있다.
#   - 또한 이 탄은 고정표적은 물론 이동표적에 대해서도 사격이 가능하며, 사격이후 표적변환이 가능하며, 5인치 함포에서는 100km, 155mm 야포에서는 85km의 사거리를 갖는다고 소개하고 있다.
#   - Excalibur S를 함포에도 적용 가능한 127mm Excalibur N5를 개발 중이다.
#   - 미국의 155mm AGS(Advanced Gun System) 함포의 경우는 사격통제 장치와 완전 자동화된 탄/장약 이송/장전 장치를 이용하여 빠른 반응성과 높은 생존성을 가지는 무인 포탑을 채택한 사례이다.

# %% [markdown]
# # 최종 함수

# %%
import re
import pandas as pd

# --- 1) CSV 로드 ---
weapon_ex = pd.read_csv(
    '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/test.csv',
    encoding='utf-8-sig'
)

# --- 2) all_examples 구성 (pdf + example 튜플) ---
all_examples = []
for _, row in weapon_ex.iterrows():
    pdf = row['pdf']
    exs = row['example']
    if isinstance(exs, str):
        try:
            exs = eval(exs)
        except:
            exs = [exs]
    for ex in exs:
        all_examples.append((pdf, ex))

# --- 3) 필터링 함수 (튜플 버전) ---
def filter_examples(terms, examples, max_run=20, max_space_run=5, max_len=100):
    matched = {}
    for term in terms:
        pat = re.compile(r'(?<!\d)' + re.escape(term) + r'(?!\d)')
        hits = []
        for pdf, ex in examples:
            # 1) 용어 매칭
            if not pat.search(ex):
                continue
            # 2) 이중 줄바꿈 제거
            if "\n\n" in ex:
                continue
            # 3) 길이 제한
            if len(ex) > max_len:
                continue
            # 4) 긴 무공백(run) 검사
            runs = re.findall(r'[가-힣A-Za-z0-9]+', ex)
            if any(len(r) > max_run for r in runs):
                continue
            # 5) 연속 공백(run) 검사
            if ' ' * max_space_run in ex:
                continue
            # 6) “다.” 로 끝나지 않는 문장 제거
            if not ex.strip().endswith("다."):
                continue
            # 모두 통과하면, (pdf, example) 기록
            hits.append((pdf, ex))
        # 순서 유지하며 중복 제거
        matched[term] = list(dict.fromkeys(hits))
    return matched

# --- 4) terms 리스트 ---
terms = weapon_ex['term'].unique().tolist()

# --- 5) 필터링 수행 ---
filtered_dict = filter_examples(terms, all_examples,
                                max_run=20,
                                max_space_run=3,
                                max_len=200)

# --- 6) CSV 저장용 DataFrame으로 변환 ---
rows = []
for term, recs in filtered_dict.items():
    for pdf, ex in recs:
        rows.append({
            'term': term,
            'pdf': pdf,
            'example': ex
        })

df_out = pd.DataFrame(rows)

# term 기준 정렬
df_out = df_out.sort_values('term')

# --- 7) CSV로 저장 ---
output_path = "/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/filtered_with_pdf.csv"
df_out.to_csv(output_path, index=False, encoding="utf-8-sig")
print(f"✔ 저장 완료: {output_path}")
# Out:
# ✔ 저장 완료: /content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/filtered_with_pdf.csv

# %% [markdown]
# # csv 저장

# %%
def xlsx_to_csv(input_xlsx: str, output_csv: str, sheet_name=0):

    # 1) 엑셀 파일 로드
    df = pd.read_excel(input_xlsx, sheet_name=sheet_name, engine='openpyxl')

    # 2) CSV로 저장 (UTF-8 BOM 포함)
    df.to_csv(output_csv, index=False, encoding='utf-8-sig')
    print(f" '{input_xlsx}' → '{output_csv}' 변환 완료 (encoding='utf-8-sig')")

# %%
if __name__ == "__main__":
    input_xlsx = '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/filtered_with_pdf.xlsx'
    output_csv = '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/국방과학연구소_무기의세계_용례매핑_전처리후.csv'     # 저장할 csv 파일 경로
    xlsx_to_csv(input_xlsx, output_csv)
# Out:
#  '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/filtered_with_pdf.xlsx' → '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/국방과학연구소_무기의세계_용례매핑_전처리후.csv' 변환 완료 (encoding='utf-8-sig')
