# %% [markdown]
# # 용어와 매칭 함수

# %%
# !pip install PyMuPDF

# %%
import os
import re
import fitz          # PyMuPDF
import pandas as pd

def extract_text_from_pdf(pdf_path: str) -> str:
    doc = fitz.open(pdf_path)
    full_text = "".join(page.get_text() + "\n" for page in doc)
    doc.close()
    return full_text

def normalize_linebreaks(text: str) -> str:
    text = re.sub(r'(?<!\n)\n(?!\n)', '', text)
    text = re.sub(r'(?<=[\.!?])(?=[^\s])', ' ', text) # ? . ! 뒤에 공백이 없는 경우 의도적으로 붙여주기
    return text

def split_sentences(text: str, min_len: int = 10) -> list[str]:
    text = normalize_linebreaks(text)
    pattern = r'(?<=[\.!?])(?:\s+|\n)|(?<=[다요었습니다요다])\n'
    parts = re.split(pattern, text)
    return [p.strip() for p in parts if len(p.strip()) >= min_len]

def map_terms_to_sentences(terms: list[str], sentences: list[str]) -> dict[str, list[str]]:
    mapped = {}
    for term in terms:
        hits = [s for s in sentences if term in s]
        if hits:
            mapped[term] = list(dict.fromkeys(hits))
    return mapped

def combine_pdfs_to_one_csv(pdf_dir: str,
                            terms: list[str],
                            output_csv: str,
                            min_len: int = 10):
    # 1) pdf 폴더에서 .pdf 파일들 자동 수집
    pdf_files = [
        os.path.join(pdf_dir, fn)
        for fn in os.listdir(pdf_dir)
        if fn.lower().endswith(".pdf")
    ]

    combined_rows = []
    # 2) PDF별 처리
    for pdf_path in pdf_files:
        base = os.path.splitext(os.path.basename(pdf_path))[0]
        raw = extract_text_from_pdf(pdf_path)
        sentences = split_sentences(raw, min_len=min_len)
        mapped = map_terms_to_sentences(terms, sentences)

        for term, examples in mapped.items():
            for ex in examples:
                combined_rows.append({
                    'pdf': base,
                    'term': term,
                    'example': ex
                })
        print(f" • {base}.pdf → {len(mapped)}개 용어 매핑")


    df_all = pd.DataFrame(combined_rows)

    # 3-1) “term + example” 쌍 단위로 중복 제거
    df_all = df_all.drop_duplicates(subset=['term', 'example'])

    df_all = df_all.sort_values(by='term')

    # 4) 용례 개수 확인
    total_examples = len(df_all)
    print(f"\n▶ 총 용례 개수: {total_examples}건\n")

    print("▶ 용어별 용례 개수:")
    print(df_all['term'].value_counts(), "\n")

    print("▶ PDF별 용례 개수:")
    print(df_all['pdf'].value_counts(), "\n")

    # 5) CSV로 저장
    df_all.to_csv(output_csv, index=False, encoding="utf-8-sig")
    print(f"✔ 최종 결과가 '{output_csv}' 에 저장되었습니다.")

# %%
if __name__ == "__main__":
    weapon_df = pd.read_csv(
          '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/무기의세계/무기의세계_불필요한것 제외.csv',
        encoding="utf-8-sig"
    )
    weapon_terms = weapon_df['용어'].tolist()

    pdf_folder =  "/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/"
    output_file ="/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/test_resid.csv"

    combine_pdfs_to_one_csv(pdf_folder, weapon_terms, output_file)
# Out:
#  • 국방과학기술플러스 250호.pdf → 17개 용어 매핑
#  • 국방과학기술플러스 249호.pdf → 16개 용어 매핑
#  • 국방과학기술플러스_248호(20년도+2분기).pdf → 17개 용어 매핑
#  • 국방과학기술플러스_246호(19년도+4분기).pdf → 4개 용어 매핑
#  • 국방과학기술플러스_247호(20년도+1분기).pdf → 8개 용어 매핑
#  • 국방과학기술플러스_244호(2019년+2분기).pdf → 4개 용어 매핑
#  • 국방과학기술플러스_245호(2019년+3분기).pdf → 0개 용어 매핑
#  • 국방과학기술플러스_242호(2018년+4분기).pdf → 17개 용어 매핑
#  • 국방과학기술플러스_243호(2019년+1분기).pdf → 0개 용어 매핑
#  • 국방과학기술플러스_239호(2018년+1분기).pdf → 5개 용어 매핑
#  • 국방과학기술플러스_238호(2017년+4분기).pdf → 2개 용어 매핑
#  • 국방과학기술플러스_237호(2017년+3분기).pdf → 4개 용어 매핑
#  • 국방과학기술플러스_236호(2017년+2분기).pdf → 2개 용어 매핑
#  • 국방과학기술플러스_235호(2017년+1분기).pdf → 14개 용어 매핑
#  • 국방과학기술플러스_241호(2018년+3분기).pdf → 1개 용어 매핑
#  • 국방과학기술플러스_240호(2018년+2분기).pdf → 1개 용어 매핑
#
# ▶ 총 용례 개수: 562건
#
# ▶ 용어별 용례 개수:
# term
# 어뢰            157
# 기뢰             84
# 미사일 방어체계       38
# 전자전기           31
# 공대공 미사일        30
# 무인전투기          22
# 지뢰             21
# 정찰기            18
# 아파치            13
# 정찰위성           12
# 장갑차            11
# 천궁             11
# 킬체인            10
# F-2             9
# SM-3            9
# 공격기             9
# 라팔              6
# 현궁              5
# 5세대 전투기         4
# P-3C            4
# 천무              4
# 근접전투            4
# 수리온             3
# 박격포             3
# 전익기             3
# 하푼              3
# 함포              3
# 공중급유기           3
# X-37B           3
# IED             3
# A-10            2
# 장사정포            2
# UH-60 블랙호크      2
# J-20            2
# 기총              2
# 사드              2
# 견인포             1
# Su-30           1
# F-4 팬텀          1
# B-52 폭격기        1
# B-2 스피릿         1
# RPG-7           1
# 신궁              1
# 세종대왕함           1
# 벙커버스터           1
# 대륙간탄도미사일        1
# 독도함             1
# 다연장로켓포          1
# 연안전투함           1
# 패트리어트 미사일       1
# Name: count, dtype: int64
#
# ▶ PDF별 용례 개수:
# pdf
# 국방과학기술플러스_242호(2018년+4분기)    174
# 국방과학기술플러스_248호(20년도+2분기)    127
# 국방과학기술플러스 250호                     87
# 국방과학기술플러스_237호(2017년+3분기)     55
# 국방과학기술플러스_239호(2018년+1분기)     31
# 국방과학기술플러스 249호                     29
# 국방과학기술플러스_235호(2017년+1분기)     22
# 국방과학기술플러스_247호(20년도+1분기)     21
# 국방과학기술플러스_244호(2019년+2분기)      6
# 국방과학기술플러스_246호(19년도+4분기)      4
# 국방과학기술플러스_236호(2017년+2분기)      2
# 국방과학기술플러스_238호(2017년+4분기)      2
# 국방과학기술플러스_241호(2018년+3분기)      1
# 국방과학기술플러스_240호(2018년+2분기)      1
# Name: count, dtype: int64
#
# ✔ 최종 결과가 '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/test_resid.csv' 에 저장되었습니다.

# %% [markdown]
# # 최종 함수(전처리 과정)

# %%
import re
import pandas as pd

# --- 1) CSV 로드 ---
weapon_ex = pd.read_csv(
    '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/test_resid.csv',
    encoding='utf-8-sig'
)

# --- 2) all_examples 구성 (pdf + example 튜플) ---
all_examples = []
for _, row in weapon_ex.iterrows():
    pdf = row['pdf']
    exs = row['example']
    if isinstance(exs, str):
        try:
            exs = eval(exs)
        except:
            exs = [exs]
    for ex in exs:
        all_examples.append((pdf, ex))

# --- 3) 필터링 함수 (튜플 버전) ---
def filter_examples(terms, examples, max_run=20, max_space_run=5, max_len=100):
    matched = {}
    for term in terms:
        pat = re.compile(r'(?<!\d)' + re.escape(term) + r'(?!\d)')
        hits = []
        for pdf, ex in examples:
            # 1) 용어 매칭
            if not pat.search(ex):
                continue
            # 2) 이중 줄바꿈 제거
            if "\n\n" in ex:
                continue
            # 3) 길이 제한
            if len(ex) > max_len:
                continue
            # 4) 긴 무공백(run) 검사
            runs = re.findall(r'[가-힣A-Za-z0-9]+', ex)
            if any(len(r) > max_run for r in runs):
                continue
            # 5) 연속 공백(run) 검사
            if ' ' * max_space_run in ex:
                continue
            # 6) “다.” 로 끝나지 않는 문장 제거
            if not ex.strip().endswith("다."):
                continue
            # 모두 통과하면, (pdf, example) 기록
            hits.append((pdf, ex))
        # 순서 유지하며 중복 제거
        matched[term] = list(dict.fromkeys(hits))
    return matched

# --- 4) terms 리스트 ---
terms = weapon_ex['term'].unique().tolist()

# --- 5) 필터링 수행 ---
filtered_dict = filter_examples(terms, all_examples,
                                max_run=20,
                                max_space_run=3,
                                max_len=200)

# --- 6) CSV 저장용 DataFrame으로 변환 ---
rows = []
for term, recs in filtered_dict.items():
    for pdf, ex in recs:
        rows.append({
            'term': term,
            'pdf': pdf,
            'example': ex
        })

df_out = pd.DataFrame(rows)

# term 기준 정렬
df_out = df_out.sort_values('term')


# --- 7) CSV로 저장 ---
output_path = "/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/국방과학연구소_나머지_용례매핑.csv"
df_out.to_csv(output_path, index=False, encoding="utf-8-sig")
print(f"✔ 저장 완료: {output_path}")
# Out:
# ✔ 저장 완료: /content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/국방과학연구소_나머지_용례매핑.csv

# %%
have_example_term = [term for term, exs in filtered_dict.items() if exs]
print(have_example_term) # 용례가 있는 용어
num_terms_with_examples = sum(1 for exs in filtered_dict.values() if exs)
num_examples_with_examples = sum(len(exs) for exs in filtered_dict.values() if exs)
print(f"용례가 있는 용어의 개수: {num_terms_with_examples}개") # 43개(50 -> 43)
print(f"총 용례의 개수: {num_examples_with_examples}개") # 334개(562 -> 334)
# Out:
# ['5세대 전투기', 'A-10', 'IED', 'J-20', 'P-3C', 'RPG-7', 'SM-3', 'Su-30', 'UH-60 블랙호크', 'X-37B', '공격기', '공대공 미사일', '공중급유기', '근접전투', '기뢰', '기총', '다연장로켓포', '대륙간탄도미사일', '독도함', '라팔', '무인전투기', '미사일 방어체계', '박격포', '벙커버스터', '사드', '세종대왕함', '수리온', '신궁', '아파치', '어뢰', '연안전투함', '장갑차', '장사정포', '전익기', '전자전기', '정찰기', '정찰위성', '지뢰', '천궁', '킬체인', '하푼', '함포', '현궁']
# 용례가 있는 용어의 개수: 43개
# 총 용례의 개수: 334개

# %%
# 결과 확인
for term, exs in filtered_dict.items():
    if exs:
        print(f"{term} ({len(exs)}건):")
        for ex in exs:
            print("  -", ex)
        print()
# Out:
# 5세대 전투기 (3건):
#   - ('국방과학기술플러스 250호', '전 세계에서 저피탐 기술이 가장 발달된 것으로 알려진 미국은 최근 저피탐 성능을 키워드로 하는 5세대 전투기 개발에 이어 6세대 전투기 개발계획을 발표했으며 중국, 일본 등 한반도를 둘러싼 주변 강대국들도 속속들이 자국의 저피탐 무기체계 개발 계획 및 결과를 발표하고 있다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '5세대 전투기인 F-22, F-35 개발 이후 스텔스 성능은 군사용 항공기에 필수적인 적용기술이 되었으며 스텔스 항공기는 적 레이더에 탐지되는 레이더 단면적(RCS)을 최소로 하는 것이 목표이다.')
#   - ('국방과학기술플러스 249호', '러시아의 5세대 전투기인 Su-57(일명 PAK-PA)에는 Tikhomirov NIIP 연구소에서 개발한 2종류의 주파수 대역을 가진 레이다가 장착되어 있다.')
#
# A-10 (1건):
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'HA-10이라는 무인기의 개발도 병행하였는데 7~15km 상공을 24시간 체공 비행하는것을 목표로 하였다.')
#
# IED (2건):
#   - ('국방과학기술플러스_239호(2018년+1분기)', 'IED에 의한 피해를 줄이기 위해서 재머를 켠 상태에서 이동을 하지만, 이 상황에서 통신장비와 간섭문제가 발생하여 원활한 통신에 문제가 발생하는 사례가 잦았다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '그 중에서 가장 대표적인 내용으로써, 급조폭발물에 의한 공격을 방지하고자 개발되고 배치된 Counter-IED (Counter Improvised Explosive Device)와 통신장비와의 간섭문제가 있다.')
#
# J-20 (1건):
#   - ('국방과학기술플러스 249호', '3세대 AESA 레이다 기술은 J-20 전투기 포함 다수의 전투기 탑재를 목표로 개발되었으며, GaAs소자를 이용하여 3차원 구조속에 여러 개의 칩을 적층하는 타일형 모듈을 구현하였다.')
#
# P-3C (1건):
#   - ('국방과학기술플러스_247호(20년도+1분기)', '1990년대에는 Helium원자의 Zeeman 효과를 적용한 자기장 센서가 개발되어 이를 적용한 ASQ-81 MAD 시스템이 개발되었고 P-3C, Lockheed S-3A Viking, SH-2F/G and SH-3H, Sikorsky SH-60B LAMPS, Mk III helicopters 등에 적용되었다.')
#
# RPG-7 (1건):
#   - ('국방과학기술플러스_235호(2017년+1분기)', '최근 북한도 이라크전 등 현대전의 전쟁교훈을 분석하여 시가지 전투에 적합한 전술과 RPG-7에 열압력탄을 개발하여 배치했다.')
#
# SM-3 (5건):
#   - ('국방과학기술플러스_242호(2018년+4분기)', '금년 1월에 일본 언론을 통해 보도된 ASM-3의 개발 완료 및 2019년 양산 착수 기사에 나타난 특징[41]도 XASM-3의 개발목표와 크게 다르지 않은 것으로 보인다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '이 중 현재 우리가 언론에서 흔하게 듣는 천궁2, 패트리엇이나 사드(THAAD1)) 등의 체계는 탄도탄의 종말단계 요격을 위한 것이며 SM-3, GBI2) 등의 체계는 중간단계 요격을 위한 것이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '마지막으로 이지스함에서 SM-3로 요격하는 방안이 있다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '일 본  일본 방위성 기술연구본부는 2016년 양산을 목표로 XASM-3 초음속 공대함 미사일 개발을 2003년에 착수하였었다.')
#   - ('국방과학기술플러스_235호(2017년+1분기)', '탄도탄 방어(BMD; Ballistic Missile Defense)를 위해 SM-3의 단분리 과정을 포함한 비행단계별 플랫폼의 형태를 변경시켜가면서 가시화하고 있는 모습을 시각적으로 형상화하여 보여준다.')
#
# Su-30 (1건):
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'BrahMos는 인도 공군의 수호이 전투기(Su-30MKI)에서 발사되었으며, 인도 공군은 금년 말까지 40대의 수호이에 BrahMos를 장착할 예정이다.')
#
# UH-60 블랙호크 (1건):
#   - ('국방과학기술플러스 250호', '2006년에는 아파치 헬기에서 고정익 무인기 Hunter를 조종하는 장비를 개발하였고, 2007년부터는 UH-60 블랙호크에 상호운용 LOI 2급 장비인 VUIT29)를 탑재하여 무인기로부터 비디오 영상을 직접 수신하도록 하여 상황인식 능력을 개선하였다.')
#
# X-37B (2건):
#   - ('국방과학기술플러스_246호(19년도+4분기)', '또한, 열구조 방식은 X-43이나 X-37B 비행체 등에 사용하기 위해 개발되었는데 초고온 강도도 요구되었다.')
#   - ('국방과학기술플러스 249호', '아울러 미 공군이 ’10년부터 비공개적으로 궤도에 올려 각종 비행시험을 하고 있는 군사용 X-37B 우주항공기는 강력한 우주무기로서의 가능성을 두고 그 정체와 용도 등에 대한 설이 난무하다.')
#
# 공격기 (7건):
#   - ('국방과학기술플러스_248호(20년도+2분기)', '특히 일본의 경우 공식적인 전자공격기를 보유하고 있지 않은 것으로 보이나, 한반도 최근접 지역에 최신형 장거리 감시레이더를 배치하여[20] 한국을 비롯한 주변국 감시를 강화하는 움직임을 보이고 있다.')
#   - ('국방과학기술플러스 249호', '(그림 5~6) 향후 미국은 드론 대응 기술을 한층 더 강화한 후 순항 미사일 형태의 전자기펄스탄을 실용화할 것으로 보이며 최종적으로는 전자기펄스를 발사하는 무인공격기를 개발할 것으로 예상된다.')
#   - ('국방과학기술플러스_238호(2017년+4분기)', '무인공격기와 순항유도무기 체계 적용을 위한 가스터빈 엔진은 MTCR 규정에 따른 EL(Export Licence) 문제로 인하여 국내 독자적인 엔진개발이 불가피하여 90년대 초반부터 순항유도무기용 단수명 터보제트엔진의 개발을 시초로 하여, 20년대 중반이후의 무인항공기 체계개발을 위한 장수명의 터보팬엔진 핵심기술 개발을 진행하고 있다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '인도는 자체 개발한 경공격기 테자스(Tejas)에 Meteor를 통합하려 하였으나, 유럽 6개국이 참여한 MBDA와 이스라엘의 정치적인 이해관계로 결국 무산된 바 있다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '국방망/전장망 유형별 사이버방어 수준 현황軍 IT 유형별로 공격기술의 적용 가능성을 검토하여 각 유형에 적용 가능한 공격기술을 분류하였다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '軍 IT 환경별로 분석된 유형별 사이버방호체계를 기준으로 공격기술에 연계되는 방어기능을 식별하여 보유한 방어기능과 부족한 방어기능을 평가하였다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '킬체인 공격단계별 공격기술과 방어기능 수준평가공격기술과 방어기능의 연관성 분석을 통해 킬체인 공격단계와 방어 영역별 수준을 평가한 결과, 약화와 거부 영역의 방어분야는 공격단계에 가장 적절히 대응할 수 있는 기능을 보유하고 있는 것으로 평가되었으며, 방어기능 100%의 의미는 현재까지 식별된 모든 방어기능을 보유하고 있다는 것을 의미한다.')
#
# 공대공 미사일 (22건):
#   - ('국방과학기술플러스_248호(20년도+2분기)', '중국과 파키스탄의 직접적인 위협을 받는 인도로서는 ASTRA보다 더 좋은 성능의 공대공 미사일인 Meteor를 가지기 위해 여러 노력을 기울였으나 지금까지는 성과가 없는 실정이다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '무장탑재량을 획기적으로 늘리기 위하여  AIM-120을 개발한 Raytheon은 Peregrine 중거리 공대공 미사일을 자체 예산으로 개발 중이다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '그러나 1990년대 걸프전을 시작으로 공대공 미사일, 그 중에서도 비가시선 거리(BVR, Beyond Visual Range) 밖의 적 항공기를 요격할 수 있는 중거리 공대공 미사일의 역할은 비약적으로 증가하였다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '걸프전 이후, 미국의 원거리 공중 전력에 위협을 느낀 러시아와 중국은 미국의 공중급유기와 조기경보기 등을 요격하기 위한 BVR 미사일 개발에 집중적으로 투자하여 다수의 고성능 중-장거리 공대공 미사일을 보유하게 되었다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '일본은 50여 년 전에 이미 단거리 공대공 AAM-1을 전력화한 이후, 자국의 우수한 전자기술을 바탕으로 새로운 중거리 공대공 미사일을 개발해 왔다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '최초 전력화 이후 지금까지 지속적으로 성능을 향상시켜왔으나, 30년전에 개발된 AIM-120기반으로는 러시아와 중국의 최신예 공대공 미사일을 대응하기 역부족이란 인식으로부터 완전히 새로운 공대공 미사일 개발을 준비하고 있다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', 'KF-X에 장착할 중거리 공대공 미사일은 사거리나 형상에 대한 까다로운 요구조건과 함께 항공기 체계통합을 위한 기술적 문제도 극복해야 한다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '현대 항공기의 레이더 탐지성능이 증가함에 따라 BVR 영역에서 운용할 수 있는 중장거리 공대공 미사일에 대한 개발경쟁이 치열하다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '말하자면 400mm급 공대함 유도탄과 200mm 급 공대공 미사일은 주요 구성품의 크기는 다르지만 동일한 설계개념과 형상을 공유하는 것이다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '만일 국산 공대공 미사일이 Meteor와 같은 덕티드 램제트 엔진을 기반으로 한다면, 이미 수행한 KFX-Meteor의 체계통합 결과를 십분 활용하여 기술개발 위험을 획기적으로 낮출 수 있을 것이다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '이렇게 확보한 기술들은 향후 중단거리 공대공 미사일의 국내 개발에 직접 활용될 수 있을 것이다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '장기적으로 KF-X에 자체 개발한 공대공 미사일이 필요한 이유다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '중국중장거리 공대공 미사일에 가장 많은 투자를 하고 있는 국가이다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '실제교전 상황에서 공대공 미사일이 의미 있는 확률로 적기를 요격할 수 있는 거리를 나타내는 회피불능구역(NEZ, No Escape Zone)이라는 용어가 있다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '일본  일본은 50년 전, 미국으로부터 도입한 AIM-9B의 복제수준으로 AAM-1 단거리 공대공 미사일을 개발한 바 있다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '또한, AAM-4B는 개량된 이중추력 모터로 약 120km 사거리를 가지는 것으로 알려져 있지만, 이 정도로는 중국과 러시아의 200km급 BVR 공대공 미사일에 대응하기는 어려운 실정이므로 일본으로서는 F-35내부 무장창에 탑재가능하며 긴 사거리를 가지는 공대공 미사일이 필요하였다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '일본은 미국산 항공기 플랫폼의 제약에서 벗어나기 위해  BVR 미사일 유도용 지령송신기를 자체 개발하였으며, 인도는 자국산 항공기에 Meteor를 탑재하는 것을 포기하고 독자 BVR 공대공 미사일을 개발하고 있다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '조만간 인도에서 자체 개발한 덕티드 램제트 추진 공대공 미사일에 대한 소식을 들을 수 있을 듯하다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '정치적인 이유로 EU의 Meteor도입이 쉽지 않기 때문에 인도는 자체적으로 덕티드 램제트 기반 공대공 미사일 개발을 서두르고 있으며, 그 일환으로 인도는 2013년, 러시아와 SFDR(Solid Fuel Ducted Ramjet) 추진체계를 개발하는 협력계약을 체결하고, 2019년 지상발사 시험을 성공하였다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '미국 중거리 공대공 미사일 중 최고의 베스트셀러는 당연히 AIM-120 AMRAAM이다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '1990년대 걸프전을 시작으로 공대공 미사일, 그 중에서도 비가시선 거리(BVR, Beyond Visual Range) 밖의 적 항공기를 요격할 수 있는 중거리 공대공 미사일의 역할은 비약적으로 증가하였다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '최근에는 항공기의 탐지능력이 점점 확장됨에 따라 더 멀리서 상대를 제압할 수 있는 중장거리 공대공 미사일무장이 필수적으로 요구된다.')
#
# 공중급유기 (2건):
#   - ('국방과학기술플러스_248호(20년도+2분기)', '걸프전 이후, 미국의 원거리 공중 전력에 위협을 느낀 러시아와 중국은 미국의 공중급유기와 조기경보기 등을 요격하기 위한 BVR 미사일 개발에 집중적으로 투자하여 다수의 고성능 중-장거리 공대공 미사일을 보유하게 되었다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '러시아와 중국은 전통적으로 조기경보기나 공중급유기 등 원거리 고가치 자산(HVA, High Value Assets)을 요격하기 위하여 중/장거리 공대공 전력에 투자해 왔으며, 현재는 전력의 다양성과 속력, 사거리 등 비행성능 측면에서 미국을 압도하고 있는 실정이다.')
#
# 근접전투 (3건):
#   - ('국방과학기술플러스_235호(2017년+1분기)', '차량수송형은 감시정찰, 화생방/폭발물 탐지, 근접전투 등의 용도로 개발되었고 70Kg 급의 Talon은 4000대 이상이 운용되고 있다.')
#   - ('국방과학기술플러스 250호', '지상무인체계 관점의 기술적 난이도를 고려할 때 ① 수송·보급, 화생방 오염지역 정찰, ② 장애물 개척, 화력지원, ③ 대공방호, ④ 수색·정찰, ⑤ 근접전투 순으로 높아진다.')
#   - ('국방과학기술플러스 250호', '현재 군에서 소요제기하는 지상무인체계는 근접전투 가능한 무기체계 중심이나, 이러한 지상무인체계 기술적 난이도는 매우 높으므로 많은 시간과 비용을 필요로 한다.')
#
# 기뢰 (55건):
#   - ('국방과학기술플러스_237호(2017년+3분기)', '기뢰 대항작전은 모든 기뢰원에 대한 완전 소해를 목표로 수행되어야 하나 현실적으로 어려운 실정이다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '머리말기뢰는 적은 비용을 사용하여 다양한 방법으로 해양지형에 관계없이 광범위하게 부설할 수 있어 수상(중)함에 막대한 피해를 유발시킬 수 있을 뿐 아니라 해군작전 중 심리적인 부담을 가중시키며, 미래에도 지속적인 사용이 가능한 저비용 고효율의 무기이다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '기뢰전은 크게 기뢰 부설작전과 기뢰대항 작전으로 구분되며, 기뢰대항 작전은 적의 기뢰부설 시도를 막고 기뢰 위협을 감소시키는 모든 작전이며 적의 기뢰전 위협을 사전에 차단하는 공격적 기뢰대항 작전과 기뢰가 부설된 이후에 대응하는 방어적 기뢰 대항작전으로 분류된다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '본 장에서는 기뢰대항 작전 중 방어적 기뢰대항 작전을 지원하는 체계에 대해 언급하고자 한다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '미국의 경우, 이라크전에서 약 6개월 이상의 많은 기간을 소비한 작전이 기뢰 탐색 및 소해이다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '음향 탐지 기술USV를 이용하여 기뢰를 탐지해야 할 경우, 다양한 종류의 음향탐지센서가 필요하다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '대부분의 감응기뢰는 자기장 및 음향신호에 감응하여 발화되며, 일부 기뢰의 경우, 전기장, 압력, 지자기 왜곡 신호에 감응 하여 발화된다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '기뢰의 제거 방식에는 기뢰 작동 원리를 이용하여 인위적으로 감응시켜 폭발되도록 하는 방법, 기뢰 위치에 폭약을 설치하여 파괴하는 방법, 계류 기뢰의 계류색을 절단하여 수면에 부상시켜 기관포로 사격, 기폭하는 방법 등이 있다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '일반적으로 기뢰탐색함의 Side Looking Multi-beam Sonar를 이용하여 기뢰를 탐색하며 최근의 소해함은 기뢰 소해장치와 탐색장치를 동시에 갖추고 있는 추세이다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '소해장비 기술기뢰함(Mine Wafare Ship)은 기뢰를 부설하는 부설함(Mine Laying Ship)과 부설된 기뢰를  탐색(Mine Hunting)하고 소해(Mine Sweeping)하는 기뢰 탐색함/소해함으로 구분한다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '본 장에서는 대기뢰전 수행을 위한 소해장비 기술과 소해능력에 직접적 영향을 미치는 음향탐지 및 무장 장치에 대해서 언급한다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '이와 같이, 대기뢰전시의 소해용 무인수상정 체계로의 전환은 세계적 발전 추세이다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '소해를 포함한 대기뢰전에 대한 운용개념이 가장 잘 정비되어 있는 미 해군에서도 함정소해와 항공소해의 장점을 조합한 무인수상정 소해체계가 효율적 대안으로 제시되어 개발, 운용 및 시험 중에 있다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '고성능 기뢰에 대한 효과적 작전을 위해 기존 플랫폼 위주에서 네트워크 중심작전, 협동교전이 가능한 형태로 발전되어야 하므로 복잡한 전장환경 하에서도 우군 피해를 최소화하면서 기존 탐색/ 소해함과 협동작전이 가능한  MCM용 무인체계의 획득 운용이 요구된다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '미 해군 상륙작전의 주된 장애가 이라크 기뢰였으며 실제로 1만톤 급 이상 함정 2척이 기뢰 폭발로 큰 손상을 입은 사례가 있다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '소해헬기에서 운용하는 개념으로 체계개발이 완료되었으며, 고도 300m 이상에서 수심 20m까지의 기뢰를 대상으로 하며 포구속력은 1,000~1,300m/s로 알려져 있다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '최근 기술의 발전에 따라 기뢰의 성능이 향상되고 복잡해짐에 따라 대기뢰전의 수행 전력 및 대응방향도 발전되어 가고 있다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '남북전쟁을 통하여 기뢰전은 발전을 계속하였고, 남부 연합은 함정 보유면에서 월등했던 북부 연합 함정에 대응하기 위하여 광범위하게 기뢰전을 펼쳤다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '242 - Fourth-quarter  이처럼 예인식이나 운반식의 어뢰는 특수폭약이나 특수 기뢰의 범주에 속하는데,  그 당시에 어뢰라는 이름으로 통용되었고, 실제로 자체추진식의 어뢰가 개발됨에 따라 기뢰와 어뢰가 구분되고 자체추진식의 어뢰를 본래의 어뢰라 칭하게 되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '242 - Fourth-quarter수 있는 것은 함정의 수면 하를 공격할 수 있는 수중무기인 어뢰와 기뢰가 대표적인 무기체계이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '그러나 기뢰는 부설수단에 크게 의존하는 반면 어뢰는 자항추진으로 표적을 찾아내고 공격하여 임무를 완수할 수 있다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '이중 무인수상정은 LCS07 등에 배치하여 시험 중이거나 전력화 단계이며 대기뢰전 외 다종의 다목적  무인수상정을 운용 및 일부 개발 중이다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '국내에도 기개발된 기뢰 탐지 가능 소나는 다수가 있다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '239 - First-quarter 2018(3) RAMICS  RAMICS(Rapid Airborne Mine Clearance System)은 초공동 기술을 적용한 수중 탄환을 개발하는 프로그램으로, 부유식 또는 얕은 수심의 계류식 기뢰 제거를 목적으로 개발되었다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '현대 기뢰는 음향센서, 자기센서, 압력센서, 진동센서 등 다양한 센서를 이용하는 복합감응 방식을 이용하고 있으나 선진국에서도 유 무인함 공통적으로 음향 및 자기에 대한 소해로 한정하여 운용 혹은 연구개발 진행 중이다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '따라서, 미래전에서도 기뢰는 지속적으로 운용될 것이 예상되므로 대기뢰전 분야에 대한 지속적인 투자가 필요할 것으로 판단된다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '우군 안전과 생존성 확보하의 기뢰 소해를 위해 MCM용 무인수상정 운용은 세계적 추세이며, 미국 및 영국 등 선진국들이 이라크전의 실전 경험을 토대로 보다 개선된 무인체계 개발을 추진 중에 있다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '237 - Third-quarter 2017한국 해군은 소해함을 이용한 대기뢰전 전투 임무를 수행하고 있으므로 함정과 승조원에게는 매우 위험한 전투 환경이다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '국내적으로 기뢰 탐색 및 소해장비 외 대부분의 관련 핵심 기술들은 성숙되어 있으나 USV에 맞도록 개량 혹은 설계 변경하여 체계에 적용할 필요가 있다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '기뢰 탐색 및 소해장비의 성능은 무인수상정 플랫폼 체계의 전체 제원과 성능에 영향을 미치기 때문에 국내 독자 기술 축적이 필수적이며 현재의 미흡한 기술수준을 고려하여 단계적이고 체계적인 기술 개발이 필요하다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '인간의 창의력과 기술의 발전이 부유기뢰와 Spar 어뢰에서 오늘날 함대에 배치된 높은 기술 수준의 음향호밍 어뢰로 수중무기를 발전 시켰다.')
#   - ('국방과학기술플러스_247호(20년도+1분기)', '1 UXO 탐지장비UXO 탐지장비는 지하나 수중의 금속물체에 의한 지구자기장의 왜곡을 탐지하는 장비로써 주로 드론이나 무인기 등에 탑재하여 지뢰나 기뢰탐지 등의 위치를 검출한다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '나아가, 해군에서 현 운용중인 기뢰함, 소해함 체계와의 유 무인 협동작전을 효과적으로 수행할 수 있는 MCM용 무인수상정 개발이 절실히 필요하다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '237 - Third-quarter 2017Black Star•임무: 대기뢰전•체계 성능/제원: 공개 자료 무4)\t 스웨덴 최근 SAM3, Paraya 등의 USV 개발과 무인체계 관련 기술 개선 성과가 알려지고 있다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '2)\t 영국 전통적 해양 강국으로서 무인수상정에 대한 기반기술을 지속적으로 발전시켜 왔으며 SAS를 사용하는 MCM용 무인체계를 프랑스와 공동개발 착수하는 등 무인수상정을 이용한 기뢰처리 체계를 개발 진행중이다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '주요국의 대기뢰전(MCM)용 USV 개발 동향1)\t 미국 미국은 “Organic MCM System”으로 불리는 총 7종의 소해장비를 개발하여 무인수상정, 잠수함, 수상함, 헬기에 분산 탑재하여 기뢰전을 수행하는 개념을 적용 중이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'David Bushnell은 어뢰와 기뢰전의 아버지라 불리며, 수중전에 대한 그의 접근방법은 미국의 어뢰와 기뢰전의 효시이다.')
#   - ('국방과학기술플러스 250호', '전시에 천해 환경에서 항해하는 함정에 위협이 대표적인 병기는 기뢰(Sea Mine)이며, 이 기뢰는 항만이나 해역을 봉쇄 또는 방어하는 가장 효과적인 무기체계이다.')
#   - ('국방과학기술플러스 250호', '이러한 전투용 수중드론은 미사일, 어뢰, 기뢰 등을 탑재하여 대잠전, 대수상함전, 대기뢰전 및 대지전 등 다양한 성분작전 임무를 수행할 예정이다.')
#   - ('국방과학기술플러스 250호', '이는 현재 유인 핵잠수함이 수행하는 임무를 대신하여 수행할 수 있는 것으로 간주되고 있으며, 순항 미사일 및 어뢰 발사 플랫폼 또는 기뢰 부설 등 임무를 수행할 수 있을 것이다.')
#   - ('국방과학기술플러스 250호', '이는 미 해군의 LDUUV 프로젝트와 거의 같은 크기로, 더 작은 UUV 또는 잠재적으로 수중무장이나 기뢰를 운반할 수 있을 정도의 크기로 알려져 있다.')
#   - ('국방과학기술플러스 250호', '이 초대형 수중드론은 결국에는 대잠전(ASW), 기뢰전(MCM), 대수상함전(ASuW), 정보감시정찰(ISR), 그리고 특수전 지원임무 등 복합작전을 수행할 수 있도록 할 예정이고 프로젝트가 잘 진행되면 핵무장까지 고려하고 있는 것으로 알려져 있다.')
#   - ('국방과학기술플러스 250호', '기존의 유인잠수함에서 수행하는 대부분의 성분작전인 대잠전, 대수상함전, 감시정찰, 기뢰전, 특수전 지원 및 대지전 임무 등을 수행할 수 있으며, 초대형 수중드론은 핵무장도 가능할 것으로 예상된다.')
#   - ('국방과학기술플러스 250호', '미 해군은 수중드론 탑재 수중무장으로써 지능형 자율어뢰, 자율 자항기뢰, 소형미사일 등을 개발하고 있으며, 수중드론에서 운용할 수 있도록 기존의 수중무장을 개량하는 여러 가지 프로젝트도 수행하고 있다.')
#   - ('국방과학기술플러스 250호', '기뢰는 적은 비용으로도 적에게 막대한 피해 및 심리적 부담을 줄 수 있는 병기로서, 현대전은 물론 미래전의 경우에도 지속적으로 활용될 것으1\t\t  개요국방과학연구소 해양기술연구원수석연구원 양창섭로 예상된다.')
#   - ('국방과학기술플러스 250호', '최근 개발되는 기뢰는 부설 해역 다변화, 탐지 능력 및 파괴 범위 증대, 대기뢰전 세력에 대한 대응 능력 향상 등으로 천해에서의 소나 및 무인기뢰처리기에 의존한 탐지 및 제거에는 한계가 있다.')
#   - ('국방과학기술플러스 250호', 'Orca 프로젝트는 다양한 수중무장을 탑재하기 위한 운용개념(CONOPS)을 연구하고 탑재 하중의 통합과 기뢰, 어뢰 등을 통합 운용할 수 있는 연동기술을 개발할 예정이다.')
#   - ('국방과학기술플러스 250호', '걸프전 이전까지 대부분의 국가들은 유인 소해함에 의존한 기뢰 소해 작전이 주류를 이루었으나, 걸프전 이후부터 본격적으로 무인 소해정 개발을 착수하여 현재 일부 국가에서는 이미 전력화되어 운용 중에 있다.')
#   - ('국방과학기술플러스 250호', '현재 미국 해군에서 운용 중인 무인 기뢰 소해장비는 UISS(Unmanned Influence Sweep System)이며, 기존의 항공 소해장비와 유인 함정 소해장비의 장점만을 택한 방식이다.')
#   - ('국방과학기술플러스 250호', 'Proteus는 주로 탑재물 통합을 위한 연동시험, 최신의 자율운항기술 시험, 장거리 및 원격 운용기술 시험, 해저면에 기뢰 부설 및 주기적인 검사, 해저 음파탐지기 조사 및 파괴, 다이버 및 수중무장 수송 같은 수중 기반시설 검사를 포함한 여러 가지 임무용으로 사용될 수 있도록 다목적으로 개발하고 있다.')
#   - ('국방과학기술플러스 250호', '자기 감응기뢰 소해를 위해서는 다수의 영구자석 봉(Dyad) 배열을 사용하며, 음향 감응기뢰 소해는 별도 부착된 음향신호 발생기(AAG, Advanced Acoustic Generator)가 담당한다.')
#   - ('국방과학기술플러스 250호', '복합재 선체는 근접 기뢰 폭발 충격에도 견딜 수 있도록 설계되었다.')
#   - ('국방과학기술플러스 250호', '영국 해군은 ARCIMS 체계의 성공적인 시험평가를 통해 유인 기뢰 소해 개념에서 무인 기뢰 소해 개념으로 패러다임의 변화를 가져 왔으며, 현재 기존 운용 중인 Hunt급 소해함을 2대의 USV 운용 모함으로 활용하기 위한 전면 개조 작업이 진행될 예정이다.')
#   - ('국방과학기술플러스 250호', '영국영국 국방성은 자국 방산업체인 Atlas Electronik UK와의 계약을 통해 ARCIMS(ATLAS Remote Combined Influence Minesweeping System) 자율 무인 기뢰소해 시스템을 개발하여 왔으며, 2020년  초반에 캐나다 해역에서의 혹한 운용 시험을 성공적으로 완료하였다.')
#   - ('국방과학기술플러스 250호', '그리고 부수적으로 대형급 UUV를 운반하고, 기뢰를 부설하는 대기뢰전(MCM), 정보 감시 및 정찰(ISR) 임무 등도 수행할 것이다.')
#
# 기총 (1건):
#   - ('국방과학기술플러스 250호', '전통적인 기총대신 전방향으로 발사가 가능한 터렛(turret)에 장착된 레이저 무기가 항공기에서 활용가능하게 될 경우 이를 전술한 전방향 영상인식기술과 결합할 경우 가공할 성능이 예상되며, 이는 알파고 쇼크에서 겪은 경험에 비추어 볼 때 숙달된 조종사의 경험에 기반을 둔 현재의 근접 공중전의 양상을 근본적으로 바꿀 수 있을 것으로 예상된다.')
#
# 다연장로켓포 (1건):
#   - ('국방과학기술플러스_242호(2018년+4분기)', '3) BM-21 (122 mm GRAD 9M22U)  BM-21은 122 mm 구경의 다연장로켓포로서 1963년 소련 육군에 실전배치 되었으며 50개국 이상이 널리 사용하는 다연장로켓이다.')
#
# 대륙간탄도미사일 (1건):
#   - ('국방과학기술플러스_246호(19년도+4분기)', '그리고 이러한 장점으로 인해 초창기 대륙간탄도미사일이나 미국의 X-15, 머큐리, 제미니 계획 등에 적용되었다.')
#
# 독도함 (1건):
#   - ('국방과학기술플러스_235호(2017년+1분기)', '• SIMDIS Plug-In 소프트웨어 개발한국해군이 운용하고 있는 함정의 전투체계는 크게 외국으로부터 도입된 전투체계와 LPH(독도함) 이후 건조되는 함정(PKG, FFG)에 탑재되는 국내개발 전투체계로 구분할 수 있다.')
#
# 라팔 (3건):
#   - ('국방과학기술플러스 249호', '라팔 전투기는 초기 개발과정에서 잠시 수동위상배열 레이다를 채택하였다가 최종모델에는 AESA 레이다로 변경하였다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '또 다른 노력으로 2016년 인도는 프랑스로부터 라팔 36기를 도입하였다.')
#   - ('국방과학기술플러스_235호(2017년+1분기)', '라팔 F2/F3의 임무컴퓨터인 MPDU (Modular Data Processing Unit)는 ASAAC의 STANG 4626 규격을 적용하였다.')
#
# 무인전투기 (12건):
#   - ('국방과학기술플러스 249호', '5단계 수준의 통합이 이루어졌으며 , 향후 개발되는 6세대 전투기 혹은 무인전투기는 3세대 혹은 4세대의 센서 융합이 이루어질 것이다.')
#   - ('국방과학기술플러스 250호', '앞서 소개한 여러 제어 기법은 향후 무기체계에 실제 적용을 위해서는 추가적인 연구가 필요하지만 잠재적 효용성이 매우 높을 것으로 생각되며, 특히 최근 개발되고 있는 다양한 센서 관련 기술의 효율적인 융합을 통해 혁신적인 무인전투기 체계가 개발될 수 있을 것으로 기대된다.')
#   - ('국방과학기술플러스 250호', '자율화시스템 기술은 특히 군사용 분야에서는 기존의 정찰 및 공격형 유인기의 무인화  뿐만 아니라 지능형 군집(Swarm) 드론 무인 체계나 유·무인통합 운영 체계 및 무인전투기 등을 위해 필요한 핵심기술이다.')
#   - ('국방과학기술플러스 250호', '현재 선진국에서는 공대공 등 다양한 임무를 수행하기 위하여 자율화 수준 3~4단계의 무인전투기 개발 기술을 연구하고 있으나 현재 기술 추세로 볼 때 2030년대 후반 또는 40년대 이후나 가능할 것으로 예상하고 있다.')
#   - ('국방과학기술플러스 250호', '중앙 집중형은 무인전투기 편대와 같이 상위 계층이 하위 계층을 통제하는 데 반해, 분산형은 무인체 간에 동등한 권한을 갖고 협력하는 체계로서, 실질적인 군집무인체계라 할 수 있다.')
#   - ('국방과학기술플러스 250호', '무인전투기 자율화시스템 개발을 위한 자율화 수준은 미 국방성 자율화 수준 기준으로 완전 자율화를 의미하는 4단계가 요구되고 있으나 현재 운용중인 무인기 Predator, Global Hawk의 자율화 수준이 2단계이며, 최신예 무인전투기 X-45 역시 2~3단계 수준에 머물고 있다.')
#   - ('국방과학기술플러스 250호', '적의 방공망에 근접 또는 침투하여 무력화시키는 대공제압 임무는 현재 스텔스 유인전투기, 저공침투 유인전투기 등을 활용하여 수행 중이나, 생존성 및 임무 성공률 향상을 위하여 1990년대 말부터 무인전투기에 대한 연구가 수행되고 있다.')
#   - ('국방과학기술플러스 250호', '향후 개발이 예상되는 무인전투기의 임무가 점차 확장될 경우, 유인전투기간의 교전은 무인전투기로의 대체될 것으로 예측된다.')
#   - ('국방과학기술플러스 250호', '따라서 무인전투기의 공중전 임무를 위해서는 유인조종사와 마찬가지로, 교전 상황을 인식하고 전투기의 한계 성능을 최대한 활용하여 해당 시점에 필요한 적절한 기동을 선택할 수 있는 전술 기동 제어 기법이 요구된다.')
#   - ('국방과학기술플러스 250호', '이 같은 자율 근접 공중전 알고리듬은 독자적인 무인전투기 뿐만 아니라 유인전투기를 보조하는 윙맨(Wingman) 개념 보조전투기에도 적용가능하며, 유인전투기 조종사의 판단을 보조하는 용도로도 활용 가능하다.')
#   - ('국방과학기술플러스 250호', '이상과 같이 근접공중전 기술 개발 동향과 이를 무인전투기에 도입하는 방안에 대해 고찰해 보았다.')
#   - ('국방과학기술플러스 250호', '무인전투기 개발을 위해서는 적진 근접/침투 감시정찰, 적방공망제압, 고가치 목표공격 등 초기작전 수행에 필수적인 스텔스, 고속/고기동/고성능 등의 기술이 요구된다.')
#
# 미사일 방어체계 (1건):
#   - ('국방과학기술플러스_248호(20년도+2분기)', '미사일 방어체계 Ⅱ┃ 47상승단계요격체계는 크게 탐지체계와 지휘통제체계, 요격체계로 이루어진다.')
#
# 박격포 (1건):
#   - ('국방과학기술플러스_244호(2019년+2분기)', '운용형태는 화포나 박격포, 소총, 유탄발사기에서 발사 후 일정 시간이 지나면 주날개와 꼬리 날개를 전개하는 탄도비행형 정찰포탄, 화포에서 발사 후 포탄내부의 영상송신 자탄을 방출하고 자탄은 낙하선을 전개하여 영상과 좌표를 지상중계소로 전송하는 자탄 방출형, 그리고 포탄내부에 UAV를 방출하여 UAV방출형으로 정찰포탄을 분류하고 있다.')
#
# 벙커버스터 (1건):
#   - ('국방과학기술플러스_248호(20년도+2분기)', '탄두 폭발 현상벙커버스터와 같은 지하관통 탄두를 제외한 일반적인 고폭 탄두의 폭발은 크게 공중, 지면폭발로 구분할 수 있다.')
#
# 사드 (1건):
#   - ('국방과학기술플러스_248호(20년도+2분기)', '이 중 현재 우리가 언론에서 흔하게 듣는 천궁2, 패트리엇이나 사드(THAAD1)) 등의 체계는 탄도탄의 종말단계 요격을 위한 것이며 SM-3, GBI2) 등의 체계는 중간단계 요격을 위한 것이다.')
#
# 세종대왕함 (1건):
#   - ('국방과학기술플러스_235호(2017년+1분기)', '한국 해군은 현재까지 미해군과 계약을 통해 DDH-Ⅱ급 5척(충무공 이순신함(’04/’06), 문무대왕함(’08), 최영함(’12), 왕건함(‘14), 강감찬(’16)), DDG 구축함 3척(세종대왕함(’10), 율곡 이이함(’12), 서애 류성룡함(’14))의 CSSQT을 실시한 바 있다.')
#
# 수리온 (2건):
#   - ('국방과학기술플러스 250호', '탑재장비 기술  국내에서는 사단급 무인기, 차군 무인기 및 중고도 무인기 등의 개발을 통해서 무인기와 지상통제장치간의 데이터 링크 시스템은 개발된 바는 있으나, 수리온 등과 같은 유인 헬기에 탑재할 수 있을 수준의 소형/경량화 된 데이터링크 시스템은 개발된 바가 없다.')
#   - ('국방과학기술플러스 250호', '국내에는 수리온과 소형 무장헬기 등의 개발 경험을 통해 헬기 내 임무장비들을 운용 및 제어하는 OFP 기술은 획득되었다고 볼 수 있으나, 유인헬기와 무인기간의 상호 운용을 위한 OFP 설계 기술은 확보되지 않았다.')
#
# 신궁 (1건):
#   - ('국방과학기술플러스 249호', '또한 기존 도입 열전지를 적용하던 휴대용 대공유도무기(신궁), 단거리 지대공 유도무기(천마) 등에도 국산 열전지를 대체하여 적용하고 있다.')
#
# 아파치 (8건):
#   - ('국방과학기술플러스 250호', '2006년에는 아파치 헬기에서 고정익 무인기 Hunter를 조종하는 장비를 개발하였고, 2007년부터는 UH-60 블랙호크에 상호운용 LOI 2급 장비인 VUIT29)를 탑재하여 무인기로부터 비디오 영상을 직접 수신하도록 하여 상황인식 능력을 개선하였다.')
#   - ('국방과학기술플러스 250호', '2011년에는 아파치 헬기, OH-58D 카이오와(Kiowa) 공격정찰 헬기와 RQ-11 Raven, RQ-20 Puma, MQ-5 Hunter, RQ-7 Shadow 및 MQ-1C Gray Eagle등의 고정익 무인기간의 유무인 협업(MUM-T) 작전능력을 수행하는 시범비행을 한 바 있다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '아파치의 유무인 협업 개발진행과정은 다음과 같다.')
#   - ('국방과학기술플러스 250호', '2009년에는 아파치 헬기에서 보잉 H-6 리틀버드(Little Bird) 다목적 무인 헬기를 조종하는 시연비행을 수행한 바 있다.')
#   - ('국방과학기술플러스 250호', 'AH-64E 아파치 헬기에 장착된 UTA는 TCDL을 장착한 무인항공시스템(UAS, Unmanned Aerial System)과도 호환 가능하다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '아파치(AH-64E)에 적용된 유무인 협업사례유무인 협업은 미국 DARPA에서 98년 기초연구인 SEC(Software Enabled Control) 프로그램을 시작으로 현재 MUM-TX가 개발진행중에 있으며, AH-64E에 적용하여 실전 배치되고 있다.')
#   - ('국방과학기술플러스_237호(2017년+3분기)', '미군은 2014년 아프카니스탄에서 무인기(MQ-1C, Grey Eagle)에 장착된 감지기로 부터 지능정보를 획득 후 아파치(AH-64E)에서 무인기에 장착된 미사일(Hellfire)로 공격까지 실시간 연동을 성공적으로 수행하였다.')
#   - ('국방과학기술플러스_235호(2017년+1분기)', '3) Matei Zaharia, Databricks하둡의 정체/부진과는 다르게 Databricks사가 개발한 아파치 스파크의 지속적 성장이 예측된다.')
#
# 어뢰 (112건):
#   - ('국방과학기술플러스_242호(2018년+4분기)', '242 - Fourth-quarter  이처럼 예인식이나 운반식의 어뢰는 특수폭약이나 특수 기뢰의 범주에 속하는데,  그 당시에 어뢰라는 이름으로 통용되었고, 실제로 자체추진식의 어뢰가 개발됨에 따라 기뢰와 어뢰가 구분되고 자체추진식의 어뢰를 본래의 어뢰라 칭하게 되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '242 - Fourth-quarter수 있는 것은 함정의 수면 하를 공격할 수 있는 수중무기인 어뢰와 기뢰가 대표적인 무기체계이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '그러나 기뢰는 부설수단에 크게 의존하는 반면 어뢰는 자항추진으로 표적을 찾아내고 공격하여 임무를 완수할 수 있다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '인간의 창의력과 기술의 발전이 부유기뢰와 Spar 어뢰에서 오늘날 함대에 배치된 높은 기술 수준의 음향호밍 어뢰로 수중무기를 발전 시켰다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'David Bushnell은 어뢰와 기뢰전의 아버지라 불리며, 수중전에 대한 그의 접근방법은 미국의 어뢰와 기뢰전의 효시이다.')
#   - ('국방과학기술플러스 250호', '이러한 전투용 수중드론은 미사일, 어뢰, 기뢰 등을 탑재하여 대잠전, 대수상함전, 대기뢰전 및 대지전 등 다양한 성분작전 임무를 수행할 예정이다.')
#   - ('국방과학기술플러스 250호', '이는 현재 유인 핵잠수함이 수행하는 임무를 대신하여 수행할 수 있는 것으로 간주되고 있으며, 순항 미사일 및 어뢰 발사 플랫폼 또는 기뢰 부설 등 임무를 수행할 수 있을 것이다.')
#   - ('국방과학기술플러스 250호', '미 해군은 수중드론 탑재 수중무장으로써 지능형 자율어뢰, 자율 자항기뢰, 소형미사일 등을 개발하고 있으며, 수중드론에서 운용할 수 있도록 기존의 수중무장을 개량하는 여러 가지 프로젝트도 수행하고 있다.')
#   - ('국방과학기술플러스 250호', 'Orca 프로젝트는 다양한 수중무장을 탑재하기 위한 운용개념(CONOPS)을 연구하고 탑재 하중의 통합과 기뢰, 어뢰 등을 통합 운용할 수 있는 연동기술을 개발할 예정이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '이처럼 자력으로 표적을 탐지하여 성공적인 공격을 하기 위한 어뢰에 요구되는 능력은 여러 가지가 있겠지만 어뢰의 특성을 대표할 수 있는 요소를 살펴보면 다음과 같이 정리할 수 있다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'Mk 48 ADCAP 어뢰는 모든 미국 잠수함에 탑재되며, 유선유도를 사용하거나 사용하지 않고 운용이 가능하다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '어뢰 기술의 발전 전망  수 만 톤에 이르는 전함과 항공모함을 비롯하여 적게는 수백 톤에 이르는 고속정에 이르기까지 단 몇 번의 공격으로 날려 보낼 수 있는 것이 바다에서 전쟁을 치르는 우리 인류의 오랜 꿈이었을 것이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '바) Mk54 어뢰  1999년부터 개발을 시작해 2003년 양산에 들어간 최신 대잠 경어뢰이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'Mk 50 어뢰는 길이가 9 피트 이고, 무게가 750 파운드 이며, 40 노트를 초과하는 속력에 20,000 야드의 주행거리를 가지며, 대략 100 파운드의 지향성 탄두가 장착된다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'Mk 50 어뢰는 ASW 항공기, 헬리콥터, 또는 수상 전투함으로부터 발사된다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '그 후 펜실베이니아 주립대학교의 APL(Applied Physics Laboratory)에서 연구를 재개하였는데, 그것은 해군의 신형 경어뢰 사업의 일부분이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'Mk 50은 증기를 생산하기 위한 발열화학 물질을 사용하는 증기 구동형 어뢰이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '마) Mk50 어뢰  미국 해군은 소련이 고속 심해잠수 위협인 알파급 잠수함을 취역시켰던 1972년에 Barracuda란 명칭으로 Mk 50 어뢰의 개발을 시작하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '다) 유선 유도 어뢰의 등장  Mk 39 어뢰는 2차 대전 후에 중어뢰의 중기유도 기술을 개발하기 위한 목적으로 시작되었으며, 대략 120발의 Mk 27 Mod 4 어뢰가 1956년에 Mk 39 어뢰로 개조되었고, 목적은 유선유도 기술의 개발에 있었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'Mk 48 어뢰는 미국어뢰역사에 있어서 현재수준의 기술을 대표하는 상징으로 현재도 후속개발은 계속되고 있고, 개선된 중기유도를 갖는 Mod 3 어뢰는 현재 생산 중에 있다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '이에 따라 1940년 미국 NDRC에서는 음향호밍어뢰를 개발하기 위한 과제를 지원하기로 결정하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '이 어뢰는 표적함의 추진기 캐비테이션에서 발생되는 소음에 의해 표적을 접촉하고 호밍하게 된다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '(전해액의 비중검사, 전해액 보충과 주기적인 충전 등)다) 수동 음향호밍 어뢰 개발  1943년, 종말호밍을 하는 음향어뢰(GNAT: German Naval Acoustic Torpedo)를 독일해군이 사용하고 있다는 사실이 연합군에 알려지게 되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '2차 대전에 사용된 전기식 어뢰는 전원으로 납 2차 전지를 사용하였는데, 이 전지는 주기적인 정비가 요구되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '전기식 어뢰는 공기탱크가 전지부로 교체된다는 점에서 이전의 기계식어뢰와 다르고, 엔진과 부속품들은 전동기로 대체되었으며, 사용 가능한 전원과 전기식 제어가 일반적으로 적용되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '배기가스에 의한 항적이 없는 것은 물론, Mk 18과 같은 전기식 어뢰는 열기관 어뢰의 제작에 소요되는 노력의 70 % 수준만으로 완성이 가능하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '의 Sharon 시설에서 Mk 18 어뢰의 개발로 이어졌다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '이 분과의 첫 번째 목적은 잠수함의 정확한 탐지와 대잠장치에 관련된 모든 요소와 현상들을 가능한 완벽하게 연구하여, 수중음향의 모든 단계에서 체계적인 연구를 바탕으로 2차 대전 기간 동안에 음향호밍어뢰의 실용개발과 배치를 가능하도록 기초 작업을 하는 것이었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'Tate가 위원장인 제 6분과는 수상/수중전 분과로 어뢰 연구개발 업무를 담당하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '1930년대는 Mk 13어뢰(항공기용), Mk 14어뢰(잠수함용), 그리고 Mk 15어뢰(구축함용)가 개발 후 실전 배치되었으며, 이러한 어뢰들은 2차 대전 개전 초기에 현대식 어뢰재고를 구성하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'Mk 18 어뢰는 2차 대전 기간 동안에 일본의 선박 1,000,000톤가량을 침몰시킨 것이 인증 되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '능동호밍을 할 때 어뢰는 어뢰자신이 송신한 신호가 표적에서 반사 되어 돌아온 신호에 의하여 표적 접촉을 한다는 것이 듣고만 따라가는 수동호밍과는 다르다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '두 가지 버전에 대한 평가를 거쳐 Mk 48 Mod 1 어뢰가 양산과 함대 전력화 장비로 1971년에 선정되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'Mk 48 어뢰는 수상함이나 고속의 심해 잠수함을 표적으로 탐지공격하는 장거리, 고속, 심해, 유선유도, 음향호밍 하는 무기체계이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '1976년 Mk 45 어뢰는 비핵탄두인 Mk 48 어뢰로 대체되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'MK 37 어뢰보다 더 빠르고 정밀한 어뢰개발을 위한 어뢰 재구성(RETORC: Research Torpedo Re-Configuration) 사업이 1956년에 시작되어, Mk 45어뢰가 1963년에 함대에 배치되었는데, 40노트 속력이며, 11,000에서 15,000야드의 항주거리를 가지며, 핵탄두가 장착되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '는 외형적으로 Mine Mk 24와 유사한 최초의 능동호밍 어뢰인 Mk 32 어뢰 개발을 시작하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '라) Mk48 어뢰  1950년대 접어들어 잠수함이 원자력 추진을 적용하여 수중에서 20노트의 속력을 확보함에 따라 고속의 잠수함을 공격하기 위하여 더 빠른 속도의 어뢰가 요구되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '5배 이상 빠른 속력이 요구되고, 추진소음은 어뢰가 표적을 탐지하는데 방해가 되지 않을 수준으로 낮아야 한다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '다연장 발사관과 사격통제장치, 그리고 Mk 44 어뢰를 payload로 하는 ASROC missile 시스템이 1962년경에 부대에 배치되었고, 현재는 Mk 46 어뢰를 missile payload로 사용하는 ASROC 시스템은 순양함, 구축함 그리고 호위함 등에 두루 사용되는 무기체계이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '그 이후 보다 가볍고 향상된 추진특성과 높은 신뢰성을 갖는 경어뢰 확보를 위해 캠엔진 시스템이 장착된 Mk46 어뢰를 1963년부터 양산을 시작하였고, 현재 전력화 중인 대잠 경어뢰이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '차세대 대잠 경어뢰는 1952년경에 시작된 동시개발 프로그램인 EX-2로부터 발전되었고, 1956년 가을에 Florida의 Key West에 소재한 Naval Ordnance Unit(NOU)에서 기술 평가를 실시한 후에 후속개발 및 양산과 함대 배치를 위한 모델을 선정하고, Mk 44로 명명되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '이러한 배경으로 대잠 경어뢰의 개발이 시작되었고, 회전익/고정익 항공기에서 사용하기 위한 대잠 경어뢰를 확보 할 뿐만 아니라 저속이나, 상대적으로 정숙한 잠수함을 대상으로 어떤 형태의 초계함정에서도 사용의 가능성을 확보하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '242 - Fourth-quarter  2차 대전 종전 초기에 저가의 ASW 경어뢰에 대한 해군의 요구조건이 제안되었고, 1950년 대잠 경어뢰에 대한 최대중량을 실현 가능한 350 파운드로 설정함에 따라, 2차 대전 기간에 사용된 1000파운드 중량의 어뢰와 동일한 성능을 달성하는 것은 불가능 하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '그 후, 유선유도 성능을 갖는 Mk 37 Mod 1과 Mod 3 어뢰가 후속적으로 개발되었고, 1972년부터 단계적으로 Mk 48로 대체 되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '따라서 어뢰의 추진시스템은 고출력이면서 저소음 특성을 실현하기 위한 추진방식과 추진기 설계 기술이 핵심적인 기술 요소이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '표적탐지와 정밀유도 능력은 M&S 환경에서 충분히 연구하고 전투실험상으로 HILS(Hardware In the Loop Simulation)를 수행함으로써 어뢰의 실제 능력을 검증할 수 있을 것이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '에서 미 해군을 위한 어뢰개발과 제작관련 사업은 1920년대 초기에 모두 종료되고, Newport의 어뢰창이 어뢰 연구개발, 설계, 제작, 정비 및 시험에 관한 중심 기관이 되었다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '(1) Supercav  초공동 어뢰 체계에 대한 연구로는 ONR 주도로 대어뢰요격용(anti-torpedo) 초공동 어뢰 개발을 위한 “SUPERCAV ATD” 프로그램이 진행되어, 2002년 Euro Naval 전시회를 통해 개발업체인 Lockheed Martin 사가 시험발사체를 공개하였다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', 'Barracuda는 적 어뢰 요격 및 근거리 수중표적 공격용으로 개발되었으며, 해상시험을 통해 200노트(360km/h) 속도에서 안정적인 직진 주행과 완만한 형태의 곡선 궤적에 대해 방향제어가 가능함을 입증하였다.')
#   - ('국방과학기술플러스 250호', '86 ┃ 국방과학기술플러스＋무인항공기는 전자기파, 무선전신 등의 과학기술적 업적을 바탕으로 무선조종 개발에 힘입어 1910년대부터 공중발사 어뢰, 강습무인기, 공중타겟, 정찰무인기 등으로 활용되어왔다.')
#   - ('국방과학기술플러스 250호', '특히, 러시아의 초대형 수중드론인 자율 핵어뢰와 드론 핵잠수함 등의 제원 분석과 특징을 살펴보았으며, 핵 억지력의 다변화를 위해 핵무장까지 탑재하여 운용할 수 있는 수중드론의 한계가 어디까지인지 또한 미래 수중전쟁은 어떻게 수행될 것인지에 대한 스스로의 질문에 해답을 얻을 수 있었다.')
#   - ('국방과학기술플러스 250호', '이 수중원자력 플랜트의 첫 번째 군사적 적용은 거대한 포세이돈 자율 핵어뢰 추진시스템의 동력원을 제공하는 에너지원이다.')
#   - ('국방과학기술플러스 250호', '이는 잠수함 발사 탄도 미사일(SLBM)의 약 2배, 일반 중어뢰의 30배 크기 정도로서 주요 제원 및 사양은 표 1에 주어져 있다.')
#   - ('국방과학기술플러스 250호', '미국의 수중드론 개발현황미 해군은 순항 미사일, 어뢰, 지뢰 및 소형 UUV로 무장한 초대형급 수중드론을 목표로 오르카(Orca) XLUUV를 개발하고 있다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', 'Shkval은 초공동 기술을 적용한 최초의 어뢰로서, 초기형은 탐지기가 없는 비유도 방식(unguided)으로 직주형 어뢰에 가까웠으며, 최고 속도 200노트(360km/h)로 개발되었다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '러시아  러시아는 초공동 기술을 주로 어뢰 체계에 적용하는데 관심을 가지고, 구소련 시절인 1950년대부터 연구개발에 착수하여 Shkval이라 명명된 고속로켓 어뢰를 1970년대 말부터 실전배치하였다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '특히 초공동 어뢰가 침로를 변경할 경우, 캐비테이터 받음각 및 어뢰 자세 변화로 인해 공동 형상이 비대칭적으로 변화하고 몸체의 일부가 공동을 벗어날 수 있다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '통상적인 어뢰의 경우에는 방향타(control fin)을 통해 자세 및 운동제어가 가능하지만, 초공동 어뢰의 경우 공동의 형상이나 어뢰의 자세에 따라 방향타의 일부 또는 전부가 공동에 잠기게 되어 제어가 보다 어려워지게 된다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '파괴위력  영국은 Spearfish에 적용된 것과 같이 어뢰의 탄두를 Omni-directional 폭발과 지향성 폭발이 가능하도록 개발하여 수상함과 잠수함 표적에 따라 폭발 모드를 선택하여 발사함으로서 파괴위력을 극대화 시키고 있다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '이처럼 신형 중어뢰의 탄두는 일반적으로 200~300kg 범위여서 1발 공격으로 대형 전투함을 효과적으로 격침시킬 수 있을 것으로 판단되어 더 이상의 탄두 대형화는 없을 것으로 예상된다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '현대식 어뢰는 20세기 해전의 핵심적인 요소 중의 하나이고, 단 한 발로 함정과 잠수함을 무력화하는 어뢰의 성능은 항상 해군 지휘관들의 마음속에 자리하고 있다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '미 해군의 도전은 현세대 어뢰를 개선하는 것뿐만 아니라 차세대 수중무기를 위한 새로운 기술을 개발하는 것으로 속도, 스텔스 기능, 그리고 새로운 교전개념을 적용함으로서, 현대식 어뢰는 우리의 적에 대하여 명백한 우위를 유지하는데 필요한 능력을 지속적으로 제공할 것이다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '초공동 무기체계는 2차 세계대전 후 1950년대부터 주로 구소련(현 러시아)을 중심으로 본격적인 연구가 수행되었으며, 1970년대 후반에는 러시아에서 최초의 직주형 초공동 어뢰인 Shkval을 개발하여 실전배치하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '이 항적을 탐지하는 기술을 개발하여 표적탐지 수단으로 이용하면 표적은 어뢰 공격에 대항하기 위한 마땅한 대응수단이 없어지게 된다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '현재까지 개발된 초공동 무기체계로는 대표적으로 초공동 탄환(supercavitation ammunition)과 초공동 어뢰(supercavitation torpedo)를 들 수 있는데, 모두 초공동 기술을 이용한다는 기본 개념은 동일하지만 소요되는 핵심기술에 있어서는 조금씩 차이가 있다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '여기에서는 초공동 무기체계 중에서도 주로 초공동 어뢰 체계에 해당하는 핵심 소요기술에 대해서만 살펴보기로 한다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '초공동 어뢰 체계를 위한 핵심 소요기술은 크게 초공동 발생/유지 기술, 수중로켓 추진기술, 초공동 상태에서의 탐지기술 및 유도/제어 기술로 분류할 수 있다.')
#   - ('국방과학기술플러스_235호(2017년+1분기)', '이를 Python 스크립트 언어와 접목하여 어뢰가 잠수함을 탐지하는 센서 정보를 재구성하고 다양한 관측자 각도와 방향에서 어뢰와 잠수함간의 조우상태를 볼 수 있도록 시연되었다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '초공동 발생/유지 기술  초공동 어뢰가 초공동 상태를 유지하면서 고속 주행하기 위해서는 무엇보다 초공동을 안정적으로 발생시키고 유지시키는 기술이 중요한데, 이를 위해서는 공동 발생 장치 즉, 캐비테이터(cavitator)가 필수적이다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '캐비테이터는 초공동을 발생시키기도 하지만 동시에 초공동 어뢰에 항력으로 작용하는 부분이기도 하다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '수중로켓 추진기술  초공동 어뢰는 초공동 상태까지 도달할 수 있는 강력한 초기 발사속도와, 200노트 이상의 초고속 주행을 위해 에너지 밀도가 매우 높은 로켓 추진방식이 필요하다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '로켓 추진방식으로는 일반적인 고체로켓 추진 방식을 사용할 수있는데 실제 독일의 초공동 어뢰 Barracuda와 미국에서 개발중인 것으로 알려진 Supercav에 적용된 바 있다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '반면, 러시아의 초공동 어뢰 Shkval 같은 경우에는 해수 흡입형 로켓추진기관을 사용하는데, 이 방식은 해수를 흡입해서 해수로부터 산화제를 얻어내고 해수와 쉽게 반응하는 금속 분말 연료를 연소시켜 강력한 추진력을 만들어 낸다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '초공동 상태에서의 탐지기술  초공동 어뢰가 무기체계로서의 효용성을 극대화하기 위해서는 초공동 상태에서 수중 표적을 탐지하고, 추적할 수 있는 유도/제어 기술이 필요하다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', 'Defense Science & Technology Plus010  먼저 수중 표적 탐지기술 같은 경우에는, 음향센서를 어뢰 내부에 탑재해야 하는데, 초공동 어뢰는 이 음향센서를 해수와 접촉하는 유일한 부분인 캐비테이터 내부에 위치시켜야 하는 문제가 발생한다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '공동 현상이란 일정한 온도 하에서 물의 압력이 증기압(vapor pressure, Pvapor) 이하로 낮아졌을 때 물이 수증기로 기화(vaporization) 되는 현상으로, 주로 고속 회전하는 프로펠러나 고속 어뢰에서 많이 발생한다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '또한, 1차 대전 기간 동안 독일에서 개발에 성공한 전기추진 어뢰에 대한 관심이 높아졌고, 해군 내부에서 전기추진 어뢰 개발에 대한 업무가 해군 시험소를 중심으로 진행이 되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '그 당시에 시도된 몇 가지의 어뢰들로는 “Lay”, “Lay Haight”, “Ericsson”, “Cunningham”, “Sims-Edison”, 그리고 “Barber”등이 있고, 이 어뢰들의 주요특성은 아래와 같다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '미 해군에서 사용되는 Whitehead 어뢰의 최종모델인 Whitehead Mk 5는 이 개념으로 작동되며 27 노트의 속력으로 4000 야드의 거리를 주행한다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '그 당시까지 자체추진 어뢰는 Whitehead 어뢰가 주도였으나, 미국은 Whitehead 어뢰를 구입하지 않고, 자국의 어뢰를 연구개발 할 계획을 수립하기로 결정하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '영국해군은 1869년 자국 해역에서 Whitehead 어뢰의 성공적인 실탄시험을 확인하고 Whitehead 어뢰에 관심을 가졌으며, 프랑스, 독일, 이태리, 러시아, 중국 해군은 영국해군에 이어서 Whitehead 어뢰를 구입하였으며, 순식간에 Whitehead 어뢰는 전 세계를 대상으로 수출되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '적이 가까이 오도록 기다리는 것 보다는 표적방향으로 주행하여 공격하도록 한 그의 설계는 어뢰에 예전과는 다른 개념의 설계가 적용되는 전환점이 되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '2) 자체추진식 어뢰  1866년 영국의 기술자 Robert Whitehead는 최초로 자체추진 어뢰를 개발하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '미국에서는 2차 대전 말기에  전기추진 방식의 음향호밍어뢰가 실전에 배치되면서 수중유도무기로서 어뢰의 위상이 정립되는 출발점이 되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '이와 같이 대규모 해전을 통하여 어뢰라는 무기체계의 역할과 중요성이 인식되었으며, 추진성능의 향상과 더불어 탐지성능과 제어성능의 중요성이 대두되었고, 독일을 비롯한 각국에서 이를 위한 연구가 비밀리에 진행되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '2차 대전 기간 동안에는 태평양과 대서양에서 새로운 발사수단인 기동성이 뛰어난 함재기와 은밀성이 높은 잠수함을 이용해 더욱 위협적이고 효과적으로 어뢰 공격을 수행할 수 있게 되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '1차 대전이 끝난 후 부족했던 어뢰공격의 효과를 높이기 위한 방안으로 어뢰의 주행속력과 항주거리를 증대하기 위하여 다양한 종류의 추진방식 개발이 시도되었으나 별다른 진전을 보지 못한 상태에서 2차 대전이 발발하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '1차 대전 기간 동안 항공기와 잠수함이 등장하면서 발사 플랫폼이 3차원으로 확대되었고, 어뢰는 더욱 강력하게 수상함 및 수송선단을 공격하는 무기로 운용되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '이 무렵부터 미국에서는 신형 대잠 무기체계 개발에 대한 대대적인 투자가 이루어졌고, 어뢰 기술이 획기적으로 발전하는 계기가 되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '초기의 어뢰는 주로 수상함에 탑재되어 적 수상함을 근거리에서 육안으로 식별한 후 무유도 직진으로 공격하는 형태였으며, 추진방식으로는 압축공기와 경유를 에너지원으로 사용하는 외연기관이 사용되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '어뢰(魚雷)라는 용어는 한자로 어형수뢰(魚形水雷)의 줄임말이고 영어로는 ‘Torpedo’라고 불린다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '머리말 어뢰는 현재 세계 각 국의 해군에서 대 잠수함 또는 대 수상함 전을 위한 수중유도무기체계로 운용되고 있다.')
#   - ('국방과학기술플러스 249호', '열전지 관련 기술의 발전으로 앞으로 미사일, 어뢰 등 다양한 분야에서 활용이 확대될 것으로 예상된다.')
#   - ('국방과학기술플러스 249호', '현재 수중유도무기(어뢰)를 대상으로 유도제어부 등 전자장치 공급전원 이외에 추진모터에 필요한 출력(power)을 열전지로 공급하는 기술에 대한 연구를 진행하고 있다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '현대식 구조의 어뢰는 1866년 Robert Whitehead가 오스트리아의 해군 장교 Giovanni Luppis와 아들 John의 도움으로 개발하였는데, 폭약을 장착한 상태로 표적을 향하여 수상에서 발사되어 수중을 주행한 후 충격폭발에 의하여 표적을 파괴하도록 고안되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '본 내용에서는 미국 어뢰개발에 대한 이해를 돕기 위하여 어뢰개발의 역사 및 미래 발전전망 등에 대한 현황을 개략적으로 살펴보고자 한다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '후에 열기관(hot running) 어뢰를 만들었으며, 이 장치는 성능을 향상시키기 위하여 압축공기를 가열하는 연소실을 사용하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'Whitehead Mk 1, 2, 3 어뢰는 냉기관(cold running) 무기라고 하는데, 냉기관 무기란 압축공기로 작동되는 무기라는 의미이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '55m의 Whitehead  Mk 1, Mk 2, 및 Mk 3 어뢰는 기본적으로 동일하고 기계적인 세부사항만 조금 차이가 있으며, Mk 1과 Mk 2 버전은 길이 5m가 되는 것도 있다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '는 미 해군을 위하여 5가지 형태의 Whitehead 어뢰 300발을 제작하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'Whitehead 어뢰가 개발(1866년)된 지 26년이 지난 뒤에야 미국의 전문가들은 그 가치를 최종적으로 인정하게 되었는데, 이는 아마도 1891년 4월 23일 계류된 상태에서 포함(Gunboat)에서 발사된 Whitehead 어뢰의 공격으로 침몰된 칠레의 반란군함 3500톤급 BLANCO함에 대한 성공적인 어뢰공격에 자극을 받아서 일 것이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '그 당시 거의 대부분의 국가에서는 Whitehead 어뢰를 소유하고 있었기 때문에, 미국은 다른 국가에 뒤쳐질 수도 있다는 걱정에서 벗어나기 위하여 Whitehead 어뢰의 구입을 결정하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'Howell 어뢰는 Whitehead 어뢰가 공급되기 전인 1898년까지 미국전투함에 사용되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '회전하는 플라이휠이 자이로스코프 효과를 만들어 내며, 방위각 편차는 어뢰가 코스를 벗어났을 때 어뢰의 기울기를 감지하는 단진자에 의해 조정되며, 타와 연동되어 있다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '두 개의 평행 축에 연결된 가변 추진기가 플라이휠로부터 베벨기어로 구동되고, 플라이휠의 속도가 감소되면 어뢰의 속도를 일정하게 유지하기 위하여 추진기 피치를 변화시켜 보상을 한다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'Howell은 10,000 rpm을 갖는 132 파운드의 플라이휠에 의해 구동되는 어뢰를 개발 했다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '당시 Newport의 해군 어뢰창은 많은 민군 출신의 발명자들이 제안하는 어뢰에 대한 시제품 제작과 시험을 위한 장소로 널리 이용되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '설계의 수정/보완을 통하여 생산을 위한 계획이 병기감실에 제출되었고, 시험을 위하여 2발의 어뢰가 제작되었지만 추후에 어떠한 조치가 이루어졌는지에 대해서는 더 이상의 기록이 없으며, NTS의 어뢰(Fish Torpedo) 사업은 1874년에 종결되었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '이 연구소에서 개발한 어뢰는 Whitehead 어뢰와 유사하여, 6~8 노트의 속력으로 400 야드 거리를 주행 할 수 있었다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '어뢰발사관에 장치된 증기 터빈은 발사 이전에 플라이휠을 가동시켰으며, 해군은 전술적인 용도로 50발만 생산하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', 'Spar 어뢰가 사용되어 졌는데 폭약장치는 공격하는 함정의 선수에서 앞으로 약 30피트 길이의 튼튼한 막대기 끝에 설치되었으며, 그 폭약으로 상대를 공격하였다.')
#
# 연안전투함 (1건):
#   - ('국방과학기술플러스 250호', '따라서 최근에는 소해 작전을 연안전투함(LCS)의 복합 임무 모듈중 하나로 편성하여 무인 수상정을 이용한 소해 개념을 적용 중에 있다.')
#
# 장갑차 (7건):
#   - ('국방과학기술플러스 250호', '전차, 장갑차와 같은 유인체계를 대상으로 하는 임무통제 기술은 하나의 체계를 여러 명의 운용자가 효과적으로 운용하기 위하여, 수집된 정보의 가시화 및 운용을 위한 인터페이스 등에 대한 기술 개발이 이루어져 왔다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '따라서 앞으로 사거리가 더욱 증대되고, 헬기뿐만 아니라 차량이나 장갑차 탑재용으로 계열화 개발이 진행된다면 이스라엘의 SPIKE 계열과 같이, 무선 데이터링크 적용도 고려해볼 수 있다.')
#   - ('국방과학기술플러스_235호(2017년+1분기)', '국내 개발동향1980년대 이전의 국내 지상전투차량은 M계열의 전투차량을 해외에서 도입운용 하였고, 1980년 후반부터 국내 자체개발에 의한 전차/장갑차 등이 전력화 운용되고 있다.')
#   - ('국방과학기술플러스_235호(2017년+1분기)', '전차(K2)/장갑차(K21)에서도 디지털제어 방식을 적용 중이나 1차원 센서/명령신호를 기반으로 하는 방식이며, 지상로봇에서는 2차원의 영상신호를 저지연/실시간 전송 및 피드백제어에 활용하는 확장된 디지털제어 방식이 적용되고 있다.')
#   - ('국방과학기술플러스_247호(20년도+1분기)', '[그림2,3,4] 지상 플래폼의 경우 비교적 저출력 레이저는 차륜형/궤도형 장갑차에 탑재하고, 고출력 레이저는 트럭 탑재형으로 개발이 진행 중이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '대표적으로 대전차 유도무기는 전차 이외의 표적에도 효과적인 이중목적 탄두 혹은 다목적 탄두를 적용하며, 장착하는 플랫폼도 항공기, 헬기, 장갑차 및 일반 전투차량 등으로 다양화 하고 있다.')
#   - ('국방과학기술플러스_247호(20년도+1분기)', '이외에도 ‘인공지능 기반 시각적 부분 가림 물체 자동 식별 기술’과제를 통해 50%이상의 은폐/엄폐한 전차, 장갑차 등의 물체에 대하여 70%이상의 인식 정확도를 달성하기 위하여 연구를 수행중이다.')
#
# 장사정포 (1건):
#   - ('국방과학기술플러스_244호(2019년+2분기)', '한반도에서 전쟁 발발시 북한군은 초기에 대량의 유도탄과 장사정포병 화력으로 국가 중요시설, 군사시설, 항만, 도로, 주요 도시 등을 파괴하여 초전에 기선을 제압할 것을 예상된다.')
#
# 전익기 (2건):
#   - ('국방과학기술플러스_238호(2017년+4분기)', '이러한 가격 경쟁력의 장점을 활용하기 위해 미국 GE 사의 최신 터보프롭 엔진개발에도 동 연소기 기술이 적용된 것으로 보고되고 있으며 프랑스의 경우, 오래전부터 슬링거 연소기 기술을 회전익기용 터보샤프트 엔진개발에 적용하고 있는 것으로 알려져 있다.')
#   - ('국방과학기술플러스 250호', '또한 2030년대 중반에 도입될 미래 회전익기인 FVL에서도 MUM-T 개념은 중요한 개발요소로 고려되고 있다.')
#
# 전자전기 (20건):
#   - ('국방과학기술플러스_248호(20년도+2분기)', '이러한 원격지원 전자전기에 요구되는 임무를 고려한 주요 요구기능과 성능을 표 2에 나타내었다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '미래 전장 장악능력 확보를 위한 게임 체인저(Game Changer) - 전자전기앞서 언급한 요구능력을 보유한 원격지원 전자전기의 주요 임무는 아군의 다양한 작전수행시 필요한 적 레이더에 대한 전자공격과 적 무선통신망에 대한 전자공격으로 정의될 수 있다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '이와 같은 추세에 맞추어, 본고에서는 전자전기 분류 및 특성, 국외 전자전기 개발/운용 현황 및 국내 전자전기 보유 의미 및 역할에 대해 살펴보기로 한다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '(그림 3(a)) ・ IL-22PP[12]: 러시아의 IL-22PP Porubshchik은 2017년 8월 최초로 공개된 전자전기로 IL-22 ‘Coot-B’ 항공기를 기반으로 제작된 SIGINT 및 원격지원 전자전기이다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '(그림 3(b))・ Y-9G[13]: 중국의 Y-9G는 2014년에 최초로 공개된 전자전기이다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '특히 항공기의 기동성 및 광범위한 작전범위 특성을 이용한 전자전기를 지속적으로 개발하고 있으며, 최근 국내에서도 이러한 전자전기 개발에 대한 움직임이 활발해지고 있다.')
#   - ('국방과학기술플러스_247호(20년도+1분기)', '국내 보유 자체보호 전자전장비는 제한적으로 수집된 신호정보 특성을 기반으로 위협별 대응 전자전기법을 수동 생성하고 라이브러리화하여 탑재 운용되기 때문에, 많은 시간과 전문가의 분석을 필요로 한다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '(그림 3(d))・ HAVA SOJ[16]: 터키가 개발하고 있는 신형 전자전기 체계로 2018년 9월 터키의 전자장비 방산업체인 Aselsan사가 주 계약업체로 선정되면서 개발이 시작되었으며, 통신 및 레이더 전자공격장비가 탑재될 것으로 추정된다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '이와 같이 개전 초 압도적 공격능력 보유효과 확보 및 전쟁 승패에 있어 결정적 요소가 된다는 점에서 전자전기는 미래 전장의 핵심요소, 나아가 미래 전장의 게임 체인저(Game Changer)로서 역할을 담당하게 될 것으로 판단된다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '한반도 주변의 잠재적 위협 고려시, 적 방공망 무력화를 통한 제공권 장악 능력과 적 종심지역 무선통신망 교란 능력 확보를 위해서는 해외 선진국과 마찬가지로 원격지원 전자전기가 반드시 필요하다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '이러한 측면에서, 주변국 전력 확대 및 향후 한반도 정세변화에 대비하여 우리나라 역시 전자전기 개발 및 확보를 추진하여야 할 때이다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '(그림 2(a))・ JH-7 Flying Leopard[8]: 중국에서 운용 중인 전자전기로 성능과 관련된 자세한 내용은 알려지지 않았으며, 기본적으로 자체보호를 수행하는 것으로 판단되나 호위재밍도 수행할 수 있는 것으로 예측되고 있다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '전자전기는 전자공격을 수행하는 항공기로 정의할 수 있으며, 전자공격을 수행하는 방식에 따라 분류될 수 있다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '(그림 2(b))・  J-16D[9]: 2015년 12월에 첫 비행이 수행된 이후 전자전기로서의 능력 확보를 위해 지속적인 개발이 이루어지고 있는 것으로 보이며, 현재까지의 형상적 특징으로 볼 때 주익 끝부분에 AN/ALQ-218과 유사한 전자전 관련 포드를 장착함으로써 이를 통해 레이더 신호를 수신/분석할 수 있을 것으로 판단된다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '원격지원 전자전기는 임무수행 아군기의 생존성 및 임무효율 증대와 개전초 압도적 공격능력 보유효과를 가져올 수 있다는 점에서 미래 전장의 게임 체인저(Game Changer)로서의 역할을 수행할 것으로 기대된다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '아래 내용은 각각의 전자전기에 대한 세부 내용을 나타낸 것이다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '대형 항공기 플랫폼 기반의 전자전기원격지원 재밍을 주 임무로 수행하는 대형 항공기 플랫폼의 전자전기는 다음 그림 3에 나타낸 미국의 EC-130H 및 EC-37B와 러시아의 IL-22PP, 중국의 Y-9G 그리고 터키의 HAVA SOJ로 그 예를 들 수 있다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '다음 내용은 각각의 전자전기에 대한 세부 내용을 나타낸 것이다.')
#   - ('국방과학기술플러스_239호(2018년+1분기)', '2차 공동연구에서는 국과연의 전자전기능이 추가된 연합작전 스펙트럼 관리도구(eCSMT, enhanced CSMT) 개발이 진행이 되었고, CERDEC에서는 새롭게 개발 중인 EMBM (Electromagnetic Battle Management) 스펙트럼 관리도구 개발이 진행되었다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '・ EC-130H[11]: 현재 운용 중인 대표적 전자전기인 EC-130H Compass Call은 C-130H 항공기를 기반으로 개발된 적 방공지휘/통제 체계 마비를 위한 원격 통신교란체계이다.')
#
# 정찰기 (11건):
#   - ('국방과학기술플러스_246호(19년도+4분기)', '이와 같은 추세는 드론, 무인 정찰기 등 항공 관련 무기체계 개발에서도 두드러지게 나타나고 있으며 선진국은 한시라도 빨리 전력화를 위해서 열을 올리고 있다.')
#   - ('국방과학기술플러스_247호(20년도+1분기)', '자기장 센서는 이미 오래 전부터 개발되어 쓰이고 있는 Hall 센서와 Fluxgate 등이 있으현대전에서는 레이더, 정찰기, 위성 등 적성국의 움직임을 파악하기 위한 감시정찰체계의 중요성이 점점 높아지고 있다.')
#   - ('국방과학기술플러스_247호(20년도+1분기)', '2 MAD 시스템  MAD 시스템은 해저를 운항하는 잠수함 등을 탐지하기 위한 장비로써 그림 19와 같이 정찰기의 꼬리부분에 장착하여 지구자기장의 왜곡을 측정하여 잠수함의 위치와 크기를 구분한다.')
#   - ('국방과학기술플러스_247호(20년도+1분기)', '초기 대 잠수함 정찰기에 적용 된 AN/ASQ-10A는 1960년대 개발되었으며 당시 기술 수준으로 가장 정밀한 Fluxgate 자기장 센서를 적용한 것으로 판단된다.')
#   - ('국방과학기술플러스_247호(20년도+1분기)', '이밖에도 일본에서도 MAD 시스템을 장착한 정찰기를 자체적으로 개발하였고 이스라엘에서도 MAD 시스템을 탑재한 무인기를 개발하여 운용하고 있다.')
#   - ('국방과학기술플러스 250호', '1970년대 이후 미국은 U-2와 같은 유인 정찰기 대체용으로 중/고고도 장기체공 무인기 개발에 착수하였다.')
#   - ('국방과학기술플러스_236호(2017년+2분기)', '이 때  표적 영상 정보는 발사 전 가장 최근에 정찰기, 인공위성 등으로부터 획득된 영상으로부터 생성되어 메모리에 저장되며, 탐색기는 목표 표적물뿐만 아니라 표적지 근방의 지형 영상 정보를 이용하여 점차 표적으로 종말 유도를 수행한 후에 목표물을 최종 타격한다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '또한, Lockheed Martin은 극초음속 정찰기인 SR-72 연구 과제를 2014년에 NASA로부터 수주한 바 있다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '극초음속 순항유도무기의 개발 완료 후에는, 작전 유연성 측면에서 정찰위성보다 더 유리한 극초음속 정찰기 및 전술타격용 비행체를 개발하는 것도 가능해질 것으로 보인다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '정찰기와 같은 센서체계는 네트워크를 통하여 수집된 적 탐지 정보를 타 참여자에게 전파하고 계속적으로 정보를 갱신한다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '정찰기와 위성은 적의 위치를 탐지한 후 정확한 표적 위치를 확인한다.')
#
# 정찰위성 (9건):
#   - ('국방과학기술플러스_242호(2018년+4분기)', '극초음속 순항유도무기의 개발 완료 후에는, 작전 유연성 측면에서 정찰위성보다 더 유리한 극초음속 정찰기 및 전술타격용 비행체를 개발하는 것도 가능해질 것으로 보인다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '정찰위성은 설치 후 활동기간이 제한적이기 때문에 군사적으로 필요한 정보를 얻기 위해서는 많은 수의 위성을 운영해야 하므로 예산이 많이 소요될 수밖에 없다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '게다가 현재와 같이 ‘우주발사체 액체연료 추진체’에 의해서만 정찰위성을 설치한다면 군사적으로 꼭 필요한 시기에 추가 정찰위성을 설치해야 하는 즉시성 문제를 해결할 수 없다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '더 많은 정찰위성이 필요하지만 이 문제는 예산의 소요와 즉시성 문제에 봉착한다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '56) 이를 통해 2020년 1기, 2021년 2기, 2023년 2기의 정찰위성 전력화가 이루어질 전망이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '이를 위해 2017년 7월 25일 제104회 방위사업추진위원회에서 군 정찰위성을 전력화하는 ‘4·25사업’55)이 심의·의결되어 ‘425사업추진기본전략’과 ‘체계개발기본계획안’이확정되었다.')
#   - ('국방과학기술플러스 249호', '물론, 사전에 저궤도 정찰위성이 탄도탄 발사 징후를 포착하여 제공하게 된다면 탄도탄 발사 탐지 신뢰성을 더욱 높일 수 있다.')
#   - ('국방과학기술플러스 249호', '또한, 기술의 발전으로 초소형 위성의 대량 생산이 가능해짐에 따라 세계 각국은 저비용의 초소형 위성군(Mega Constellation) 발사를 계획하고 있어 향후, 아군의 군정찰위성 및 초소형 위성군의 안정적인 운영을 위해 우주감시가 요구된다.')
#   - ('국방과학기술플러스 249호', '또한, 북한이 탄도미사일 개발능력을 활용하여 멀지 않은 시기에 정찰위성을 발사하여 한반도에 전개하여 미군의 전략자산이나 증원전력 현황을 촬영할 개연성 고려 시 이에 대한 감시가 요구되는 상황이다.')
#
# 지뢰 (10건):
#   - ('국방과학기술플러스_247호(20년도+1분기)', '1 UXO 탐지장비UXO 탐지장비는 지하나 수중의 금속물체에 의한 지구자기장의 왜곡을 탐지하는 장비로써 주로 드론이나 무인기 등에 탑재하여 지뢰나 기뢰탐지 등의 위치를 검출한다.')
#   - ('국방과학기술플러스 250호', '미국의 수중드론 개발현황미 해군은 순항 미사일, 어뢰, 지뢰 및 소형 UUV로 무장한 초대형급 수중드론을 목표로 오르카(Orca) XLUUV를 개발하고 있다.')
#   - ('국방과학기술플러스_235호(2017년+1분기)', '자가기동형은 바퀴형, 궤도형 등의 형태로 개발되어 감시정찰, 수송지원, 지뢰제거 및 전투용으로 운용 중이다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '표 3의 지뢰탐지과업에서 감시장비, 무장장비가 해당하며, 이를 보조장비로 식별한다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '예를 들어, 이동감시 과업은 지뢰탐지로봇 보다 감시로봇이 더 높은 적합도를 가져야 한다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '이동과업은 주행장비, 지뢰탐지과업은 지뢰탐지기, 고정감시는 감시장비, 이동감시는 주행장비와 감시장비가 주장비가 된다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '지뢰탐지 로봇은 감시장비의 IR이 작동되지 않아 중결함으로 식별된다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '표 1 과업을 수행하기 위한 임무장치는 주행장치, 감시장치, 무장장치, 지뢰탐지기 등이 있으며 식(10)에 적용하면 다음과 같다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '그림 8에서 보듯이 기존 임무계획과는 달리 이동감시 과업에 대한 임무예비 협업과 지뢰탐지 과업에 대한 임무단축 협업을 적용한 로봇-과업 적합도 기반의 임무최적할당이 적용되었음을 확인하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '표 1은 로봇을 위해 정의된 과업의 예이며 대기, 이동, 지뢰탐지, 고정감시, 이동감시 등 총 5개 과업 종류가 있다.')
#
# 천궁 (8건):
#   - ('국방과학기술플러스_242호(2018년+4분기)', '천궁은 2011년에 개발이 완료되었으며, 2015년에 탄도미사일 요격 능력이 추가된 성능 개량형이 개발되었다.')
#   - ('국방과학기술플러스 249호', '현재까지의 열전지의 무기체계 적용국내 개발 열전지는 중거리 지대공 유도무기인 천궁에 최초로 적용되었다.')
#   - ('국방과학기술플러스 249호', '그러나 천궁에 적용되는 4종의 열전지 중 점화용 열전지 1종에만 국내 개발 열전지가 적용되었고, 나머지는 도입 열전지가 적용되는 형태였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '천궁 탄두의 형상은 그림 39-(b)와 같으며 파편부 외면에 여러 가닥의 변형화약을 사용하였다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '4) 천궁  천궁은 대한민국이 개발한 중거리/중고도(사거리 40km, 요격고도 15kn)의 지대공 미사일이다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '그러나 천궁이나 해궁을 KF-X에 그대로 장착하기에는 너무 무겁거나 너무 작다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '한국은 그동안 천궁과 해궁 등 지상발사형 대공 미사일을 성공적으로 개발해 왔다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '천궁에 탑재된 탄두는 표적 지향성 탄두로 탄두의 폭발력을 표적방향으로 집중시켜 탄두의 에너지를 효율적으로 이용하였다.')
#
# 킬체인 (3건):
#   - ('국방과학기술플러스_248호(20년도+2분기)', '킬체인 공격단계별 공격기술과 방어기능 수준평가공격기술과 방어기능의 연관성 분석을 통해 킬체인 공격단계와 방어 영역별 수준을 평가한 결과, 약화와 거부 영역의 방어분야는 공격단계에 가장 적절히 대응할 수 있는 기능을 보유하고 있는 것으로 평가되었으며, 방어기능 100%의 의미는 현재까지 식별된 모든 방어기능을 보유하고 있다는 것을 의미한다.')
#   - ('국방과학기술플러스_242호(2018년+4분기)', '242 - Fourth-quarter  『2012년 개정된 미사일지침』은 2013년 2월 12일 북한의 3차 핵실험 후 도입된 우리 군의 ‘킬체인(Kill-Chain)체계’와 ‘한국형 미사일 방어(KAMD)체계’ 구축의 핵심 전력 증강에 기여했다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '우리 軍이 지속적으로 지능화·고도화·정교화·조직화된 적 사이버위협에 능동적으로 대응 가능한 사이버킬체인 기반의 「국방 사이버위협 대응체계 구축」비전을 제안한다.')
#
# 하푼 (1건):
#   - ('국방과학기술플러스_248호(20년도+2분기)', '하푼, 해성-I 등 대함 유도탄은 보다 긴 사거리, 초음속 추진기, 해면밀착 비행능력, 다중모드 탐색기 적용 등을 통해 치명성을 향상시켜 나가고 있으며, SM-2, 해궁과 같은 대공 유도탄 또한 비행속도, 사거리, 표적 식별능력 향상을 통해 정밀 요격능력을 발전시켜 나가고 있다.')
#
# 함포 (2건):
#   - ('국방과학기술플러스_244호(2019년+2분기)', '그러나, 화포와 함포에서의 재래식 탄약발사는 사거리와 포신의 수명 저하로 한계가 있다.')
#   - ('국방과학기술플러스_244호(2019년+2분기)', '지상 화포와 함포에서 발사된 정찰포탄과 장거리 활공포탄은 발사후 초기의 고압과 충격으로 활공탄약을 보호하기 위해 저장약으로 발사하고 있다.')
#
# 현궁 (5건):
#   - ('국방과학기술플러스 249호', '순수한 국내 열전지만의 적용은 보병용 중거리 유도무기인 현궁에서부터 시작되었다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '이는 발사 후 망각 유도(Fire & Forget) 방식으로 보병용 중거리 유도무기 현궁의 운용 방식과 동일하고, 사수가 유도탄 발사 후 광섬유를 절단하지 않으면 MITL 운용도 가능하다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '75인치 유도로켓 비궁과 보병용 중거리유도무기 현궁에 적용된 탐색기 추적알고리듬 기술을 기반으로 하여 다양한 기후 조건, 전장 환경에서 해상/육상 표적에 대응할 수 있도록 개발 중이다.')
#   - ('국방과학기술플러스 249호', '현궁의 경우, 무기체계가 소형이었기 때문에 하나의 열전지로 모든 전원시스템을 감당했지만 이후 함대공 유도무기(해궁), 함대지 유도탄(해룡) 등 유도무기체계의 대형화에 따라 주전원용 열전지/구동용 열전지/원격통신용 열전지 등 열전지의 역할이 세분화되었다.')
#   - ('국방과학기술플러스_248호(20년도+2분기)', '현재 국내에서는 보병용 중거리유도무기 현궁 체계 기술 기반으로 소형무장헬기 공대지 유도탄을 개발하고 있다.')

# %%
df_out
# Out:
#         term                                            pdf  \
# 0    5세대 전투기                  국방과학기술플러스 250호
# 1    5세대 전투기  국방과학기술플러스_242호(2018년+4분기)
# 2    5세대 전투기                  국방과학기술플러스 249호
# 3       A-10  국방과학기술플러스_242호(2018년+4분기)
# 4        IED  국방과학기술플러스_239호(2018년+1분기)
# ..       ...                                            ...
# 332       현궁                  국방과학기술플러스 249호
# 329       현궁                  국방과학기술플러스 249호
# 330       현궁  국방과학기술플러스_248호(20년도+2분기)
# 331       현궁  국방과학기술플러스_248호(20년도+2분기)
# 333       현궁  국방과학기술플러스_248호(20년도+2분기)
#
#                                                example
# 0    전 세계에서 저피탐 기술이 가장 발달된 것으로 알려진 미국은 최근 저피탐 성능을 키...
# 1    5세대 전투기인 F-22, F-35 개발 이후 스텔스 성능은 군사용 항공기에 필수적...
# 2    러시아의 5세대 전투기인 Su-57(일명 PAK-PA)에는 Tikhomirov NI...
# 3    HA-10이라는 무인기의 개발도 병행하였는데 7~15km 상공을 24시간 체공 비행...
# 4    IED에 의한 피해를 줄이기 위해서 재머를 켠 상태에서 이동을 하지만, 이 상황에서...
# ..                                                 ...
# 332  현궁의 경우, 무기체계가 소형이었기 때문에 하나의 열전지로 모든 전원시스템을 감당했...
# 329       순수한 국내 열전지만의 적용은 보병용 중거리 유도무기인 현궁에서부터 시작되었다.
# 330  이는 발사 후 망각 유도(Fire & Forget) 방식으로 보병용 중거리 유도무기...
# 331  75인치 유도로켓 비궁과 보병용 중거리유도무기 현궁에 적용된 탐색기 추적알고리듬 기...
# 333  현재 국내에서는 보병용 중거리유도무기 현궁 체계 기술 기반으로 소형무장헬기 공대지 ...
#
# [334 rows x 3 columns]

# %% [markdown]
# # csv 저장

# %%
def xlsx_to_csv(input_xlsx: str, output_csv: str, sheet_name=0):

    # 1) 엑셀 파일 로드
    df = pd.read_excel(input_xlsx, sheet_name=sheet_name, engine='openpyxl')

    # 2) CSV로 저장 (UTF-8 BOM 포함)
    df.to_csv(output_csv, index=False, encoding='utf-8-sig')
    print(f" '{input_xlsx}' → '{output_csv}' 변환 완료 (encoding='utf-8-sig')")

# %%
if __name__ == "__main__":
    input_xlsx = '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/국방과학연구소_나머지_용례매핑.xlsx'
    output_csv = '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/국방과학연구소_무기의세계_용례매핑_나머지_전처리후.csv'     # 저장할 csv 파일 경로
    xlsx_to_csv(input_xlsx, output_csv)
# Out:
#  '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/국방과학연구소_나머지_용례매핑.xlsx' → '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/국방과학연구소_무기의세계_용례매핑_나머지_전처리후.csv' 변환 완료 (encoding='utf-8-sig')

# %% [markdown]
# # 용어별 리스트로 csv 저장

# %%
def group_manual_csv(input_csv: str, output_csv: str):
    # 1) 기존 CSV 로드 (UTF-8 BOM 포함)
    df = pd.read_csv(input_csv, encoding='utf-8-sig')

    # 2) 컬럼 이름 확인 (필요시 조정)
    print("원본 컬럼:", df.columns.tolist())

    # 3) term별로 pdf와 example을 리스트로 묶기
    grouped = (
        df
        .groupby('term')
        .agg({
            'pdf': lambda s: list(dict.fromkeys(s)),   # PDF 출처 중복 제거 후 리스트
            'example': list                            # 예시 문장 리스트
        })
        .reset_index()
        .rename(columns={
            'pdf': 'sources',
            'example': 'examples'
        })
    )

    # 4) 결과 확인
    print(grouped.head())

    # 5) CSV로 저장 (UTF-8 BOM 포함)
    grouped.to_csv(output_csv, index=False, encoding='utf-8-sig')
    print(f"✔ '{output_csv}'에 저장 완료!")

if __name__ == "__main__":
    input_csv = '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/국방과학연구소_무기의세계_용례매핑_나머지_전처리후.csv'
    output_csv = "/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/국방과학연구소_무기의세계_용례매핑_나머지_전처리후_일대다.csv"
    group_manual_csv(input_csv, output_csv)
# Out:
# 원본 컬럼: ['term', 'pdf', 'example']
#       term                                            sources  \
# 0  5세대 전투기  [국방과학기술플러스 250호, 국방과학기ᄉ...
# 1      IED    [국방과학기술플러스_239호(2018년+1분기)]
# 2     J-20                    [국방과학기술플러스 249호]
# 3     P-3C    [국방과학기술플러스_247호(20년도+1분기)]
# 4    RPG-7    [국방과학기술플러스_235호(2017년+1분기)]
#
#                                             examples
# 0  [전 세계에서 저피탐 기술이 가장 발달된 것으로 알려진 미국은 최근 저피탐 성능을 ...
# 1  [IED에 의한 피해를 줄이기 위해서 재머를 켠 상태에서 이동을 하지만, 이 상황에...
# 2  [3세대 AESA 레이다 기술은 J-20 전투기 포함 다수의 전투기 탑재를 목표로 ...
# 3  [1990년대에는 Helium원자의 Zeeman 효과를 적용한 자기장 센서가 개발되...
# 4  [최근 북한도 이라크전 등 현대전의 전쟁교훈을 분석하여 시가지 전투에 적합한 전술과...
# ✔ '/content/drive/MyDrive/Hanhwa/crawling_project/crawling_project/data/국방과학연구소_무기의세계_용례매핑_나머지_전처리후_일대다.csv'에 저장 완료!
