# %%
# !pip install folium

# %%
import pandas as pd
import ast
import folium
from IPython.display import display
from collections import defaultdict

# 1) 토큰 → 표준 국가명 매핑
token_to_country = {
    'United Arab Emirates': 'United Arab Emirates',
    '한반도': 'South Korea', '대한': 'South Korea', '한국': 'South Korea', '한': 'South Korea',
    '인천': 'South Korea', '부산': 'South Korea', '서울': 'South Korea', '울산': 'South Korea',
    '국군': 'South Korea', '우리 군': 'South Korea', '당국': 'South Korea', '국내': 'South Korea',
    '북한': 'North Korea',
    '영국': 'United Kingdom',
    '소련': 'Russia', '러시아': 'Russia',
    '서독': 'Germany', '동독': 'Germany', '독일': 'Germany',
    '일제': 'Japan', '일본': 'Japan',
    '중국': 'China',
    '이란': 'Iran',
    '미 공군': 'United States', '미공군': 'United States',
    '미 해병대': 'United States', '미해병대': 'United States',
    '미 육군': 'United States', '미육군': 'United States',
    '미 해군': 'United States', '미해군': 'United States',
    '미군': 'United States', '미 대통령': 'United States', '미국': 'United States',
    '프랑스': 'France',
    '이탈리아': 'Italy',
    '네덜란드': 'Netherlands',
    '벨기에': 'Belgium',
    '터키': 'Turkey',
    '베트남': 'Vietnam',
    '오스트레일리아': 'Australia', '호주': 'Australia',
    '대만': 'Taiwan',
    '아프가니스탄': 'Afghanistan',
    '리비아': 'Libya',
    '유럽': 'Europe',
    '이라크': 'Iraq',
    '인도네시아': 'Indonesia',
    '필리핀': 'Philippines',
    '태국': 'Thailand',
    '페루': 'Peru',
    '캐나다': 'Canada',
    '브라질': 'Brazil',
    '스웨덴': 'Sweden',
    '스페인': 'Spain',
    '이스라엘': 'Israel',
    'UAE': 'United Arab Emirates',
    '사우디': 'Saudi Arabia',
    '폴란드': 'Poland',
    '말레이시아': 'Malaysia',
}

# 토큰을 길이 내림차순으로 정렬 (긴 토큰부터 매칭)
tokens_sorted = sorted(token_to_country.keys(), key=len, reverse=True)

# 2) 표준 국가명 → 수도 위도·경도 매핑
coords = {
    'South Korea': (37.5665, 126.9780),          # Seoul
    'North Korea': (39.0392, 125.7625),          # Pyongyang
    'United Kingdom': (51.5074, -0.1278),        # London
    'Russia': (55.7558, 37.6173),                # Moscow
    'Germany': (52.5200, 13.4050),               # Berlin
    'Japan': (35.6895, 139.6917),                # Tokyo
    'China': (39.9042, 116.4074),                # Beijing
    'Iran': (35.6892, 51.3890),                  # Tehran
    'United States': (38.9072, -77.0369),        # Washington, D.C.
    'France': (48.8566, 2.3522),                 # Paris
    'Italy': (41.9028, 12.4964),                 # Rome
    'Netherlands': (52.3676, 4.9041),            # Amsterdam
    'Belgium': (50.8503, 4.3517),                # Brussels
    'Turkey': (39.9334, 32.8597),                # Ankara
    'Vietnam': (21.0278, 105.8342),              # Hanoi
    'Australia': (-35.2809, 149.1300),           # Canberra
    'Taiwan': (25.03297, 121.56542),             # Taipei
    'Afghanistan': (34.5553, 69.2075),           # Kabul
    'Libya': (32.8872, 13.1913),                 # Tripoli
    'Europe': (50.8503, 4.3517),                 # Brussels (EU)
    'Iraq': (33.3152, 44.3661),                  # Baghdad
    'Indonesia': (-6.2088, 106.8456),            # Jakarta
    'Philippines': (14.5995, 120.9842),          # Manila
    'Thailand': (13.7563, 100.5018),             # Bangkok
    'Peru': (-12.0464, -77.0428),                # Lima
    'Canada': (45.4215, -75.6972),               # Ottawa
    'Brazil': (-15.7939, -47.8828),              # Brasília
    'Sweden': (59.3293, 18.0686),                # Stockholm
    'Spain': (40.4168, -3.7038),                 # Madrid
    'Israel': (31.7683, 35.2137),                # Jerusalem
    'United Arab Emirates': (24.4539, 54.3773),  # Abu Dhabi
    'Saudi Arabia': (24.7136, 46.6753),          # Riyadh
    'Poland': (52.2297, 21.0122),                # Warsaw
    'Malaysia': (3.1390, 101.6869),              # Kuala Lumpur
}

# 3) CSV 읽고 '용례리스트' 파싱
df = pd.read_csv('통합.csv')
df['용례리스트'] = df['용례리스트'].apply(
    lambda x: ast.literal_eval(x) if pd.notnull(x) else []
)

# 4) 국가별 집계 (행 단위 한 번씩 카운트 + 세부항목별 빈도 집계)
country_data = {}
for _, row in df.iterrows():
    countries_in_row = set()
    for sentence in row['용례리스트']:
        for token in tokens_sorted:
            if token in sentence:
                countries_in_row.add(token_to_country[token])
    for country in countries_in_row:
        rec = country_data.setdefault(
            country,
            {
                'count': 0,
                'item_freq': defaultdict(int),
                'words': set()
            }
        )
        rec['count'] += 1
        rec['item_freq'][row['세부항목']] += 1
        rec['words'].add(row['용어'])

# 5) Folium 맵 생성 및 마커 추가
m = folium.Map(location=[20, 0], zoom_start=2)
for country, rec in country_data.items():
    lat, lon = coords[country]
    # 세부항목별 빈도를 "항목: 빈도" 형태로 정리
    item_lines = [f"{item}: {cnt}" for item, cnt in rec['item_freq'].items()]
    # 용어들을 쉼표로 나열
    term_list = ", ".join(rec['words'])
    popup = (
        f"<b>{country}</b><br>"
        f"등장 행 수: {rec['count']}건<br>"
        f"세부항목별 빈도:<br>{'<br>'.join(item_lines)}<br>"
        f"용어:<br>{term_list}"
    )
    folium.Marker(
        [lat, lon],
        popup=folium.Popup(popup, max_width=300)
    ).add_to(m)

# 6) Jupyter Notebook에서 바로 보기
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3019e6ca1ad1ec5d73a1c9c43969e15c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3019e6ca1ad1ec5d73a1c9c43969e15c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3019e6ca1ad1ec5d73a1c9c43969e15c = L.map(
#                 &quot;map_3019e6ca1ad1ec5d73a1c9c43969e15c&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d640aa5b387e78dd4eb62d37fa80e28 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d640aa5b387e78dd4eb62d37fa80e28.addTo(map_3019e6ca1ad1ec5d73a1c9c43969e15c);
#
#
#             var marker_302ddbd026e6cdb5376759af1707e893 = L.marker(
#                 [35.6892, 51.389],
#                 {
# }
#             ).addTo(map_3019e6ca1ad1ec5d73a1c9c43969e15c);
#
#
#         var popup_7b937716fd519af5a88145910542c6e7 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_a28e34569360af0ef417c669baf83367 = $(`&lt;div id=&quot;html_a28e34569360af0ef417c669baf83367&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Iran&lt;/b&gt;&lt;br&gt;등장 행 수: 42건&lt;br&gt;세부항목별 빈도:&lt;br&gt;해상병기: 2&lt;br&gt;개인화기: 7&lt;br&gt;항공병기: 10&lt;br&gt;육상병기: 4&lt;br&gt;미사일: 7&lt;br&gt;기타무기: 6&lt;br&gt;폭탄 및 핵무기: 2&lt;br&gt;무기 및 병기공학 일반: 3&lt;br&gt;우주무기: 1&lt;br&gt;용어:&lt;br&gt;유로파이터 타이푼, 현궁, 기관단총, PAK FA, 코브라 공격헬기, F-4 팬텀, M4 카빈, 전투식량, AK-47, 샷건, 현무 미사일, T-72 전차, A-6 인트루더, 공격기, 조총, Mi-24 하인드 공격헬기, 기뢰, 99식 소총, 토우 대전차 미사일, 라팔, 45형 데어링급 구축함, 저격수, K-9 자주포, 네이비실, 편전, 거북선, 돌격소총, SM-3, A-10, 신궁, 야시장비, 하푼, 장갑차, 대륙간탄도미사일, 정찰위성, 전자전기, 어뢰, M-109 자주포, 정찰기, 바스타드 소드, 키드급 구축함, RPG-7&lt;/div&gt;`)[0];
#                 popup_7b937716fd519af5a88145910542c6e7.setContent(html_a28e34569360af0ef417c669baf83367);
#
#
#
#         marker_302ddbd026e6cdb5376759af1707e893.bindPopup(popup_7b937716fd519af5a88145910542c6e7)
#         ;
#
#
#
#
#             var marker_ef5f62a71cece2822092358372536aa8 = L.marker(
#                 [51.5074, -0.1278],
#                 {
# }
#             ).addTo(map_3019e6ca1ad1ec5d73a1c9c43969e15c);
#
#
#         var popup_76ca7856032e31c4fb89f928f25cc481 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_10738d3a6cc5e156e53c4d1559844b4d = $(`&lt;div id=&quot;html_10738d3a6cc5e156e53c4d1559844b4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;United Kingdom&lt;/b&gt;&lt;br&gt;등장 행 수: 77건&lt;br&gt;세부항목별 빈도:&lt;br&gt;해상병기: 10&lt;br&gt;항공병기: 20&lt;br&gt;개인화기: 17&lt;br&gt;폭탄 및 핵무기: 4&lt;br&gt;육상병기: 12&lt;br&gt;기타무기: 7&lt;br&gt;미사일: 3&lt;br&gt;무기 및 병기공학 일반: 4&lt;br&gt;용어:&lt;br&gt;M1 에이브람스 전차, 루이스 경기관총, 강습상륙함, 공대공 미사일, 기관단총, 리버티선, 미라주 2000, 전함 드레드노트, 열차포, 45형 데어링급 구축함, 저격수, 스텐 기관단총, 연안전투함, 전함 비스마르크, 프레데터, M14 소총, A-10, 차륜형 장갑차, 5세대 전투기, 장갑차, 유로파이터 타이푼, 흑표, 경기관총, 경항공모함, 블랙번 버캐니어, 특수작전차량, 리볼버, 전투식량, 아파치, 박격포, 조총, 해리어, 아크 로열, 토마호크 순항미사일, 드 하빌랜드 뱀파이어, M1911 권총, 미니건, 함포, M-109 자주포, HK416, 티거, 스피트파이어, RPG-7, 무인전투기, 사드, F-4 팬텀, 지뢰, T-50, MP5 기관단총, 킬체인, 소드피쉬 뇌격기, 공격기, 그린베레, 맥심 기관총, 라팔, K-9 자주포, 대함미사일, 돌격소총, 레오파르트 2, 순양전함, 톰슨 기관단총, 허리케인 전투기, F-22 랩터, 화차, 바스타드 소드, 공중급유기, IED, 저격총, 기뢰, 전차상륙함, 거북선, 대포병 레이더, 전자전기, M16 소총, 어뢰, 정찰기, M1903 스프링필드 소총&lt;/div&gt;`)[0];
#                 popup_76ca7856032e31c4fb89f928f25cc481.setContent(html_10738d3a6cc5e156e53c4d1559844b4d);
#
#
#
#         marker_ef5f62a71cece2822092358372536aa8.bindPopup(popup_76ca7856032e31c4fb89f928f25cc481)
#         ;
#
#
#
#
#             var marker_0569f807e7b21038df90270b7bfb466e = L.marker(
#                 [37.5665, 126.978],
#                 {
# }
#             ).addTo(map_3019e6ca1ad1ec5d73a1c9c43969e15c);
#
#
#         var popup_8c765b66ab73d8e7d2f7f08538b16599 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_ce77a461161a059c200bd76694c9fe70 = $(`&lt;div id=&quot;html_ce77a461161a059c200bd76694c9fe70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;South Korea&lt;/b&gt;&lt;br&gt;등장 행 수: 238건&lt;br&gt;세부항목별 빈도:&lt;br&gt;해상병기: 27&lt;br&gt;항공병기: 68&lt;br&gt;육상병기: 38&lt;br&gt;개인화기: 48&lt;br&gt;미사일: 18&lt;br&gt;폭탄 및 핵무기: 10&lt;br&gt;우주무기: 2&lt;br&gt;기타무기: 17&lt;br&gt;무기 및 병기공학 일반: 10&lt;br&gt;용어:&lt;br&gt;M1 에이브람스 전차, MG42 기관총, 마르다, 수리온, 루이스 경기관총, PK 기관총, 강습상륙함, CVN-65 엔터프라이즈, 공대공 미사일, 항공모함 쿠즈네초프, 피스아이, 기관단총, 코브라 공격헬기, MiG-21 피쉬베드, 비살상무기, 리버티선, 미라주 2000, 전략 폭격기, 전함 드레드노트, K5 권총, P-8A 포세이돈, 천무, 기총, A-6 인트루더, 장사정포, Mi-28 하보크, 열차포, 동펑 탄도미사일, AC-130 건십, UH-60 블랙호크, CV-5 요크타운, 견인포, M8 정찰장갑차, OH-58 카이오와, UH-1 휴이, 45형 데어링급 구축함, M3 기관단총, 저격수, 하이랜더의 클레이모어, 스텐 기관단총, 알레이버크급 구축함, 연안전투함, 전함 비스마르크, 프레데터, M14 소총, A-10, 스트라이커 장갑차, 차륜형 장갑차, 5세대 전투기, 장갑차, 방탄조끼, 글라디우스, 케텐크라트, X-37B, MiG-19 파
